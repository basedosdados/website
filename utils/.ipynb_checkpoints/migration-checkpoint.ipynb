# %%
from pprint import pprint
import sys
import os, json, re, requests
import random

from pathlib import Path
import ckanapi.errors
from ckanapi.errors import NotFound
import pandas as pd

# %%
from ckanapi import RemoteCKAN

os.environ["CKAN_API_KEY"] ="" 

if not os.environ.get('CKAN_API_KEY'):
    print("You need to export environment variable `CKAN_API_KEY`. PLease generate an api key from this page: http://localhost:5000/user/dev/api-tokens")
    exit(1)
    
    
user_agent = None
CKAN_API_KEY = os.environ['CKAN_API_KEY']
CKAN_URL = os.environ.get('CKAN_URL', 'http://localhost:5000')

basedosdados = RemoteCKAN(CKAN_URL, user_agent=user_agent, apikey=CKAN_API_KEY)

# %%
def validate(package_dict):
    
    if package_dict.get('extras'):
        package_dict['extras'] = [kv for kv in package_dict.get('extras') if 'key' in kv and 'value' in kv] # there is a strange bug splitting extra dicts into dicts missing value and key, so we simply remove these, we aren't validating extras anyway
    try:
        basedosdados.action.package_validate(**package_dict)
    except ckanapi.errors.ValidationError as e:
        return e.error_dict['message']

def migrate_resource_external_link(resource_dict, package_dict):
    
    # brazilian_ip to country_ip_address_required
    resource_dict['country_ip_address_required'] = None
    if resource_dict.get('brazilian_ip') == 'yes':
        resource_dict['country_ip_address_required'] = ['bra']
    resource_dict.pop('brazilian_ip', None)

    # free to is_free
    resource_dict['is_free'] = resource_dict.pop('free', None)
    
    # license_type
    resource_dict.pop('license_type', None)
    resource_dict['license'] = 'mit' 
    
    # signup_needed to requires_registration
    resource_dict['requires_registration'] = resource_dict.pop('signup_needed', None)
    
    # delete version
    resource_dict.pop('version', None)
    
    # package API to has_api
    api_mapping = {'Não': 'no', 'Sim': 'yes'}
    api = package_dict.pop('API', None)
    if api:
        resource_dict['has_api'] = api_mapping.get(api)
    else:
        resource_dict['has_api'] = None
        
    # map update_frequency values
    update_frequency_mapping = {'empty': None}
    resource_dict['update_frequency'] =  update_frequency_mapping.get(resource_dict.get('update_frequency', None), None)
    
    # pop bdm_file_size
    resource_dict.pop('bdm_file_size', None)
    
    # clean extra from temporal coverage
    resource_dict['temporal_coverage'] = [v for v in resource_dict.get('temporal_coverage', []) if isinstance(v, int)] 
    
    return resource_dict

def migrate_resource_bdm_table(resource_dict, package_dict):
    
    # delete primary_keys
    resource_dict.pop('primary_keys', None)
    
    # structure published
    to_pop = [k for k in resource_dict.keys() if 'published_by.' in k]
    for k in to_pop:
        resource_dict.pop(k, None)
            
    resource_dict['published_by'] = dict(
        name=resource_dict.pop('publisher', None),
        email=resource_dict.pop('publisher_email', None),
        github_user=resource_dict.pop('publisher_github', None),
        website=resource_dict.pop('publisher_website', None)
    )
    
    # structure treated
    resource_dict['data_cleaned_by'] = dict(
        name=resource_dict.pop('treated_by.name', None),
        email=resource_dict.pop('treated_by.email', None),
        github_user=resource_dict.pop('treated_by.github', None),
        website=resource_dict.pop('treated_by.website', None),
        code_url=resource_dict.pop('treated_by.code_url', None)
    )
        
    
    # treatment_description to data_cleaning_description
    resource_dict['data_cleaning_description'] = resource_dict.pop('treatment_description', None)
    
    # pop url_ckan
    resource_dict.pop('url_ckan', None)
    
    # pop url_github
    resource_dict.pop('url_github', None)
    
    # columns
    cols = resource_dict.get('columns')
    if cols == '' or cols is None: 
        resource_dict.pop('columns', None)
        resource_dict['columns'] = []
    
    # spatial coverage
    spatial_coverage_mapping = {
        'vazio': None,
        'america_norte': ['north_america'],
        'africa': ['africa'],
        'europa': ['europe'],
        'internacional': ['all'],
        'america_sul': ['south_america'],
    }
    resource_dict['spatial_coverage'] = dict(
        continent=spatial_coverage_mapping.get(resource_dict.pop('spatial_coverage', None), None)
    )
    
    # observation level to entity
    res = resource_dict.get('observation_level')
    if res is None:
        resource_dict['entity'] = None
    elif res[0] == 'other' or None:
        resource_dict['entity'] = None
    else:
        resource_dict['entity'] = resource_dict.pop('observation_level', None)
    resource_dict.pop('observation_level', None)
    
    # clean extra from temporal coverage
    resource_dict['temporal_coverage'] = [v for v in resource_dict.get('temporal_coverage', []) if isinstance(v, int)] 

    return resource_dict
    
def migrate(package_dict):
    
    # Resources
    for resource in package_dict['resources']:
        
        if resource['resource_type'] == 'external_link':
            resource = migrate_resource_external_link(resource, package_dict)
        
        elif resource['resource_type'] == 'bdm_table':
            resource = migrate_resource_bdm_table(resource, package_dict)

    
    return package_dict

# %%
ORIGINAL_CKAN_URL = 'https://basedosdados.org'
api_url = ORIGINAL_CKAN_URL + '/api/3/action/package_list'
packages = requests.get(api_url, verify=False).json()['result']
# Out:
# /Users/m/miniconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'basedosdados.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
def get_content(p):
    api_url = ORIGINAL_CKAN_URL + f'/api/3/action/package_show?id={p}'
    return requests.get(api_url).json()['result']

import json
for p in packages:
    json.dump(get_content(p), open(f'packages/{p}', 'w'))

# %%
def package_update(package_path, validate_only=True):
    package = json.load(open(package_path))
    migrated = migrate(package)
    if validate(migrated):
        raise Exception(res)
    
    if not validate_only:
        try:
            basedosdados.action.package_update(**migrated)
        except NotFound:
            print(package_path)

# %%
package = json.load(open('packages/br_abrinq_oca'))
# migrated = migrate(package)

# %%
full_input = ['id', 'name', 'title', 'type', 'notes', 'author', 'author_email', 'maintainer', 'maintainer_email', 'state', 'license_id', 'url', 'version', 'metadata_created', 'metadata_modified', 'creator_user_id', 'private', 'license_title', 'num_resources', 'resources', 'groups', 'owner_org', 'organization', 'num_tags', 'tags', 'relationships_as_object', 'relationships_as_subject', 'isopen', 'extras', 'download_type']

# %%
no_input = ['id', 'name', 'title', 'type', 'notes', 'author', 'author_email', 'maintainer', 'maintainer_email', 'state', 'license_id', 'url', 'version', 'metadata_created', 'metadata_modified', 'creator_user_id', 'private', 'license_title', 'num_resources', 'resources', 'groups', 'owner_org', 'organization', 'num_tags', 'tags', 'relationships_as_object', 'relationships_as_subject', 'isopen', 'extras']

# %%
ORIGINAL_CKAN_URL = 'http://localhost:5000'
api_url = ORIGINAL_CKAN_URL + '/api/3/action/package_show?id=br_abrinq_oca'

package = requests.get(api_url).json()['result']
# package = migrate(package)
if 'extras' in package.keys():
    print("Tem extras")
# Out:
# Tem extras

# %%
# package['extras'][6]
# package['extras'][6]['value'] = "BD Mais"

# %%
package.keys()

# %%
package.pop('download_type')
# Out:
# 'BD Mais'

# %%
basedosdados.action.package_update(**package)
# Out:
# {'id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#  'name': 'br_abrinq_oca',
#  'title': 'Observatório da Criança e do Adolescente',
#  'type': 'dataset',
#  'notes': 'O Observatório da Criança e do Adolescente é um espaço virtual que possibilita a consulta, em um mesmo lugar, dos principais indicadores sociais relacionados direta e indiretamente à infância e adolescência no Brasil. Seu objetivo é organizar as informações e facilitar o acesso a bases de dados de diversas fontes púbicas e privadas sobre população, qualidade de vida e bem-estar de crianças e adolescentes com idades ente zero e 18 anos, permitindo uma análise da evolução das principais políticas, dos desafios e das desigualdades regionais. Destina-se a formadores de opinião, representantes da sociedade civil, pesquisadores, gestores públicos e quaisquer pessoas que queiram, a partir de um simples mecanismo de busca online, conhecer a realidade e os problemas sociais que mais afetam as crianças e os adolescentes no país.',
#  'author': None,
#  'author_email': None,
#  'maintainer': None,
#  'maintainer_email': None,
#  'state': 'active',
#  'license_id': None,
#  'url': 'https://observatoriocrianca.org.br/',
#  'version': None,
#  'metadata_created': '2020-01-31T17:38:21.600263',
#  'metadata_modified': '2021-07-31T00:32:06.086042',
#  'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc',
#  'private': False,
#  'license_title': None,
#  'num_resources': 3,
#  'resources': [{'id': '1123f235-3868-4eca-96f9-be12dadd89e7',
#    'name': 'Cenário Infância',
#    'description': '',
#    'position': 0,
#    'url': 'https://observatoriocrianca.org.br/cenario-infancia',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-01-31T17:38:38.445081',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-31T00:03:17.804926',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'language': ['portuguese'],
#    'has_api': 'no',
#    'availability': 'online',
#    'spatial_coverage': 'america_sul',
#    'temporal_coverage': [2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'free': 'yes',
#    'brazilian_ip': 'no',
#    'license_type': 'CHECK',
#    'signup_needed': 'no',
#    'version': ''},
#   {'id': '02cc80cd-78cc-4aa9-b260-8636ffee126b',
#    'name': 'Agenda Legislativa',
#    'description': '',
#    'position': 1,
#    'url': 'https://observatoriocrianca.org.br/agenda-legislativa',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-01-31T17:38:49.313164',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-31T00:03:17.805086',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'language': ['portuguese'],
#    'has_api': 'no',
#    'availability': 'online',
#    'spatial_coverage': 'america_sul',
#    'temporal_coverage': [2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'free': 'yes',
#    'brazilian_ip': 'no',
#    'license_type': 'CHECK',
#    'signup_needed': 'no',
#    'version': ''},
#   {'id': '749c1fc0-7794-42a6-af6f-f80ff38094c2',
#    'name': 'primeira_infancia_municipios',
#    'description': '',
#    'position': 2,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-12-01T05:28:29.494824',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-31T00:03:17.805192',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'primeira_infancia_municipios',
#    'spatial_coverage': 'america_sul',
#    'temporal_coverage': [2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'version': '',
#    'bdm_file_size': None}],
#  'groups': [{'id': 'ea02cfce-ac55-4079-8de2-02ec79f01c78',
#    'name': 'educacao',
#    'title': 'Educação',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-055755.408617Educacao-Exame-Abril.jpg',
#    'created': '2019-09-17T04:33:15.634528',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'Educação',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-055755.408617Educacao-Exame-Abril.jpg'},
#   {'id': '9b4676bf-be6f-4faa-8890-dbdab6992784',
#    'name': 'gov-fin-pub',
#    'title': 'Governo e Finanças Públicas',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-060407.937294Prestaodecontas.jpg',
#    'created': '2019-09-17T04:33:57.471452',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'Governo e Finanças Públicas',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-060407.937294Prestaodecontas.jpg'},
#   {'id': 'c1990559-75f6-43d0-94f2-8ecfe470b673',
#    'name': 'populacao',
#    'title': 'População',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-060328.174268381c2abde74ad5fb139f94f5347d0fa6.jpg',
#    'created': '2019-09-17T04:57:54.436345',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'População',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-060328.174268381c2abde74ad5fb139f94f5347d0fa6.jpg'},
#   {'id': '8358e722-42fc-408a-8859-084d74da5dd5',
#    'name': 'saude',
#    'title': 'Saúde',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-060434.084225heart-checkup.png',
#    'created': '2019-09-17T04:33:27.710809',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'Saúde',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-060434.084225heart-checkup.png'},
#   {'id': '56e94027-c292-4450-8934-df4232414049',
#    'name': 'seguranca',
#    'title': 'Segurança, Crime, Violência, e Conflito',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-18-005515.746896violence.jpg',
#    'created': '2019-09-18T00:55:15.759613',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'Segurança, Crime, Violência, e Conflito',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-18-005515.746896violence.jpg'}],
#  'owner_org': '08030a35-10bd-4c47-b0e0-5f3a777a209a',
#  'organization': {'id': '08030a35-10bd-4c47-b0e0-5f3a777a209a',
#   'name': 'fundacao-abrinq',
#   'title': 'Fundação Abrinq',
#   'type': 'organization',
#   'description': 'www.fadc.org.br',
#   'image_url': '2020-01-31-173514.705149logo-abrinq.png',
#   'created': '2020-01-31T17:35:14.724875',
#   'is_organization': True,
#   'approval_status': 'approved',
#   'state': 'active'},
#  'num_tags': 6,
#  'tags': [{'id': '8c8a3100-c02e-43fc-89c8-216af9883619',
#    'name': 'congresso',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'congresso'},
#   {'id': 'dd915162-d8b4-4d6c-a951-0a5c85c109b6',
#    'name': 'desigualdade',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'desigualdade'},
#   {'id': 'cfd870c0-8a0a-42d5-a497-86c13ec0f8be',
#    'name': 'legislacao',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'legislacao'},
#   {'id': '0a716590-9eef-41f6-a0ab-a9cf55b6d2cb',
#    'name': 'lei',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'lei'},
#   {'id': '4a3c65d8-3c09-4291-b9e0-75c991156621',
#    'name': 'proposicao',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'proposicao'},
#   {'id': '6f8fd0b7-1820-4e60-95aa-f56fa9bec1fd',
#    'name': 'regulacao',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'regulacao'}],
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'isopen': False,
#  'extras': [{'id': '6711cebd-bbf8-41c0-88b5-d64a0e0431ac',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'ano',
#    'value': '["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]',
#    'state': 'active'},
#   {'id': 'fe5c692d-0484-4bdd-bde1-b91402418f6a',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'api',
#    'value': 'nao',
#    'state': 'active'},
#   {'id': '1a0dfe9c-7c8c-4f9b-8a68-cd61a6393629',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'autor',
#    'value': '',
#    'state': 'active'},
#   {'id': '0c3e5d57-4659-4dff-803a-b254762c86d2',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'autor_email',
#    'value': '',
#    'state': 'active'},
#   {'id': 'a2c7af26-9284-4dee-82ff-92a37efc9cc0',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'coleta',
#    'value': 'administrativo',
#    'state': 'active'},
#   {'id': 'a8a1635d-ae0c-4517-b50e-7a2b4d7a66d6',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'disponibilidade',
#    'value': 'online',
#    'state': 'active'},
#   {'id': 'a21b4448-85b0-4ada-9c0f-13132e56e192',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'download_type',
#    'value': 'BD Mais',
#    'state': 'active'},
#   {'id': '2176c047-6c7e-4b55-93b6-6aa233cfef58',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'estado',
#    'value': 'todos',
#    'state': 'active'},
#   {'id': 'dbb675bb-9d94-4b0f-8f8f-5af332150fc8',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'gratis',
#    'value': 'sim',
#    'state': 'active'},
#   {'id': '4bcc3778-b70f-4ba8-87a4-14011adfa08d',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'idioma',
#    'value': '["portugues"]',
#    'state': 'active'},
#   {'id': 'bb41ede7-f53c-42e1-95c4-fdbe303ed970',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'ip_brasileiro',
#    'value': 'nao',
#    'state': 'active'},
#   {'id': 'c5872633-b507-4bd8-80bc-7499244432e3',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'mantenedor',
#    'value': '',
#    'state': 'active'},
#   {'id': 'e3c485a5-d450-437a-847a-dbd04e1a0d1d',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'mantenedor_email',
#    'value': '',
#    'state': 'active'},
#   {'id': 'b40d9811-1d57-402f-b248-8a6fb3391c50',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'microdados',
#    'value': 'nao',
#    'state': 'active'},
#   {'id': 'fcc74cce-dbbd-4f7c-89d5-26ea0bb1c7a2',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'nivel_observacao',
#    'value': '["pais", "estado", "municipio", "lei"]',
#    'state': 'active'},
#   {'id': '7bfe3aef-d72d-4b95-bf05-917e27dac35f',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'pais',
#    'value': 'brasil',
#    'state': 'active'},
#   {'id': 'e9dd8cf9-2829-4150-87b3-2489bc4fae47',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'periodicidade',
#    'value': 'ano',
#    'state': 'active'},
#   {'id': '67ad97a7-53af-40eb-bda8-0e1c17d22e13',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'regiao',
#    'value': 'america_sul',
#    'state': 'active'},
#   {'id': '70646851-b27b-4ace-bace-7d1e6c26a7a5',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'registro',
#    'value': 'nao',
#    'state': 'active'},
#   {'id': 'c0f9e338-475b-4379-9ee2-556f5d03f707',
#    'package_id': '360325f9-e18c-412d-a9c7-3047e5504b7a',
#    'key': 'versao',
#    'value': '',
#    'state': 'active'}]}

# %%
package.keys()
# Out:
# dict_keys(['id', 'name', 'title', 'type', 'notes', 'author', 'author_email', 'maintainer', 'maintainer_email', 'state', 'license_id', 'url', 'version', 'metadata_created', 'metadata_modified', 'creator_user_id', 'private', 'license_title', 'num_resources', 'resources', 'groups', 'owner_org', 'organization', 'num_tags', 'tags', 'relationships_as_object', 'relationships_as_subject'])

# %%
package['download_type']
# Out:
# 'BD Mais'

# %%
migrated['extras'] = {'download_type': 'BD Mais'}

# %%
basedosdados.action.package_update(**migrated)
# Out:
# {'id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#  'name': 'br-ms-sim',
#  'title': 'Sistema de Informações sobre Mortalidade (SIM)',
#  'type': 'dataset',
#  'notes': 'O Sistema de Informações sobre Mortalidade (SIM) foi criado pelo DATASUS para a obtenção regular de dados sobre mortalidade no país. A partir da criação do SIM foi possível a captação de dados sobre mortalidade, de forma abrangente, para subsidiar as diversas esferas de gestão na saúde pública. Com base nessas informações é possível realizar análises de situação, planejamento e avaliação das ações e programas na área.',
#  'author': None,
#  'author_email': None,
#  'maintainer': None,
#  'maintainer_email': None,
#  'state': 'active',
#  'license_id': None,
#  'url': 'http://www2.datasus.gov.br/DATASUS/index.php?area=0901&item=1',
#  'version': None,
#  'metadata_created': '2019-09-21T14:06:23.493093',
#  'metadata_modified': '2021-07-29T03:31:52.627800',
#  'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc',
#  'private': False,
#  'license_title': None,
#  'num_resources': 9,
#  'resources': [{'id': 'e8469c6d-3c5f-4069-8b40-d6c30597da94',
#    'name': 'Baixar (Link Externo)',
#    'description': '',
#    'position': 0,
#    'url': 'http://www2.datasus.gov.br/DATASUS/index.php?area=0205&id=6937',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2019-09-21T14:06:31.633381',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639048',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'language': ['portuguese'],
#    'has_api': None,
#    'is_free': 'yes',
#    'requires_registration': 'no',
#    'availability': 'online',
#    'country_ip_address_required': None,
#    'license': 'mit',
#    'spatial_coverage': 'america_sul',
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': None},
#   {'id': '13330fc1-7e8e-4b1c-acd8-b36431c53c8c',
#    'name': 'Como Aplicar para Microdados Identificados',
#    'description': '',
#    'position': 1,
#    'url': 'http://www.saude.gov.br/acesso-a-informacao/servico-de-informacao-ao-cidadao',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2019-10-24T20:18:50.487709',
#    'datastore_active': False,
#    'format': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639175',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'language': ['portuguese'],
#    'has_api': None,
#    'is_free': 'yes',
#    'requires_registration': 'no',
#    'availability': 'online',
#    'country_ip_address_required': None,
#    'license': 'mit',
#    'spatial_coverage': 'america_sul',
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': None},
#   {'id': 'cd656892-c826-48ce-b781-9aa1c81016f7',
#    'name': 'Baixar (Fiocruz)',
#    'description': '',
#    'position': 2,
#    'url': 'https://bigdata-metadados.icict.fiocruz.br/dataset/sistema-de-informacoes-de-mortalidade-sim',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-05-05T17:23:15.354123',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639224',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'language': ['portuguese'],
#    'has_api': None,
#    'is_free': 'yes',
#    'requires_registration': 'no',
#    'availability': 'online',
#    'country_ip_address_required': None,
#    'license': 'mit',
#    'spatial_coverage': 'america_sul',
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': None},
#   {'id': 'db22c1d9-ec31-4c2e-92b9-f6faf839519a',
#    'name': 'dicionario',
#    'description': '',
#    'position': 3,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2021-05-18T06:06:34.858410',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639268',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'dicionario',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '5871b5e5-e1ee-4091-a23e-31c0fcdec19c',
#    'name': 'microdados',
#    'description': '',
#    'position': 4,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-21T17:53:01.252144',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639311',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': '',
#    'resource_type': 'bdm_table',
#    'table_id': 'microdados',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '587132df-9805-4ee9-8ea7-db2081f2e05e',
#    'name': 'municipio',
#    'description': '',
#    'position': 5,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-21T17:53:11.084168',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639353',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': '',
#    'resource_type': 'bdm_table',
#    'table_id': 'municipio',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '03e9a399-f17e-4a63-b44f-264402cb00bc',
#    'name': 'municipio_causa',
#    'description': '',
#    'position': 6,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-21T17:53:19.933268',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639393',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': '',
#    'resource_type': 'bdm_table',
#    'table_id': 'municipio_causa',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': 'c102e36d-9b3a-4def-9935-f58229ab86ae',
#    'name': 'municipio_causa_idade',
#    'description': '',
#    'position': 7,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-11-16T02:03:58.410076',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639433',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'municipio_causa_idade',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '17c28f2e-3d85-4238-b579-225de0d882f7',
#    'name': 'municipio_causa_idade_sexo_raca',
#    'description': '',
#    'position': 8,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-11-16T02:04:03.986753',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T03:31:52.639472',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'fa5975ce-f295-474f-85c4-c5b283afb482',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'municipio_causa_idade_sexo_raca',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': [2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019],
#    'update_frequency': 'one_year',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []}],
#  'groups': [{'id': 'c1990559-75f6-43d0-94f2-8ecfe470b673',
#    'name': 'populacao',
#    'title': 'População',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-060328.174268381c2abde74ad5fb139f94f5347d0fa6.jpg',
#    'created': '2019-09-17T04:57:54.436345',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'População',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-060328.174268381c2abde74ad5fb139f94f5347d0fa6.jpg'},
#   {'id': '8358e722-42fc-408a-8859-084d74da5dd5',
#    'name': 'saude',
#    'title': 'Saúde',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-060434.084225heart-checkup.png',
#    'created': '2019-09-17T04:33:27.710809',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'Saúde',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-060434.084225heart-checkup.png'}],
#  'owner_org': 'e0ebaa47-b9e1-4ef7-9b99-4ac3b6d57345',
#  'organization': {'id': 'e0ebaa47-b9e1-4ef7-9b99-4ac3b6d57345',
#   'name': 'ministerio-da-saude',
#   'title': 'Ministério da Saúde (MS)',
#   'type': 'organization',
#   'description': 'www.saude.gov.br',
#   'image_url': '2019-09-19-062654.732960concurso-ministerio-da-saude-300x291.jpg',
#   'created': '2019-09-19T06:26:54.745120',
#   'is_organization': True,
#   'approval_status': 'approved',
#   'state': 'active'},
#  'num_tags': 1,
#  'tags': [{'id': 'df030c7f-39e4-4099-8d75-f2c7ffd36974',
#    'name': 'mortalidade',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'mortalidade'}],
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'isopen': False}

# %%
[package_path for package_path in Path().glob('packages/*') if 'tse' in package_path.name]
# Out:
# [PosixPath('packages/database-of-accredited-postsecondary-institutions-and-programs-dapip'),
#  PosixPath('packages/br-tse-eleicoes'),
#  PosixPath('packages/integrated-postseondary-education-data-system-ipeds'),
#  PosixPath('packages/br-tse-filiacao-partidaria')]

# %%
for package_path in Path().glob('packages/*'):
    package_update(package_path, False)
# Out:
# packages/letourdataset
# packages/marinetraffic
# packages/covid-19-preprints
# packages/cdc-s-social-vulnerability-index-svi
# packages/world-sea-temperatures
# packages/passageiros-no-titanic
# packages/u-s-survey-of-doctorate-recipients-sdr
# packages/world-atlas-of-language-structures-wals
# packages/nobel-laureates-1901-present
# packages/smithsonian-open-access
# packages/global-carbon-atlas
# packages/occupied-palestinian-territory
# packages/genomic-data-commons-gdc
# packages/the-microbe-directory
# packages/atlas-da-violencia
# packages/macro-financial-dataset
# packages/large-logo-dataset-lld
# packages/uniform-crime-reporting-ucr-program-data-arrests-by-age-sex-and-race
# packages/diario-oficial-do-estado-do-distrito-federal
# packages/pesquisa-de-opiniao-american-trends-panel
# packages/oecd-tax-database
# packages/global-attitudes-on-abortion
# packages/prestadores-de-servicos-turisticos-cadastur
# packages/human-mortality-database-hmd
# packages/territorial-self-governance-dataset-terrgo
# packages/museum-data-files-mdf
# packages/br-anatel-telefonia-movel
# packages/comtrade
# packages/public-utility-data-liberation-project-pudl
# packages/every-politician
# packages/censo-gife
# packages/confronting-the-demographics-of-power-america-s-sheriffs
# packages/quality-of-government-qog
# packages/maddison-project-database-for-historical-development
# packages/dataluta
# packages/usaspending-gov
# packages/missing-migrants-project
# packages/global-open-data-index-godi
# packages/anuario-brasileiro-de-seguranca-publica
# packages/dsny-monthly-tonnage-data
# packages/pinball-map
# packages/diario-oficial-do-estado-do-para
# packages/polls-and-the-timeline-of-elections
# packages/taxa-de-cambio
# packages/nomes-africanos
# packages/caselaw-access-project-cap
# packages/south-african-national-income-dynamics-study-nids
# packages/distribuicao-geografica-do-programa-mais-medicos-pmm
# packages/bb-integra
# packages/acessos-de-telefonia-fixa-no-brasil
# packages/climate-data-record-cdr-of-normalized-difference-vegetation-index-ndvi
# packages/censo-e-pesquisa-nacional-sobre-a-populacao-em-situacao-de-rua
# packages/centros-de-convivencia-de-idosos
# packages/opportunity-atlas
# packages/international-registry-of-seismograph-stations-ir
# packages/diario-oficial-do-estado-do-rio-grande-do-sul
# packages/the-indonesia-family-life-survey-ifls
# packages/allsides-media-bias-chart
# packages/levantamento-nacional-de-informacoes-penitenciarias-infopen
# packages/panel-study-of-income-dynamics-psid
# packages/opentraffic
# packages/police-public-contact-survey-ppcs
# packages/international-social-survey-programme-issp
# packages/simply-scripts
# packages/estatisticas-sobre-microempreendedores-individuais-mei
# packages/painel-correicao-em-dados
# packages/best-hip-hop-songs-of-all-time
# packages/sistema-nacional-de-cadastro-rural-sncr
# packages/saci
# packages/police-use-of-force-project
# packages/br-me-pensionistas
# packages/sipri-military-expenditure-database
# packages/china-s-public-diplomacy-dashboard-dataset
# packages/estatisticas-do-registro-civil
# packages/diretorio-nacional-de-enderecos-dne
# packages/censo-do-sistema-unico-de-assistencia-social-suas
# packages/pesquisa-anual-de-servicos
# packages/climate-policy-database
# packages/gemstat
# packages/economia-informal-urbana
# packages/stayinghome-club
# packages/ucdp-georeferenced-event-dataset-ged-global-version
# packages/the-covid-tracking-project
# packages/estatisticas-do-futebol
# packages/iowa-liquor-sales
# packages/mapa-das-franquias
# packages/open-data-inception
# packages/macimide-global-expatriate-dual-citizenship-dataset
# packages/posse-e-porte-de-arma-de-fogo
# packages/demographic-and-health-surveys-dhs
# packages/archigos
# packages/moderate-resolution-imaging-spectroradiometer-modis
# packages/br-anatel-banda-larga-fixa
# packages/ucs-satellite-database
# packages/ibge-paises
# packages/the-evolution-of-the-american-census
# packages/world-database-on-protected-areas-wdpa
# packages/rois-de-informacoes-desclassificadas
# packages/leis-estaduais
# packages/pesquisa-de-informacoes-basicas-estaduais-estadic
# packages/world-development-indicators
# packages/mapa-de-feiras-organicas
# packages/dominios-gov-br
# packages/sistema-de-informacoes-hospitalares-do-sus-sihsus
# packages/executive-approval-project-eap
# packages/banco-de-dados-da-wikipedia
# packages/bolsa-familia
# packages/living-planet-index-lpi
# packages/taxas-de-letalidade-violenta-por-grandes-regioes-rj
# packages/programa-de-fiscalizacao-em-entes-federativos
# packages/the-largest-known-primes
# packages/international-bathymetric-chart-of-the-arctic-ocean-ibcao
# packages/the-study-of-the-tsunami-aftermath-and-recovery-star
# packages/world-population-prospects-wpp
# packages/influence-watch
# packages/united-states-newspaper-panel-1869-2004
# packages/soccer-match-event-dataset
# packages/favicons
# packages/operacao-serenata-de-amor
# packages/diario-oficial-do-estado-de-roraima
# packages/natural-earth-data
# packages/monitor-de-politicas-de-drogas-nas-americas
# packages/u-s-cancer-statistics-center
# packages/side-effect-resource-sider
# packages/diario-oficial-do-estado-do-amapa
# packages/world-press-freedom-index
# packages/residuos-solidos
# packages/global-human-settlement-ghs-built
# packages/list-of-dirty-naughty-obscene-and-otherwise-bad-words
# packages/pesquisa-de-assistencia-medico-sanitaria-ams
# packages/mapbiomas-alerta
# packages/the-digital-atlas-of-roman-and-medieval-civilizations-darmc
# packages/survey-of-the-incarcerated
# packages/amazonia-minada
# packages/purpleair-real-time-air-quality-monitoring
# packages/indicadores-criminais-de-sp
# packages/nascidos-vivos-com-microcefalia-ou-zika
# packages/russia-longitudinal-monitoring-survey-rlms
# packages/national-crime-victimization-survey-ncvs
# packages/sipri-arms-embargoes
# packages/the-official-register-of-the-united-states-1816-1959
# packages/atlas-de-mortalidade-por-cancer
# packages/acaps-covid-19-government-measures-dataset
# packages/survey-of-earned-doctorates-sed
# packages/manchas-de-oleo-no-litoral-brasileiro
# packages/migracao-internacional
# packages/linchamentos-beck-and-tolnay-1995
# packages/tic-organizacoes-sem-fins-lucrativos
# packages/fire-information-for-resource-management-system-firms
# packages/devedores-da-uniao
# packages/federal-employee-viewpoint-survey-fevs
# packages/journalists-killed
# packages/cadastro-empresas-brasileiras-exportadoras-e-importadoras
# packages/barro-lee-education-attainment-dataset
# packages/colecao-de-cnpjs-e-cpfs-brasileiros
# packages/human-fertility-database-hfd
# packages/authoritarian-ruling-elites-database-ared
# packages/programa-de-analise-de-residuos-de-agrotoxicos-em-alimentos-para
# packages/globalpetrolprices-com
# packages/global-power-plant-database
# packages/oxford-covid-19-government-response-tracker-oxcgrt
# packages/pesquisa-de-opiniao-u-s-politics-policy
# packages/acidentes-de-transito
# packages/diario-oficial-do-estado-de-mato-grosso
# packages/global-health-security-index
# packages/bolsas-e-auxilios-pagos
# packages/conflitos-no-campo
# packages/asian-barometer
# packages/stadiumdb
# packages/indicadores-programa-mais-medicos-pmm
# packages/github-typo-corpus
# packages/anuario-estatistico-de-acidentes-do-trabalho-aeat
# packages/classificacao-de-agrotoxicos-e-cancerigenos-do-iarc
# packages/plano-de-nacional-de-controle-de-residuos-e-contaminantes-pncrc
# packages/whose-heritage-public-symbols-of-the-confederacy
# packages/ranked-vote
# packages/medicare-nursing-home-compare-datasets
# packages/afrobarometer
# packages/comparative-constitutions-project-ccp
# packages/tic-governo-eletronico
# packages/ucdp-onset-dataset
# packages/pesticide-properties-database-ppdb
# packages/desmatamento-global-forest-cover
# packages/epsg-io-coordinate-systems-worldwide
# packages/estatisticas-de-seguranca-por-municipio-rj
# packages/world-giving-index-wgi
# packages/proposicoes-apresentadas-a-camara-dos-deputados
# packages/pollbase
# packages/project-gutenberg
# packages/notificacao-de-casos-de-doenca-pelo-coronavirus-2019-covid-19
# packages/college-scorecard
# packages/shakespeare-and-company-project
# packages/rural-household-multiple-indicator-survey-rhomis
# packages/estrangeiros-resgatados-em-situacao-analoga-a-escravidao
# packages/mobile-coverage-explorer
# packages/matriz-de-dados-do-credito-rural-mdcr
# packages/indicadores-de-qualidade-dos-servicos-de-tv-por-assinatura-stva-no-brasil
# packages/br-inep-censo-escolar
# packages/comprehensive-universe-of-u-s-patents-cusp
# packages/ucdp-prio-armed-conflict-dataset
# packages/estatistica-bancaria
# packages/u-s-prison-system-statistics
# packages/at-the-circulating-library-a-database-of-victorian-fiction-1837-1901
# packages/quick-draw-dataset
# packages/sipri-arms-transfers-database
# packages/diario-oficial-do-estado-do-ceara
# packages/learning-and-educational-achievement-in-punjab-schools-leaps
# packages/aldeias-indigenas-sistema-indigenista-de-informacoes
# packages/correlates-of-war-territorial-change
# packages/terremotos-no-mexico
# packages/world-poverty-clock
# packages/credibly-accused-priests
# packages/database-of-accredited-postsecondary-institutions-and-programs-dapip
# packages/licitacoes-federais
# packages/terrain-ruggedness
# packages/estoque-da-divida-publica-federal
# packages/artigo-19-violacoes-a-liberdade
# packages/brazilian-electoral-panel-studies-beps
# packages/parliamentary-rules-database
# packages/covid-19-community-mobility-reports
# packages/info-gripe
# packages/peacekeeping-troop-and-police-contributions
# packages/u-s-newspaper-navigator
# packages/climate-action-tracker-cat
# packages/worldometer
# packages/coronavirus-impact-dashboard
# packages/bounty-targets-data
# packages/producao-da-extracao-vegetal-e-da-silvicultura-pevs
# packages/a-complete-catalog-of-every-time-someone-cursed-or-bled-out-in-a-quentin-tarantino-movie
# packages/remessas-de-dinheiro-internacionais-remittances
# packages/killed-by-police
# packages/painel-de-obras
# packages/programa-nacional-de-acesso-ao-ensino-tecnico-e-emprego-pronatec
# packages/geothermal-data-repository-gdr
# packages/financial-access-survey-fas
# packages/world-management-survey-wms
# packages/atlas-of-historical-county-boundaries
# packages/lista-de-devedores-da-pgfn
# packages/sistema-de-avaliacao-da-educacao-basica
# packages/the-atlas-of-surveillance
# packages/worldwide-bureaucracy-indicators-wwbi
# packages/infogov
# packages/ucdp-non-state-conflict-dataset
# packages/sustainable-development-goals-sdg
# packages/diario-oficial-do-estado-do-rio-grande-do-norte
# packages/u-s-tv-service-contour-data-points
# packages/certificacao-quilombola
# packages/geocoded-peacekeeping-operations-geo-pko
# packages/carga-horaria-por-docente-sao-paulo
# packages/painel-de-viagens-governo-federal
# packages/indicador-de-diferenca-entre-os-desempenhos-observado-e-esperado
# packages/long-term-productivity-database
# packages/manifesto-project
# packages/contratos-federais
# packages/acessos-dos-servicos-de-tv-por-assinatura-no-brasil
# packages/latin-american-human-mortality-database
# packages/open-data-barometer-odb
# packages/global-georeferenced-database-of-dams-goodd
# packages/the-planetary-exploration-budget-dataset
# packages/cropscape-cropland-data-layer
# packages/england-s-immigrants-1330-1550
# packages/design-of-international-trade-agreements-desta
# packages/social-explorer
# packages/reclamacoes-de-direitos-autorais-em-buscas
# packages/estatisticas-de-seguranca-por-delegacia-de-policia-rj
# packages/u-s-law-enforcement-officers-killed-and-assaulted-leoka
# packages/who-is
# packages/diario-oficial-do-estado-do-maranhao
# packages/tweets-of-congress
# packages/the-metal-archives
# packages/systemic-banking-crises
# packages/base-monetaria-papel-moeda-emitido
# packages/catalogo-de-escolas
# packages/gm-approval-database
# packages/employment-protection-legislation-database-eplex
# packages/peacekeeping-fatalities
# packages/corruption-perceptions-index-cpi
# packages/the-observatory-of-economic-complexity-oec
# packages/dados-da-educacao-brasileira
# packages/rois-de-informacoes-classificadas
# packages/healthmap-novel-coronavirus-covid-19
# packages/human-life-table-database-hld
# packages/mobile-broadband-data-costs
# packages/tv-tropes
# packages/diario-oficial-do-estado-de-sao-paulo
# packages/statoids
# packages/gestao-de-pessoas-executivo-federal-cargo-de-direcao-e-assessoramento-superiores-das
# packages/diario-oficial-do-estado-de-pernambuco
# packages/flights-in-and-out-of-san-francisco-airport
# packages/comprehensive-food-consumption-database
# packages/world-stadiums
# packages/cedulas-falsas-por-ano-e-estado
# packages/galerias-artistas-e-casas-de-leilao-de-arte-no-mundo
# packages/tic-domicilios
# packages/mapping-militants
# packages/global-slavery-index
# packages/world_competitiveness_ranking
# packages/european-union-consolidated-financial-sanctions-list
# packages/tic-educacao
# packages/california-license-plates
# packages/berkeley-earth-air-pollution
# packages/musicbrainz
# packages/analytics-usa-gov
# packages/crime-in-the-u-s
# packages/living-standards-measurement-study-lsms
# packages/penn-world-tables
# packages/painel-lei-de-acesso-a-informacao-lai
# packages/millennium-development-goals-indicators
# packages/fatal-encounters
# packages/registro-de-imoveis-do-brasil
# packages/boletim-epidemiologico-da-secretaria-especial-de-saude-indigena-sesai
# packages/censo-anual-da-igreja-catolica
# packages/ajuda-internacional-usaid
# packages/us-census-microdata
# packages/worldpop
# packages/metmuseum-of-art-open-access-initiative
# packages/estatisticas-sobre-acidentes-de-trabalho
# packages/newspapers-com
# packages/matriz-de-vizinhanca-municipios-brasileiros
# packages/sexual-orientation-laws-in-the-world
# packages/country-reports-on-terrorism
# packages/diario-oficial-do-estado-do-espirito-santo
# packages/indicadores-da-distribuicao-de-energia-eletrica
# packages/global-land-one-km-base-elevation-project-globe
# packages/portal-de-imigracao-laboral
# packages/producao-de-petroleo-e-gas-natural-nacional-dados-historicos
# packages/nascidos-vivos
# packages/u-s-frequently-occurring-surnames
# packages/portal-meu-municipio
# packages/full-emoji-list
# packages/sistema-de-deteccao-de-desmatamentos-em-tempo-real
# packages/ucdp-one-sided-violence-dataset
# packages/personal-characteristics-of-lone-actor-terrorists
# packages/national-elections-across-democracy-and-autocracy
# packages/perfil-dos-municipios-brasileiros
# packages/justica-aberta
# packages/global-transnational-mobility-dataset
# packages/global-preferences-survey-gps
# packages/painel-de-legislacao-ambiental
# packages/diario-oficial-do-estado-de-tocantins
# packages/cockatoo-island-convicts
# packages/diario-oficial-do-estado-do-rio-de-janeiro
# packages/boletim-estatistico-da-previdencia-social-beps
# packages/police-brutality-during-the-2020-george-floyd-protests
# packages/current-population-survey-cps
# packages/police-scorecard-project
# packages/exame-nacional-do-ensino-medio
# packages/a-tracker-of-trackers-covid-19-policy-responses-and-data
# packages/quantidade-de-infracoes-de-transito
# packages/sistema-de-licenciamento-ambiental-sislic
# packages/gestao-de-pessoas-executivo-federal-aposentados
# packages/observatorio-de-migracoes-forcadas
# packages/perfil-parlamentar
# packages/ceps-eurlex
# packages/trans-atlantic-slave-trade-database
# packages/programme-for-international-student-assessment
# packages/worldwide-mobile-data-pricing
# packages/dying-inside-jail-deaths-in-america
# packages/emendas-parlamentares
# packages/pantheon
# packages/nighttime-lights
# packages/indice-de-competitividade-em-turismo
# packages/leader-statement-database
# packages/tic-saude
# packages/medicare-physician-compare-datasets
# packages/ucdp-dyadic-dataset
# packages/citybikes
# packages/mass-mobilization-project-mm
# packages/mapas-da-infraestrutura
# packages/tracking-government-responses-towards-covid-19
# packages/social-connectedness-index-facebook-sci
# packages/immunization-vaccines-and-biologicals
# packages/where-s-george
# packages/young-lives
# packages/nih-open-citation-collection
# packages/salud-bienestar-y-envejeveimiento-en-america-latina-y-el-caribe-sabe
# packages/stop-question-and-frisk-data
# packages/data-on-covid-19-maintained-by-our-world-in-data
# packages/receitas-e-despesas-dos-municipios-de-sao-paulo
# packages/world-uncertainty-index-wui
# packages/precos-medicamentos-consumidor
# packages/congressional-record-for-the-43rd-114th-congresses-parsed-speeches-and-phrase-counts
# packages/u-n-treaty-collection
# packages/cadastro-nacional-de-florestas-publicas-cnfp
# packages/new-york-philharmonic-performance-history
# packages/global-atlas-for-renewable-energy
# packages/the-longevity-of-famous-people-from-hammurabi-to-einstein
# packages/world-higher-education-database-whed
# packages/united-nations-general-assembly-voting-data
# packages/participacoes-governamentais-royalties-de-petroleo-e-gas-natural
# packages/observatorio-de-homicidios
# packages/incendios-em-unidades-de-conservacao-federais
# packages/nih-chest-x-rays
# packages/human-development-reports
# packages/h1b-salary-database
# packages/u-s-protests-since-2017
# packages/integrated-postseondary-education-data-system-ipeds
# packages/world-happiness-report
# packages/the-triumph-of-injustice
# packages/poki-a-large-dataset-of-poems-by-children
# packages/cadastro-ambiental-rural
# packages/balanca-comercial-brasileira
# packages/inside-airbnb
# packages/quantidade-de-armas-de-fogo-destruidas-pelo-exercito
# packages/leiden-ranking
# packages/u-s-fm-service-contour-data-points
# packages/nature-phd-students-survey-data
# packages/electronic-army-serial-number-merged-file-ca-1938-1946
# packages/exame-nacional-de-desempenho-dos-estudantes
# packages/comparative-competition-law
# packages/frentes-parlamentares
# packages/world-air-quality-index
# packages/u-s-crime-data-explorer-cde
# packages/fastercures-covid-19
# packages/data-informasi-bencana-indonesia-dibi
# packages/faostat-land-use
# packages/mapa-das-organizacoes-da-sociedade-civil
# packages/pew-survey-of-u-s-muslims
# packages/historical-empires
# packages/bolsa-verde
# packages/cadastro-unico
# packages/the-specter-of-chemical-weapons-use-in-syria
# packages/caucasus-barometer
# packages/foreign-terrorist-organizations
# packages/coronavirus-2019-ncov-global-cases
# packages/mexican-migration-project-mmp
# packages/armas-municoes-e-equipamentos-desviados
# packages/sistema-de-registro-nacional-de-emissoes-sirene
# packages/world-digital-library-wdl
# packages/arxiv-open-archives
# packages/global-party-survey-gps
# packages/ucdp-peace-agreement-dataset
# packages/importacoes-e-exportacoes-de-petroleo
# packages/diario-oficial-do-estado-do-piaui
# packages/centennial-earthquake-catalog
# packages/anuario-estatistico-da-antaq
# packages/tweets-de-donald-trump-atacando-a-imprensa
# packages/dartmouth-flood-observatory
# packages/banco-de-dados-de-queimadas
# packages/kaokore-a-pre-modern-japanese-art-facial-expression-dataset
# packages/the-oldest-company-in-almost-every-country
# packages/covid-19-economic-stimulus-index
# packages/dados-do-conflito-no-west-bank-em-israel
# packages/sketchgraphs-a-large-scale-dataset-for-modeling-relational-geometry-in-computer-aided-design
# packages/ranking-de-transparencia-no-combate-a-covid-19
# packages/houston-police-department-shootings
# packages/official-document-system-of-the-united-nations
# packages/mapa-das-ongs-no-brasil
# packages/directions-of-trade-statistics-dots
# packages/proyecto-inventario-de-cuba
# packages/vanderbilt-television-news-archive
# packages/u-s-federal-sentencing
# packages/future-hydropower-reservoirs-and-dams-database-fhred
# packages/climate-change-in-the-contiguous-united-states
# packages/integrated-crisis-early-warning-system-icews
# packages/socioeconomic-high-resolution-rural-urban-geographic-platform-for-india-shrug
# packages/icij-offshore-leaks-database
# packages/banco-de-dados-geodesicos-bdg
# packages/quem-eram-os-papas
# packages/portal-da-transparencia-do-registro-civil
# packages/the-international-disaster-database-em-dat
# packages/crises-fiscais
# packages/br-senado-cpipandemia
# packages/pesquisa-de-orcamentos-familiares
# packages/oecd-revenue-statistics-in-latin-america-and-the-caribbean
# packages/leis-municipais
# packages/centennia-historical-atlas
# packages/tax-introduction-database-tid
# packages/democracy-index
# packages/u-s-survey-of-income-and-program-participation-sipp
# packages/arrecadacao-emissao-de-vistos-entre-2010-e-2019-por-posto
# packages/the-health-inequality-project
# packages/global-solar-atlas
# packages/ipu-parline
# packages/the-malaysian-family-life-surveys-mfls
# packages/fire-spotlight-database
# packages/international-banking-statistics-ibs
# packages/mprjmais
# packages/aiddata-s-geocoded-global-chinese-official-finance
# packages/peacekeeping-master-open-datasets
# packages/beneficios-do-instituto-nacional-de-seguro-social-inss
# packages/leg-go
# packages/interactive-terminology-for-europe-iate
# packages/produto-interno-bruto-pib
# packages/election-betting-odds
# packages/crowd-sourced-covid-19-dataset-tracking-involuntary-government-restrictions-tigr
# packages/capacidade-de-pagamento-capag-de-estados-e-municipios
# packages/censo-do-poder-judiciario
# packages/feminicidio-por-delegacia-de-policia-rj
# packages/historia-de-tentativas-de-assassinato-politico-1875-2004
# packages/ageguess
# packages/shuttle-radar-topography-mission-srtm
# packages/marine-and-hydrokinetic-data-repository-mhk
# packages/census-of-fatal-occupational-injuries-cfoi
# packages/ucdp-georeferenced-event-dataset-ged-polygons
# packages/world-values-survey
# packages/mapas-multimodais
# packages/fivethirtyeight-s-pollster-ratings
# packages/indonesia-database-for-policy-and-economic-research-indo-dapoer
# packages/br-ibge-inflacao
# packages/what-do-philosophers-believe
# packages/european-settlement-map-esm
# packages/community-earth-system-model-cesm
# packages/light-pollution-map
# packages/trump-twitter-archive
# packages/pesquisa-nacional-de-saude
# packages/atlas-etnografico
# packages/pesquisa-de-opiniao-hispanic-trends
# packages/censo-de-poblacion-y-vivienda-cpv
# packages/modern-era-retrospective-analysis-for-research-and-applications-merra
# packages/the-comprehensive-bigfoot-sightings-database
# packages/imagenet
# packages/a-shell-dataset-for-shell-features-extraction-and-recognition
# packages/informacoes-indigenas
# packages/global-terrorism-database-gtd
# packages/diversifying-economics-seminars-speakers-list
# packages/political-terror-scale-pts
# packages/pesquisa-anual-de-comercio
# packages/socio-economic-database-for-latin-america-and-the-caribbean-sedlac
# packages/solicitacoes-de-reconhecimento-da-condicao-de-refugiado
# packages/diario-oficial-do-estado-da-paraiba
# packages/oasis-brains-project
# packages/culture-under-threat-map
# packages/mapa-do-turismo-brasileiro
# packages/eventos-turisticos
# packages/u-s-national-park-trails
# packages/imoveis-da-uniao
# packages/despesas-pela-cota-para-exercicio-da-atividade-parlamentar
# packages/diario-oficial-do-estado-do-amazonas
# packages/open-corporates
# packages/geopresidios-radiografia-do-sistema-prisional
# packages/unidades-de-conservacao-painel-dinamico-de-informacoes-gerenciais
# packages/diario-oficial-do-estado-de-rondonia
# packages/bible-api-com
# packages/flightradar24
# packages/native-bee-inventory-and-monitoring-program
# packages/covid-19-nas-favelas-do-rio-de-janeiro
# packages/u-s-campaign-finance-data
# packages/salarios-dos-magistrados-no-brasil
# packages/transferencias-a-estados-e-municipios
# packages/salario-minimo
# packages/american-national-election-studies-anes
# packages/national-health-security-preparedness-index-nhspi
# packages/eurobarometer
# packages/diario-oficial-do-estado-de-goias
# packages/gestao-de-pessoas-executivo-federal-pensionistas
# packages/indicadores-de-qualidade-do-servico-de-telefonia-fixa-stfc-no-brasil
# packages/migraciones-interiores-y-exteriores-de-espana
# packages/world-input-output-database-wiod
# packages/rand-database-of-worldwide-terrorism-incidents-rdwti
# packages/report-of-the-committee-on-the-status-of-minority-groups-in-the-economics-profession-csmgep
# packages/mapping-the-gay-guides-mgg
# packages/u-s-census-linking-project
# packages/fluxos-de-comercio-em-agropecuaria
# packages/baci
# packages/encyclopaedia-britannica-1768-1860
# packages/imdb-datasets
# packages/research-for-effective-covid-19-response-recovr
# packages/general-social-survey
# packages/pesquisa-de-opiniao-journalism-and-media
# packages/visible-infrared-imaging-radiometer-suite-viirs
# packages/alistados-no-servico-militar
# packages/taxa-selic
# packages/u-s-women-elected-officials
# packages/indice-de-progresso-social-na-amazonia-brasileira
# packages/pesquisa-de-opiniao-global-attitudes-and-trends
# packages/covid-19-no-brasil-io
# packages/api-of-ice-and-fire
# packages/the-global-dataset-of-historical-yields-for-major-crops-1981-2016
# packages/feminicidio-sp
# packages/mapping-police-violence
# packages/microsoft-academic-graph-mag
# packages/pan-pesticide-database
# packages/documento-de-origem-florestal-dof
# packages/poll-of-polls
# packages/geographically-based-economic-data-g-econ
# packages/govinfo
# packages/u-k-inspire-index-polygons-spatial-data
# packages/regulacao-de-atividades-moralmente-controversas
# packages/nba-basketball-stats
# packages/mundo-kaggle-olimpiadas
# packages/earthstat
# packages/painel-dinamico-da-fiscalizacao-do-abastecimento
# packages/br-rj-rio-de-janeiro-ipp-ips
# packages/armas-apreendidas-por-delegacia-de-policia-rj
# packages/ucdp-georeferenced-event-dataset-ged-syria
# packages/censo-da-educacao-superior
# packages/cross-national-time-series-cnts-data-archive
# packages/terraclass
# packages/autuacoes-ambientais-e-embargos
# packages/eva-evidencias-sobre-violencias-e-alternativas-para-mulheres-e-meninas
# packages/covid-19-mobility-trends-reports
# packages/glad-alerts-footprint
# packages/diario-oficial-do-estado-do-acre
# packages/tree-biomass-loss
# packages/chicago-citizens-police-data-project-cpdp-co
# packages/banco-nacional-de-monitoramento-de-prisoes-bnmp
# packages/agrolink-fito
# packages/perfil-politico
# packages/the-national-registry-of-exonerations
# packages/u-s-board-on-geographic-names
# packages/the-condemned
# packages/codigos-dos-municipios-ibge
# packages/correlates-of-war-war-data
# packages/mapping-application-for-penguin-populations-and-projected-dynamics-mapppd
# packages/sistema-integrado-de-gestao-de-barragens-de-mineracao-sigbm
# packages/latinobarometro
# packages/radio-locator
# packages/lista-de-cartorios
# packages/breaking-trust-software-supply-chain-attacks
# packages/dados-abertos-do-condado-de-suffolk-nova-york
# packages/sistema-nacional-de-informacoes-sobre-saneamento-snis
# packages/whogov
# packages/global-human-settlement-population-ghs-pop
# packages/convenios
# packages/atlas-da-noticia
# packages/global-debt-database-gdd
# packages/u-s-census-of-governments
# packages/global-wind-atlas
# packages/sistema-de-informacoes-sobre-orcamentos-publicos-em-saude-siops
# packages/painel-de-obras-paralisadas-ou-atrasadas-sao-paulo
# packages/seattle-book-checkouts-by-title
# packages/sistema-nacional-de-viacao
# packages/global-carbon-budget
# packages/catalogue-of-bias
# packages/quarterly-census-of-employment-and-wages-qcew
# packages/covid-19-data-resources-for-india
# packages/american-time-use-survey-atus
# packages/cidades-dos-eua
# packages/u-s-political-polls
# packages/atlas-do-estado-brasileiro
# packages/british-social-attitudes-bsa
# packages/million-song-dataset
# packages/world-urbanization-prospects-wup
# packages/university-of-california-cliometric-history-project-uc-chp
# packages/average-happiness-for-twitter
# packages/programa-universidade-para-todos-prouni
# packages/diario-oficial-do-estado-de-sergipe
# packages/anuario-estatistico-da-previdencia-social-aeps
# packages/perfil-das-unidades-do-instituto-nacional-de-seguro-social-inss
# packages/consumer-expenditure-surveys-ce
# packages/pesquisa-de-entidades-de-assistencia-social-privadas-sem-fins-lucrativos-peas
# packages/gridded-5km-ghcn-daily-temperature-and-precipitation-dataset-nclimgrid
# packages/justica-em-numeros
# packages/global-observatory-for-physical-activity-country-cards
# packages/american-cabinet-appointments
# packages/open-states
# packages/varieties-of-democracy-v-dem
# packages/painel-de-indicadores-da-confederacao-nacional-de-reservas-particulares-do-patrimonio-natural-cnrppn
# packages/terras-indigenas-sistema-indigenista-de-informacoes
# packages/meteoritical-bulletin-database
# packages/economic-policy-uncertainty-epu
# packages/gridded-population-of-the-world-gpw
# packages/global-corruption-barometer-gcb
# packages/senadores-legislativo
# packages/classificacao-de-genero-em-nomes-brasileiros
# packages/international-survey-on-coronavirus
# packages/u-s-nonprofit-explorer
# packages/u-s-police-shootings-database
# packages/indenizacoes-dos-beneficiados-pela-lei-10-559-2002-anistiados-do-ministerio-da-defesa
# packages/pesquisa-de-opiniao-publica-nacional-aborto-junho-2019
# packages/freedom-of-information-act-annual-reports-1975-2018
# packages/tic-kids-online
# packages/roller-coaster-database-rcdb
# packages/eopp-indian-states-data
# packages/darknet-market-mortality-risks
# packages/listagem-dos-organismos-de-avaliacao-da-conformidade-organica-oac
# packages/corelogic-housing-data
# packages/wikiart
# packages/tic-empresas
# packages/lista-de-dominios-fr
# packages/fire-disinvitation-database
# packages/doacoes-de-campanha
# packages/spotify-charts
# packages/estatisticas-sobre-simples-nacional
# packages/novel-coronavirus-covid-19-situation
# packages/historico-de-matriculas-por-turma-sao-paulo
# packages/world-fertility-surveys-wfs
# packages/sistema-nacional-de-informacoes-toxico-farmacologicas-sinitox
# packages/standardized-world-income-inequality-database-swiid
# packages/native-land-ca
# packages/antarctic-iceberg-tracking-database
# packages/covid-19-outbreak-panel
# packages/kworb-net
# packages/climate-divisional-database-nclimdiv
# packages/oecd-income-distribution-database-idd
# packages/tenders-electronic-daily-ted-public-procurement-notices-from-the-eu
# packages/servico-militar-obrigatorio
# packages/orbis-amadeus
# packages/indicadores-sociais-minimos
# packages/sistema-de-informacao-de-agravos-de-notificacao-sinan
# packages/eventos-da-camara-lista-orgaos-realizadores-deputados-presentes
# packages/painel-de-raio-x-da-administracao-publica-federal
# packages/casos-de-covid-19-no-brasil
# packages/censo-dos-profissionais-do-magisterio
# packages/u-s-historical-debt-outstanding
# packages/medicare-hospital-compare-datasets
# packages/historical-light-aids-to-navigation-1514-1911
# packages/internet-archive
# packages/comparative-income-taxation-database-citd
# packages/diario-oficial-do-estado-da-bahia
# packages/ranking-da-transparencia-do-poder-judiciario
# packages/pesquisa-anual-da-industria-da-construcao-paic
# packages/national-solar-radiation-database-nsrdb
# packages/malha-municipal
# packages/painel-monitoramento-de-dados-abertos
# packages/party-facts
# packages/qualis-periodicos
# packages/uber-movement
# packages/autocratic-ruling-parties-dataset-arpd
# packages/empreendimentos-turisticos-acessiveis
# packages/doing-business
# packages/cadastro-nacional-de-estabelecimentos-de-saude-cnes
# packages/china-statistical-yearbook
# packages/mexican-health-and-aging-study-mhas
# packages/collective-actions-in-tech
# packages/electoral-contention-and-violence-ecav
# packages/integrated-civil-society-organizations-system-icso
# packages/pesquisa-de-opiniao-internet-and-technology
# packages/basketball-reference
# packages/discursos-membros-do-banco-central-europeu
# packages/pesquisa-internacional-sobre-ensino-e-aprendizagem
# packages/board-game-geek-bgg
# packages/women-in-parliament
# packages/u-s-covid-19-economic-tracker
# packages/propaganda-na-alemanha-nazista
# packages/campus-expression-survey-ces
# packages/social-conflict-analysis-database-scad
# packages/censo-agropecuario
# packages/lobbyfacts-eu
# packages/senadores-administrativo
# packages/complaints-against-new-york-police-department-officers
# packages/policy-responses-to-covid-19
# packages/estatisticas-de-comercio-exterior-do-agronegocio-brasileiro-agrostat
# packages/cartografia-dos-ataques-contra-indigenas-caci
# packages/environmental-performance-index-epi
# packages/plataforma-cidades-frageis
# packages/estatisticas-da-previdencia-social-por-municipio
# packages/contratacoes-do-senado-federal
# packages/africa-integrity-indicators
# packages/indice-nacional-de-precos-ao-consumidor-amplo-ipca
# packages/intra-american-slave-trade-database
# packages/vessel-finder
# packages/indicadores-de-qualidade-do-servico-de-telefonia-movel-smp-no-brasil
# packages/u-s-support-for-black-lives-matter
# packages/member-states-of-the-united-nations
# packages/exposure-indices-derived-from-placeiq-movement-data
# packages/wilderness-net
# packages/world-war-i-document-archive
# packages/european-population-demography-population-projections-census-asylum-and-migration
# packages/the-geographic-diversity-project
# packages/china-biographical-database-project-cbdb
# packages/armed-conflict-location-event-data-acled
# packages/lobbyview
# packages/diario-oficial-do-estado-do-mato-grosso-do-sul
# packages/pesquisa-de-opiniao-religion-and-public-life
# packages/projeto-tracksource
# packages/cidades-do-mundo
# packages/agrofit
# packages/pesquisa-de-opiniao-social-and-demographic-trends
# packages/ucdp-battle-related-deaths-dataset
# packages/hate-crime-in-the-u-s
# packages/estatisticas-futebol-brasileiro
# packages/diario-oficial-do-estado-de-alagoas
# packages/global-reservoir-and-dam-database-grand
# packages/crimes-against-humanity-in-punjab-india
# packages/achados-e-pedidos
# packages/the-international-political-economy-ipe-data-resource
# packages/censo-legislativo
# packages/avaliacao-nacional-da-alfabetizacao
# packages/americasbarometer
# packages/observing-systems-capability-analysis-and-review-oscar
# packages/covid-19-open-research-dataset-cord-19
# packages/u-s-press-freedom-tracker
# packages/diario-oficial-do-estado-do-parana
# packages/diario-oficial-do-estado-de-santa-catarina
# packages/monroe-work-today
# packages/stack-overflow-annual-developer-survey
# packages/berkeley-earth-surface-temperature
# packages/discogs
# packages/climate-hazards-center-chc
# packages/tesco-grocery
# packages/atlas-of-the-human-planet
# packages/banco-de-dados-meteorologicos-bdmep
# packages/diario-oficial-do-estado-de-minas-gerais
# packages/dados-estatisticos-da-anac
# packages/townsend-thai-project
# packages/u-s-monthly-retail-trade
# packages/global-visa-cost-dataset
# packages/arab-barometer
# packages/central-database-of-shoah-victims-names
# packages/database-of-british-and-irish-hills-dobih
# packages/chegada-de-turistas-internacionais
# packages/govtrack-us-tracking-the-u-s-congress
# packages/mapa-mundo-paises
# packages/parameter-elevation-regressions-on-independent-slopes-model-prism-climate-group
# packages/public-libraries-survey-pls
# packages/recenseamento-geral-do-imperio-do-brasil-de-1872
# packages/international-environmental-agreements-iea-database-project
# packages/radar-legislativo
# packages/exame-nacional-para-certificacao-de-competencias-de-jovens-e-adultos
# packages/the-big-mac-index
# packages/artificial-intelligence-index-report
# packages/world-governance-indicators
# packages/museus-br
# packages/latin-american-migration-project-lamp
# packages/global-administrative-unit-layers-gaul
# packages/u-s-debt-to-the-penny
# packages/utility-rate-database-urdb
# packages/classificacao-brasileira-de-ocupacoes-cbo
# packages/parliamentary-elections
# packages/fatality-analysis-reporting-system-fars
# packages/central-european-art-database-cead
# packages/pesquisa-industrial-anual
# packages/cadastro-nacional-de-produtores-organicos
# packages/indicadores-de-qualidade-da-banda-larga-fixa-scm-no-brasil
# packages/storm-events-database
# packages/global-development-network-growth-database-gdngd
# packages/pesquisa-de-opiniao-science-and-society
# packages/the-market-for-data-privacy-data-and-code
# packages/global-competitiveness-report-gcr
# packages/global-terrorism-index
# packages/the-xinjiang-data-project
# packages/new-york-city-sidewalks
# packages/global-human-settlement-model-ghs-smod
# packages/india-human-development-survey-ihds
# packages/usda-national-forest-type-dataset
# packages/arquivo-do-gabriel-garcia-marquez
# packages/pesquisa-nacional-por-amostra-de-domicilios-pnad
# packages/domains-project
# packages/repositorio-de-eleicoes-na-india
# packages/quantidade-de-novos-registros-de-armas-de-fogo-para-colecionadores
# packages/pesquisa-mensal-de-empregos-pme
# packages/ipardes-base-de-dados-do-estado-bdeweb
# packages/census-transportation-planning-products-ctpp
# packages/projetos-e-materias-do-senado-federal-legislativo
# packages/pesquisa-de-inovacao
# packages/gestao-de-pessoas-do-senado-federal-administrativo
# packages/police-union-contract-project
# packages/tools-for-harmonizing-u-s-county-boundaries
# packages/banco-de-pesquisas-de-opiniao-publica
# packages/base-de-dados-de-seguranca-cidada
# packages/south-asia-terrorism-portal
# packages/despesas-publicas
# packages/precos-agropecuarios-parana
# packages/elas-no-congresso
# packages/indonesia-administrative-level-0-4-boundaries
# packages/parlspeech
# packages/codigos-nacionais-ddd
# packages/contratos-de-marketing-e-publicidade-em-turismo
# packages/polity-iv

# %%
for package_path in Path().glob('packages/*'):
    package = json.load(open(package_path))
    migrated = migrate(package)
    res = validate(migrated)
    if res:
        print('-------' * 10)
        print(package_path.name)
#         print(package)
#         print(migrated)
        print(res)

# %%
basedosdados.action.package_update(**migrated)
# Out:
# {'id': '91292202-7188-4df1-a74d-e899e8fa824b',
#  'name': 'br-tse-eleicoes',
#  'title': 'Eleições Brasileiras',
#  'type': 'dataset',
#  'notes': 'Dados de eleições brasileiras desde 1945 fornecidos pelo TSE. Inclui dados de eleitorado, candidaturas, resultados e prestação de contas.',
#  'author': None,
#  'author_email': None,
#  'maintainer': None,
#  'maintainer_email': None,
#  'state': 'active',
#  'license_id': '',
#  'url': None,
#  'version': None,
#  'metadata_created': '2019-09-17T16:59:07.230588',
#  'metadata_modified': '2021-07-29T01:43:40.745271',
#  'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc',
#  'private': False,
#  'license_title': '',
#  'num_resources': 19,
#  'resources': [{'id': '2db55974-351d-4c6d-a20c-ced47bf3e7b7',
#    'name': 'Baixar',
#    'description': '',
#    'position': 0,
#    'url': 'http://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2019-09-17T16:59:23.688867',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.774944',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'language': ['portuguese'],
#    'has_api': None,
#    'is_free': 'yes',
#    'requires_registration': 'no',
#    'availability': 'online',
#    'country_ip_address_required': None,
#    'license': 'mit',
#    'spatial_coverage': 'america_sul',
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': None},
#   {'id': '6bcba81a-4924-4f72-a52d-486ab7abb920',
#    'name': 'bens_candidato',
#    'description': '',
#    'position': 1,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-12-23T20:02:28.351909',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775044',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'bens_candidato',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '7c47f0e4-c8ef-46fe-a61d-9179e5adab64',
#    'name': 'candidatos',
#    'description': '',
#    'position': 2,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:34:23.487064',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775098',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': '',
#    'resource_type': 'bdm_table',
#    'table_id': 'candidatos',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '7102ccb6-e9b9-4111-b46c-918e5852bcad',
#    'name': 'despesas_candidato',
#    'description': '',
#    'position': 3,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2021-02-16T05:50:16.381402',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775147',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'despesas_candidato',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '5b862e2b-bfca-44a0-850a-7d80a5d2f86e',
#    'name': 'detalhes_votacao_municipio',
#    'description': '',
#    'position': 4,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:35:29.014824',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775194',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'detalhes_votacao_municipio',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '605985e7-3c26-4ec0-8686-6fdb831c8069',
#    'name': 'detalhes_votacao_municipio_zona',
#    'description': '',
#    'position': 5,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:35:44.719545',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775242',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'detalhes_votacao_municipio_zona',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': 'eba1e4ef-1de3-4f1b-9b76-2c02d58ed7b0',
#    'name': 'detalhes_votacao_secao',
#    'description': '',
#    'position': 6,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:35:55.555093',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775288',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'detalhes_votacao_secao',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': 'be0fe762-ff81-45e1-9c38-18ee7d960e84',
#    'name': 'local_secao',
#    'description': '',
#    'position': 7,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-27T16:48:37.163692',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775336',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'local_secao',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '3b1bbc60-7ab5-41aa-8984-de012ed94879',
#    'name': 'partidos',
#    'description': '',
#    'position': 8,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:35:07.826353',
#    'datastore_active': False,
#    'format': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775386',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'dataset_id': '',
#    'table_id': 'partidos',
#    'spatial_coverage': {'continent': None},
#    'entity': None,
#    'version': '',
#    'published_by': {'name': '', 'email': '', 'github_user': '', 'website': ''},
#    'data_cleaned_by': {'name': '',
#     'email': '',
#     'github_user': None,
#     'website': '',
#     'code_url': ''},
#    'data_cleaning_description': '',
#    'auxiliary_files_url': '',
#    'source_bucket_name': '',
#    'project_id_prod': '',
#    'project_id_staging': '',
#    'partitions': '',
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': 'c86fe51c-e5f8-4085-bb1c-1d42f0c4c3a6',
#    'name': 'perfil_eleitorado_municipio_zona',
#    'description': '',
#    'position': 9,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-11-25T07:52:38.339985',
#    'datastore_active': False,
#    'format': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775436',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'dataset_id': '',
#    'table_id': 'perfil_eleitorado_municipio_zona',
#    'spatial_coverage': {'continent': None},
#    'entity': None,
#    'version': '',
#    'published_by': {'name': '', 'email': '', 'github_user': '', 'website': ''},
#    'data_cleaned_by': {'name': '',
#     'email': '',
#     'github_user': None,
#     'website': '',
#     'code_url': ''},
#    'data_cleaning_description': '',
#    'auxiliary_files_url': '',
#    'source_bucket_name': '',
#    'project_id_prod': '',
#    'project_id_staging': '',
#    'partitions': '',
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '56a24a77-97ca-4930-8411-6c69bd9f5c9d',
#    'name': 'receitas_candidato',
#    'description': '',
#    'position': 10,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2021-02-16T05:50:08.310876',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775483',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'receitas_candidato',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'columns': []},
#   {'id': 'fec5bed5-cca5-427d-86e6-d5560a3d1719',
#    'name': 'resultados_candidato',
#    'description': '',
#    'position': 11,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-11-25T07:52:53.174762',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775527',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'resultados_candidato',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': 'ce486727-7fd2-4f17-82a4-805111d1f765',
#    'name': 'resultados_candidato_municipio',
#    'description': '',
#    'position': 12,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:36:17.251967',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775571',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'resultados_candidato_municipio',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '447da515-0b8c-4930-a728-e73e9cb49181',
#    'name': 'resultados_candidato_municipio_zona',
#    'description': '',
#    'position': 13,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:36:28.088927',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775615',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'resultados_candidato_municipio_zona',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': '3d035a95-8f93-4838-a2c1-61f928a0fd47',
#    'name': 'resultados_candidato_secao',
#    'description': '',
#    'position': 14,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:36:37.944791',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775659',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'resultados_candidato_secao',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'columns': []},
#   {'id': 'fa47f0ef-580b-4722-a991-f35bdf0f5f03',
#    'name': 'resultados_partido_municipio',
#    'description': '',
#    'position': 15,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:37:10.572367',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775703',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'resultados_partido_municipio',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []},
#   {'id': 'ecaeacce-f9e5-430c-afb9-47fd4f0593cf',
#    'name': 'resultados_partido_municipio_zona',
#    'description': '',
#    'position': 16,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:37:20.315535',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775748',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'resultados_partido_municipio_zona',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'columns': []},
#   {'id': 'e2a80dce-e508-48a1-a5f0-199dccff3586',
#    'name': 'resultados_partido_secao',
#    'description': '',
#    'position': 17,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:37:33.898251',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775793',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'resultados_partido_secao',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'columns': []},
#   {'id': '419afca0-42ca-45eb-a214-3272439382f6',
#    'name': 'vagas',
#    'description': '',
#    'position': 18,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-10-13T18:34:46.045371',
#    'datastore_active': False,
#    'format': '',
#    'formato': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2021-07-29T01:43:40.775838',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': '91292202-7188-4df1-a74d-e899e8fa824b',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'table_id': 'vagas',
#    'spatial_coverage': {'continent': ['south_america']},
#    'temporal_coverage': ['CHECK',
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020],
#    'update_frequency': 'two_years',
#    'entity': None,
#    'version': '',
#    'published_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None},
#    'data_cleaned_by': {'name': None,
#     'email': None,
#     'github_user': None,
#     'website': None,
#     'code_url': None},
#    'data_cleaning_description': None,
#    'bdm_file_size': None,
#    'columns': []}],
#  'groups': [{'id': 'e5d6e7cd-f1b0-4160-bbba-86cc55b818d5',
#    'name': 'politica',
#    'title': 'Política',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-060252.188862politica.jpg',
#    'created': '2019-09-17T04:57:32.417077',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'Política',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-060252.188862politica.jpg'}],
#  'owner_org': 'f7e4fcbe-a6a1-44fe-a4bb-2c019d00c8dd',
#  'organization': {'id': 'f7e4fcbe-a6a1-44fe-a4bb-2c019d00c8dd',
#   'name': 'tribunal-superior-eleitoral',
#   'title': 'Tribunal Superior Eleitoral (TSE)',
#   'type': 'organization',
#   'description': 'www.tse.jus.br',
#   'image_url': '2019-09-19-153219.063382tse-logo-1.png',
#   'created': '2019-09-17T05:04:36.403602',
#   'is_organization': True,
#   'approval_status': 'approved',
#   'state': 'active'},
#  'num_tags': 5,
#  'tags': [{'id': '8c8a3100-c02e-43fc-89c8-216af9883619',
#    'name': 'congresso',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'congresso'},
#   {'id': '3eed8069-7c49-43f0-a39f-a20e8d26f2cc',
#    'name': 'eleicao',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'eleicao'},
#   {'id': '45211e84-94f1-4bb6-b275-edcdfbb5e278',
#    'name': 'partido',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'partido'},
#   {'id': '40ec2668-e4d2-444e-ae86-a629ec9f429e',
#    'name': 'presidencia',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'presidencia'},
#   {'id': '22f17f8f-ae62-41de-a4dd-3c82a3a5a742',
#    'name': 'voto',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'voto'}],
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'isopen': False,
#  'extras': []}

# %%
# migrated_list = []

# %%
for m in migrated_list:
    packages.remove(m)

# %%
content
# Out:
# {'id': 'acd27881-6e01-4aa6-bc20-75dd0926b0d5',
#  'name': 'worldwide-mobile-data-pricing',
#  'title': 'Worldwide Mobile Data Pricing',
#  'type': 'dataset',
#  'notes': 'Dados de 5.554 planos de dados móveis em 228 países foram coletados e analisados por Cable.co.uk entre 3 de fevereiro e 25 de fevereiro de 2020. O custo médio de um gigabyte (1 GB) foi então calculado e comparado para formar uma tabela mundial de preços de dados móveis .\r\n\r\nAo contrário de nossas medições de velocidade de banda larga em todo o mundo e preços de banda larga em todo o mundo, onde a falta de infraestrutura de linha fixa significava lacunas significativas, o fornecimento de dados móveis é quase onipresente. No entanto, ainda existem alguns países ou territórios onde não existe oferta, existe apenas infraestrutura 2G, disponibilizando apenas chamadas e / ou SMS, ou os dados simplesmente não estão disponíveis. E há países e regiões onde os problemas com a moeda não permitem uma comparação útil.',
#  'author': None,
#  'author_email': None,
#  'maintainer': None,
#  'maintainer_email': None,
#  'state': 'active',
#  'license_id': None,
#  'url': 'https://www.cable.co.uk/mobiles/worldwide-data-pricing/',
#  'version': None,
#  'metadata_created': '2020-08-25T22:43:00.562507',
#  'metadata_modified': '2020-08-25T22:44:02.243764',
#  'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc',
#  'private': False,
#  'license_title': None,
#  'num_resources': 1,
#  'resources': [{'availability': 'online',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2020-08-25T22:43:46.216591',
#    'datastore_active': False,
#    'description': '',
#    'format': '',
#    'formato': '',
#    'has_api': None,
#    'hash': '',
#    'id': '9fb68e59-59a0-4e42-b9a6-67208075286d',
#    'language': ['english'],
#    'last_modified': None,
#    'metadata_modified': '2020-08-25T22:43:46.216591',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'name': 'Visualizar e Baixar',
#    'package_id': 'acd27881-6e01-4aa6-bc20-75dd0926b0d5',
#    'position': 0,
#    'resource_type': 'external_link',
#    'size': None,
#    'spatial_coverage': 'internacional',
#    'state': 'active',
#    'temporal_coverage': [2020],
#    'update_frequency': None,
#    'url': 'https://www.cable.co.uk/mobiles/worldwide-data-pricing/',
#    'url_type': None,
#    'country_ip_address_required': None,
#    'is_free': 'yes',
#    'license': 'mit',
#    'requires_registration': 'no'}],
#  'groups': [{'description': '',
#    'display_name': 'Ciência, Tecnologia e Inovação',
#    'id': '4e4ab02b-6916-493b-9645-375ee3c3d3cd',
#    'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-27-055908.259082science-stem-feature.png',
#    'name': 'ciencia-tec-inov',
#    'title': 'Ciência, Tecnologia e Inovação'},
#   {'description': '',
#    'display_name': 'Economia',
#    'id': '52e4efe1-c527-4446-88dc-33ec9af7abb8',
#    'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-055720.95356961SjkfwyNTL.png',
#    'name': 'economia',
#    'title': 'Economia'}],
#  'owner_org': '394d152f-87cf-4895-933e-88b67593b106',
#  'organization': {'id': '394d152f-87cf-4895-933e-88b67593b106',
#   'name': 'cable-co-uk',
#   'title': 'Cable.co.uk',
#   'type': 'organization',
#   'description': 'www.cable.co.uk',
#   'image_url': '2020-08-25-224041.521553ogcablelogo.png',
#   'created': '2020-08-25T22:40:41.549898',
#   'is_organization': True,
#   'approval_status': 'approved',
#   'state': 'active'},
#  'num_tags': 2,
#  'tags': [{'display_name': 'internet',
#    'id': '7389029d-2032-45db-94ed-1dc47462da71',
#    'name': 'internet',
#    'state': 'active',
#    'vocabulary_id': None},
#   {'display_name': 'preco',
#    'id': 'eea12ebd-d7e3-4cee-8efc-774bd7f47a9a',
#    'name': 'preco',
#    'state': 'active',
#    'vocabulary_id': None}],
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'download_type': 'Link Externo'}

# %%
for p in packages:
    print('-' * 20)
    print(p)
    api_url = ORIGINAL_CKAN_URL + f'/api/3/action/package_show?id={p}'
    content = requests.get(api_url).json()['result']
    errs = validate(migrate(content))
    if errs:
        if errs[0]['errors']['owner_org'] == ['A organização não existe']:
            pass
        print(errs)
        print(content)
    else:
        migrated_list.append(p)
        packages.remove(p)
# Out:
# --------------------
# acaps-covid-19-government-measures-dataset
# --------------------
# acessos-dos-servicos-de-tv-por-assinatura-no-brasil
# --------------------
# acidentes-de-transito
# --------------------
# aea-rct-registry-dataverse
# --------------------
# afrobarometer
# --------------------
# a-global-database-on-central-banks-monetary-responses-to-covid-19
# --------------------
# agrofit
# --------------------
# aiddata-s-geocoded-global-chinese-official-finance
# --------------------
# aldeias-indigenas-sistema-indigenista-de-informacoes
# --------------------
# allsides-media-bias-chart
# --------------------
# amazonia-minada
# --------------------
# american-national-election-studies-anes
# --------------------
# americasbarometer
# --------------------
# analise-de-movimento-durante-covid-19-para-a-america-latina
# --------------------
# antarctic-iceberg-tracking-database
# --------------------
# anuario-estatistico-da-antaq
# --------------------
# anuario-estatistico-de-acidentes-do-trabalho-aeat
# --------------------
# arab-barometer
# --------------------
# armas-apreendidas-por-delegacia-de-policia-rj
# --------------------
# armed-conflict-location-event-data-acled
# --------------------
# arrecadacao-emissao-de-vistos-entre-2010-e-2019-por-posto
# --------------------
# artigo-19-violacoes-a-liberdade
# --------------------
# a-shell-dataset-for-shell-features-extraction-and-recognition
# --------------------
# a-spatial-database-of-health-facilities-managed-by-the-public-health-sector-in-sub-saharan-africa
# --------------------
# atlas-da-violencia
# --------------------
# atlas-do-estado-brasileiro
# --------------------
# atlas-of-historical-county-boundaries
# --------------------
# a-tracker-of-trackers-covid-19-policy-responses-and-data
# --------------------
# authoritarian-ruling-elites-database-ared
# --------------------
# autuacoes-ambientais-e-embargos
# --------------------
# average-happiness-for-twitter
# --------------------
# baci
# --------------------
# banco-de-dados-da-wikipedia
# --------------------
# banco-de-dados-geodesicos-bdg
# --------------------
# banco-de-pesquisas-de-opiniao-publica
# --------------------
# barro-lee-education-attainment-dataset
# --------------------
# base-monetaria-papel-moeda-emitido
# --------------------
# bb-integra
# --------------------
# berkeley-earth-air-pollution
# --------------------
# best-hip-hop-songs-of-all-time
# --------------------
# bloomberg-billionaires-index
# --------------------
# boletim-epidemiologico-da-secretaria-especial-de-saude-indigena-sesai
# --------------------
# bolsa-familia
# --------------------
# bolsa-verde
# --------------------
# bp-statistical-review-of-world-energy
# --------------------
# br-ana-atlas-esgotos
# --------------------
# br-anatel-telefonia-movel
# --------------------
# brazilian-electoral-panel-studies-beps
# --------------------
# br-bd-diretorios-brasil
# --------------------
# br_camara_atividade_legislativa
# --------------------
# breaking-trust-software-supply-chain-attacks
# --------------------
# br-ibge-amc
# --------------------
# br-ibge-inflacao
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/d9/_9rrlqns6mb8xlw_314gg7480000gn/T/ipykernel_99390/748677704.py in <module>
#       6     errs = validate(migrate(content))
#       7     if errs:
# ----> 8         if errs[0]['errors']['owner_org'] == ['A organização não existe']:
#       9             pass
#      10         print(errs)
#
# KeyError: 'errors'

# %%
# Out:
# --------------------
# acaps-covid-19-government-measures-dataset
# --------------------
# acessos-de-telefonia-fixa-no-brasil
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': 'e2ac8cfb-9d0a-4b52-87f3-9c3437c0c2a2', 'name': 'acessos-de-telefonia-fixa-no-brasil', 'title': 'Acessos de telefonia fixa no Brasil', 'type': 'dataset', 'notes': 'A Agência Nacional de Telecomunicações (Anatel) informa mensalmente a quantidade de acessos existentes no Brasil relativos aos principais serviços de telecomunicações.\r\n\r\nOs dados apresentados abaixo referem-se aos acessos individuais do Serviço de Telefonia Fixa Comutada, não incluindo os acessos referentes aos telefones de uso público (orelhões).', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': '', 'version': '', 'metadata_created': '2019-11-13T16:48:03.680651', 'metadata_modified': '2019-11-13T16:48:24.279223', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 2, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-11-13T16:48:12.204380', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': 'd436e7d8-52ca-4444-a962-ecb0449910e7', 'last_modified': None, 'metadata_modified': '2019-11-13T16:48:12.204380', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar', 'package_id': 'e2ac8cfb-9d0a-4b52-87f3-9c3437c0c2a2', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'https://cloud.anatel.gov.br/index.php/s/TpaFAwSw7RPfBa8?path=%2FTelefonia_Fixa', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}, {'cache_last_updated': None, 'cache_url': None, 'created': '2019-11-13T16:48:24.134594', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': '5ae92e16-c839-4af3-919a-4c359e1b5391', 'last_modified': None, 'metadata_modified': '2019-11-13T16:48:24.134594', 'mimetype': None, 'mimetype_inner': None, 'name': 'Visualizar', 'package_id': 'e2ac8cfb-9d0a-4b52-87f3-9c3437c0c2a2', 'position': 1, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'https://www.anatel.gov.br/dados/component/content/article/84-destaque/331-acessos-telefonia-fixa', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'Ciência, Tecnologia e Inovação', 'id': '4e4ab02b-6916-493b-9645-375ee3c3d3cd', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-27-055908.259082science-stem-feature.png', 'name': 'ciencia-tec-inov', 'title': 'Ciência, Tecnologia e Inovação'}, {'description': '', 'display_name': 'Infraestrutura e Transportes', 'id': 'be067fce-b02f-4b63-a44c-fd46ba020501', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-28-001231.066818los-angeles-highways.jpg', 'name': 'infra-transp', 'title': 'Infraestrutura e Transportes'}, {'description': '', 'display_name': 'Jornalismo e Comunicação', 'id': '600a23dc-245f-4281-ac53-92a6e2a3edff', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-28-064636.490505journalism.png', 'name': 'comunicacao', 'title': 'Jornalismo e Comunicação'}], 'owner_org': '6159fddf-3f48-45fb-9e93-85f9eb779500', 'organization': {'id': '6159fddf-3f48-45fb-9e93-85f9eb779500', 'name': 'agencia-nacional-de-telecomunicacoes-anatel', 'title': 'Agência Nacional de Telecomunicações (Anatel)', 'type': 'organization', 'description': 'www.anatel.gov.br', 'image_url': '2019-11-13-163814.698964anatel.png', 'created': '2019-11-13T16:38:14.711003', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 1, 'tags': [{'display_name': 'telefone', 'id': '09d17bdd-7f27-4730-af5a-7871c7f482c8', 'name': 'telefone', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# acessos-dos-servicos-de-tv-por-assinatura-no-brasil
# --------------------
# achados-e-pedidos
# --------------------
# acidentes-de-transito
# --------------------
# a-complete-catalog-of-every-time-someone-cursed-or-bled-out-in-a-quentin-tarantino-movie
# [{'loc': ['resources', 0, 'ExternalLink', 'update_frequency'], 'msg': "value is not a valid enumeration member; permitted: 'second', 'minute', 'hour', 'day', 'week', 'month', 'quarter', 'semester', 'one_year', 'two_years', 'three_years', 'four_years', 'five_years', 'ten_years', 'unique', 'recurring', 'uncertain', 'other'", 'type': 'type_error.enum', 'ctx': {'enum_values': ['second', 'minute', 'hour', 'day', 'week', 'month', 'quarter', 'semester', 'one_year', 'two_years', 'three_years', 'four_years', 'five_years', 'ten_years', 'unique', 'recurring', 'uncertain', 'other']}}]
# {'id': '08fb427e-cb03-4e45-ae2f-4ee6c0ca1bc1', 'name': 'a-complete-catalog-of-every-time-someone-cursed-or-bled-out-in-a-quentin-tarantino-movie', 'title': 'A Complete Catalog Of Every Time Someone Cursed Or Bled Out In A Quentin Tarantino Movie', 'type': 'dataset', 'notes': 'Todas as vezes em que alguém xingou ou sangrou em filmes do Quentin Tarantino.', 'author': None, 'author_email': None, 'maintainer': None, 'maintainer_email': None, 'state': 'active', 'license_id': None, 'url': 'https://fivethirtyeight.com/features/complete-catalog-curses-deaths-quentin-tarantino-films/', 'version': None, 'metadata_created': '2019-12-30T15:51:43.011378', 'metadata_modified': '2019-12-30T15:52:48.740844', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': None, 'num_resources': 1, 'resources': [{'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2019-12-30T15:52:01.449949', 'datastore_active': False, 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': 'f877b56a-690b-40f6-b3db-710c924de1cc', 'language': ['english'], 'last_modified': None, 'metadata_modified': '2019-12-30T15:52:01.449949', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar (Github)', 'package_id': '08fb427e-cb03-4e45-ae2f-4ee6c0ca1bc1', 'position': 0, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'america_norte', 'state': 'active', 'temporal_coverage': ['CHECK'], 'update_frequency': 'empty', 'url': 'https://github.com/fivethirtyeight/data/tree/master/tarantino', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}], 'groups': [{'description': '', 'display_name': 'Cultura e Arte', 'id': 'd3d1edae-b979-49cf-9679-e94733fb2269', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-18-192314.327701821138883884682b08c5b.jpg', 'name': 'cultura-arte', 'title': 'Cultura e Arte'}], 'owner_org': 'e7ecec6b-a556-42c0-97f1-8c7952dfebb7', 'organization': {'id': 'e7ecec6b-a556-42c0-97f1-8c7952dfebb7', 'name': 'fivethirtyeight', 'title': 'FiveThirtyEight', 'type': 'organization', 'description': 'fivethirtyeight.com', 'image_url': '2019-12-24-181506.836096logo-fox-head-color.svg', 'created': '2019-12-24T18:15:06.862766', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 2, 'tags': [{'display_name': 'cinema', 'id': 'fc5863a4-5785-474f-8da3-7352476dfafd', 'name': 'cinema', 'state': 'active', 'vocabulary_id': None}, {'display_name': 'filme', 'id': 'bcfab5f5-d866-4522-be6b-c212dffb4e6d', 'name': 'filme', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo'}
# --------------------
# aea-rct-registry-dataverse
# --------------------
# africa-integrity-indicators
# --------------------
# afrobarometer
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': 'bd8829fa-f0ec-4a46-897a-b293023c2e5b', 'name': 'afrobarometer', 'title': 'Afrobarometer', 'type': 'dataset', 'notes': 'O Afrobarometer é uma instituição de pesquisa pan-africana não partidária que realiza pesquisas de atitude pública sobre democracia, governança, economia e sociedade em mais de 30 países, repetidas em um ciclo regular. Somos a principal fonte mundial de dados de alta qualidade sobre o que os africanos estão pensando.', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': '', 'version': '', 'metadata_created': '2019-09-20T19:03:26.417153', 'metadata_modified': '2019-09-20T19:03:41.857416', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 1, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-09-20T19:03:41.728932', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': '80cae415-40cc-4f58-a7b8-4aa717a877a4', 'last_modified': None, 'metadata_modified': '2019-09-20T19:03:41.728932', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar', 'package_id': 'bd8829fa-f0ec-4a46-897a-b293023c2e5b', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'http://www.afrobarometer.org/data', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'Cultura e Arte', 'id': 'd3d1edae-b979-49cf-9679-e94733fb2269', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-18-192314.327701821138883884682b08c5b.jpg', 'name': 'cultura-arte', 'title': 'Cultura e Arte'}, {'description': '', 'display_name': 'Política', 'id': 'e5d6e7cd-f1b0-4160-bbba-86cc55b818d5', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060252.188862politica.jpg', 'name': 'politica', 'title': 'Política'}], 'owner_org': '8e9e9550-d813-4807-adb5-51a0cb19839d', 'organization': {'id': '8e9e9550-d813-4807-adb5-51a0cb19839d', 'name': 'afrobarometer', 'title': 'Afrobarometer', 'type': 'organization', 'description': 'www.afrobarometer.org', 'image_url': '2019-09-20-185624.213665MwBlWwUL400x400.jpg', 'created': '2019-09-20T18:56:24.225682', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 1, 'tags': [{'display_name': 'barometro', 'id': '0c4d960a-5d3f-41e7-b2bc-838b85a2ec1c', 'name': 'barometro', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# ageguess
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': '67fbf9ee-18e4-48c7-ac6a-1aa13c800c88', 'name': 'ageguess', 'title': 'AgeGuess', 'type': 'dataset', 'notes': 'O AgeGuess é um jogo online simples, no qual você pode postar suas fotos, fazer com que outras pessoas adivinhem sua idade e também a idade de outros usuários.\r\n\r\nO AgeGuess investiga as diferenças entre a idade percebida (quantos anos você tem) e a idade cronológica (sua idade) como um potencial biomarcador de envelhecimento.', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': '', 'version': '', 'metadata_created': '2019-11-13T16:01:02.727802', 'metadata_modified': '2019-11-13T16:02:18.325784', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 1, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-11-13T16:01:17.349566', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': '3277278f-02c1-4e80-ab5c-bb40d51c8f9a', 'last_modified': None, 'metadata_modified': '2019-11-13T16:01:17.349566', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar', 'package_id': '67fbf9ee-18e4-48c7-ac6a-1aa13c800c88', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'https://www.ageguess.org/download', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'População', 'id': 'c1990559-75f6-43d0-94f2-8ecfe470b673', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060328.174268381c2abde74ad5fb139f94f5347d0fa6.jpg', 'name': 'populacao', 'title': 'População'}], 'owner_org': 'f9344fd7-ab83-407d-8602-0d5d2507d281', 'organization': {'id': 'f9344fd7-ab83-407d-8602-0d5d2507d281', 'name': 'ageguess', 'title': 'AgeGuess', 'type': 'organization', 'description': 'www.ageguess.org', 'image_url': '2019-11-13-155901.363354logo.png', 'created': '2019-11-13T15:59:01.383271', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 1, 'tags': [{'display_name': 'idade', 'id': '3d66803a-8b5a-4227-9ca1-e198feceefb6', 'name': 'idade', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# a-global-database-on-central-banks-monetary-responses-to-covid-19
# --------------------
# a-global-scale-data-set-of-mining-areas
# [{'loc': ['resources', 1, 'ExternalLink', 'datastore_active'], 'msg': 'field required', 'type': 'value_error.missing'}]
# {'id': '5c16cc76-50c8-4512-a32d-1c48694429d2', 'name': 'a-global-scale-data-set-of-mining-areas', 'title': 'A global-scale data set of mining areas', 'type': 'dataset', 'notes': 'Este conjunto de dados fornece estimativas espacialmente explícitas da área diretamente usada para mineração de superfície em escala global. Contém mais de 21.000 polígonos de atividades relacionadas à mineração, principalmente de carvão e minérios metálicos. Diversas fontes de dados foram compiladas para identificar a localização aproximada das minas ativas em qualquer momento entre os anos de 2000 a 2017. Este conjunto de dados não cobre todos os locais de mineração existentes em todo o mundo.\r\n\r\nOs polígonos foram delineados por especialistas usando Sentinel-2 cloudless (https://s2maps.eu por EOX IT Services GmbH (contém dados Copernicus Sentinel modificados de 2017 e 2018)) e imagens de satélite de alta resolução disponíveis no Google Satellite e Bing Imagery. Os polígonos derivados cobrem a terra direta usada pelas atividades de mineração, incluindo cortes abertos, barragens de rejeitos, depósitos de estéril, lagoas de água e infraestrutura de processamento.', 'author': None, 'author_email': None, 'maintainer': None, 'maintainer_email': None, 'state': 'active', 'license_id': None, 'url': 'https://www.nature.com/articles/s41597-020-00624-w', 'version': None, 'metadata_created': '2020-10-28T16:19:12.142917', 'metadata_modified': '2020-10-28T16:20:12.332041', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': None, 'num_resources': 2, 'resources': [{'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-10-28T16:19:21.883919', 'datastore_active': False, 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': '2a83482a-514e-42e3-aa7d-01041c969be9', 'language': ['english'], 'last_modified': None, 'metadata_modified': '2020-10-28T16:19:22.060882', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar (Link Externo)', 'package_id': '5c16cc76-50c8-4512-a32d-1c48694429d2', 'position': 0, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'internacional', 'state': 'active', 'temporal_coverage': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], 'update_frequency': 'unique', 'url': 'https://doi.pangaea.de/10.1594/PANGAEA.910894', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}, {'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-10-28T16:20:12.350316', 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': 'd55b1f50-161d-4338-9e22-867ab5f76129', 'language': ['english'], 'last_modified': None, 'metadata_modified': '2020-10-28T16:20:12.337517', 'mimetype': None, 'mimetype_inner': None, 'name': 'Visualizar Mapa', 'package_id': '5c16cc76-50c8-4512-a32d-1c48694429d2', 'position': 1, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'internacional', 'state': 'active', 'temporal_coverage': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], 'update_frequency': 'unique', 'url': 'https://www.fineprint.global/visualisations/viewer/', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}], 'groups': [{'description': '', 'display_name': 'Economia', 'id': '52e4efe1-c527-4446-88dc-33ec9af7abb8', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-055720.95356961SjkfwyNTL.png', 'name': 'economia', 'title': 'Economia'}, {'description': '', 'display_name': 'Meio Ambiente', 'id': '83dff031-87ba-4265-9499-57e24e24e0b1', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060220.418949young-plant-growing-step-nature-sunshine34152-1142.jpg', 'name': 'meio-ambiente', 'title' ...
# --------------------
# agrofit
# [{'loc': ['resources', 0, 'ExternalLink', 'update_frequency'], 'msg': "value is not a valid enumeration member; permitted: 'second', 'minute', 'hour', 'day', 'week', 'month', 'quarter', 'semester', 'one_year', 'two_years', 'three_years', 'four_years', 'five_years', 'ten_years', 'unique', 'recurring', 'uncertain', 'other'", 'type': 'type_error.enum', 'ctx': {'enum_values': ['second', 'minute', 'hour', 'day', 'week', 'month', 'quarter', 'semester', 'one_year', 'two_years', 'three_years', 'four_years', 'five_years', 'ten_years', 'unique', 'recurring', 'uncertain', 'other']}}]
# {'id': 'acb82e75-e4d4-45ba-a2c7-8fa8d5cd03c5', 'name': 'agrofit', 'title': 'AGROFIT', 'type': 'dataset', 'notes': 'O AGROFIT é uma ferramenta de consulta ao público, composta por um banco de dados de todos os produtos agrotóxicos e afins registrados no Ministério da Agricultura, Pecuária e Abastecimento, com informações do Ministério da Saúde (ANVISA) e informações do Ministério do Meio Ambiente (IBAMA).\r\n\r\nO AGROFIT permite vários tipos de pesquisas para o controle de pragas na agricultura brasileira. Para pesquisar nas opções por marca comercial, cultura, ingrediente ativo, classificação toxicológica e classificação ambiental, o usuário terá o acesso rápido, permitindo obter informações sobre produtos registrados para controle de pragas (insetos, doenças e plantas daninhas), com textos explicativos e fotos.\r\n\r\nA utilização correta do AGROFIT permitirá ao usuário o uso correto e seguro dos produtos registrados no MAPA, contribuindo para evitar o uso inadequado de agrotóxicos, que poderia acarretar no desenvolvimento de resistência de pragas nas lavouras e resíduos de agrotóxicos em produtos vegetais acima dos Limites Máximos de Resíduos (LMR) estabelecidos.', 'author': None, 'author_email': None, 'maintainer': None, 'maintainer_email': None, 'state': 'active', 'license_id': None, 'url': 'http://extranet.agricultura.gov.br/agrofit_cons/principal_agrofit_cons', 'version': None, 'metadata_created': '2019-12-30T14:24:10.665372', 'metadata_modified': '2019-12-30T14:26:10.291976', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': None, 'num_resources': 1, 'resources': [{'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2019-12-30T14:24:37.414406', 'datastore_active': False, 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': 'b6a9bdea-50cc-4d50-9784-4641683acb1a', 'language': ['portuguese'], 'last_modified': None, 'metadata_modified': '2019-12-30T14:24:37.414406', 'mimetype': None, 'mimetype_inner': None, 'name': 'Pesquisar e Baixar', 'package_id': 'acb82e75-e4d4-45ba-a2c7-8fa8d5cd03c5', 'position': 0, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'america_sul', 'state': 'active', 'temporal_coverage': ['CHECK'], 'update_frequency': 'empty', 'url': 'http://extranet.agricultura.gov.br/agrofit_cons/principal_agrofit_cons', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}], 'groups': [{'description': '', 'display_name': 'Agropecuária', 'id': '995d9eba-e1d7-49a0-bb67-e59d580c08e3', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-055635.125506ico-destinonegocio-pecuaria-istock-getty-images-1030x773.jpg', 'name': 'agropecuaria', 'title': 'Agropecuária'}, {'description': '', 'display_name': 'Ciência, Tecnologia e Inovação', 'id': '4e4ab02b-6916-493b-9645-375ee3c3d3cd', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-27-055908.259082science-stem-feature.png', 'name': 'ciencia-tec-inov', 'title': 'Ciência, Tecnologia e Inovação'}, {'description': '', 'display_name': 'Meio Ambiente', 'id': '83dff031-87ba-4265-9499-57e24e24e0b1', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060220.418949young-plant-growing-step-nature-sunshine34152-1142.jpg', 'name': 'meio-ambiente', 'title': 'Meio Ambiente'}, {'description': '', 'display_name': 'Saúde', 'id': '8358e722-42fc-408a-8859-084d74da5dd5', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060434.084225heart-checkup.png', 'name': 'saude', 'title': 'Saúde'}], 'owner_org': '7a0dd0e0-defb-45dc-b7ba-8af061e39141', 'organization': {'id': '7a0dd0e0-defb-45dc-b7ba-8af061e39141', 'name': 'ministerio-da-agricultura-pecuaria-e-abastecimento-mapa', 'title': 'Ministério da Agricultura, Pecuária e Abastecimento (MAPA)', 'type': 'organization', 'description': 'http://www.agricultura.gov.br', 'image_url': '2019-11- ...
# --------------------
# agrolink-fito
# --------------------
# aiddata-s-geocoded-global-chinese-official-finance
# --------------------
# ajuda-internacional-usaid
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': '43a88df8-2e70-48b2-abbf-36f84f88a21c', 'name': 'ajuda-internacional-usaid', 'title': 'Ajuda Internacional USAID', 'type': 'dataset', 'notes': 'Como principal agência do governo dos EUA para ajuda internacional, a USAID é responsável por relatar a ajuda externa oficial do governo dos EUA ao Congresso e à Organização para Cooperação e Desenvolvimento Econômico (OCDE). Para cumprir essa responsabilidade, a USAID mantém o banco de dados oficial dos relatórios do Greenbook e da OCDE / CAD da assistência do governo dos EUA ao mundo, desde 1946 até o presente.', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': 'https://explorer.usaid.gov', 'version': '', 'metadata_created': '2019-09-27T05:24:35.756927', 'metadata_modified': '2019-09-27T05:27:42.359091', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 1, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-09-27T05:24:49.642725', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': '110a4755-7efa-4215-9af1-59c51b1c4e78', 'last_modified': None, 'metadata_modified': '2019-09-27T05:24:49.642725', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar', 'package_id': '43a88df8-2e70-48b2-abbf-36f84f88a21c', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'https://explorer.usaid.gov/data', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'Economia', 'id': '52e4efe1-c527-4446-88dc-33ec9af7abb8', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-055720.95356961SjkfwyNTL.png', 'name': 'economia', 'title': 'Economia'}, {'description': '', 'display_name': 'Educação', 'id': 'ea02cfce-ac55-4079-8de2-02ec79f01c78', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-055755.408617Educacao-Exame-Abril.jpg', 'name': 'educacao', 'title': 'Educação'}, {'description': '', 'display_name': 'Governo e Finanças Públicas', 'id': '9b4676bf-be6f-4faa-8890-dbdab6992784', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060407.937294Prestaodecontas.jpg', 'name': 'gov-fin-pub', 'title': 'Governo e Finanças Públicas'}, {'description': '', 'display_name': 'Política', 'id': 'e5d6e7cd-f1b0-4160-bbba-86cc55b818d5', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060252.188862politica.jpg', 'name': 'politica', 'title': 'Política'}, {'description': '', 'display_name': 'Saúde', 'id': '8358e722-42fc-408a-8859-084d74da5dd5', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060434.084225heart-checkup.png', 'name': 'saude', 'title': 'Saúde'}, {'description': '', 'display_name': 'Segurança, Crime, Violência, e Conflito', 'id': '56e94027-c292-4450-8934-df4232414049', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-18-005515.746896violence.jpg', 'name': 'seguranca', 'title': 'Segurança, Crime, Violência, e Conflito'}], 'owner_org': 'e445260f-f199-4e26-83ff-eced037b715a', 'organization': {'id': 'e445260f-f199-4e26-83ff-eced037b715a', 'name': 'usaid', 'title': 'USAID', 'type': 'organization', 'description': 'usaid.gov', 'image_url': '2019-09-27-052124.420360usaid.png', 'created': '2019-09-27T05:21:24.432442', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 1, 'tags': [{'display_name': 'ajuda', 'id': 'e7f237e5-c394-4c76-9a06-58bf5ea2a42c', 'name': 'ajuda', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# aldeias-indigenas-sistema-indigenista-de-informacoes
# --------------------
# alistados-no-servico-militar
# --------------------
# allsides-media-bias-chart
# --------------------
# al-urayya-project
# --------------------
# amazonia-minada
# --------------------
# american-cabinet-appointments
# --------------------
# american-national-election-studies-anes
# --------------------
# american-time-use-survey-atus
# --------------------
# americasbarometer
# --------------------
# anage-the-animal-ageing-and-longevity-database
# --------------------
# analise-de-movimento-durante-covid-19-para-a-america-latina
# --------------------
# analytics-usa-gov
# --------------------
# antarctic-iceberg-tracking-database
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': 'e6951c87-641f-41ff-9408-18c25c7a0db6', 'name': 'antarctic-iceberg-tracking-database', 'title': 'Antarctic Iceberg Tracking Database', 'type': 'dataset', 'notes': 'Monitora centenas de pedaços flutuantes de gelo, passado e presente. Os registros abrangem 1978 e 1992 até meados de 2019; um subconjunto do banco de dados lista a posição diária de 117 icebergs, tamanho estimado e ângulo de rotação.', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': 'https://www.scp.byu.edu/data/iceberg/', 'version': '3', 'metadata_created': '2019-09-27T06:23:33.434538', 'metadata_modified': '2019-12-12T20:16:39.555883', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 1, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-09-27T06:24:07.941745', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': 'f34f8b0c-83a7-41b2-a12a-001ce62ff66d', 'last_modified': None, 'metadata_modified': '2019-09-27T06:24:07.941745', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar', 'package_id': 'e6951c87-641f-41ff-9408-18c25c7a0db6', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'https://www.scp.byu.edu/data/iceberg/', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'Meio Ambiente', 'id': '83dff031-87ba-4265-9499-57e24e24e0b1', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060220.418949young-plant-growing-step-nature-sunshine34152-1142.jpg', 'name': 'meio-ambiente', 'title': 'Meio Ambiente'}], 'owner_org': '6e1dcf85-b1be-4a0e-9ee3-5a09847cbf99', 'organization': {'id': '6e1dcf85-b1be-4a0e-9ee3-5a09847cbf99', 'name': 'brigham-young-university', 'title': 'Brigham Young University', 'type': 'organization', 'description': '', 'image_url': '2019-09-27-062123.0635651200px-BrighamYoungUniversitymedallion.svg.png', 'created': '2019-09-27T06:21:23.076002', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 2, 'tags': [{'display_name': 'iceberg', 'id': '298b09a8-bf4d-4720-b080-818db62ee9be', 'name': 'iceberg', 'state': 'active', 'vocabulary_id': None}, {'display_name': 'mudancas climaticas', 'id': '5081498d-c16f-46df-bf22-c232eb3c2d78', 'name': 'mudancas climaticas', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# anuario-brasileiro-de-seguranca-publica
# [{'loc': ['resources', 1, 'ExternalLink', 'datastore_active'], 'msg': 'field required', 'type': 'value_error.missing'}]
# {'id': '5912b8df-56cc-47cf-833f-e0710c3be764', 'name': 'anuario-brasileiro-de-seguranca-publica', 'title': 'Anuário Brasileiro de Segurança Pública', 'type': 'dataset', 'notes': 'Concebido com o objetivo de suprir a falta de conhecimento consolidado, sistematizada e confiável no campo, o Anuário Brasileiro de Segurança Pública compila e analisa dados de registros policiais sobre criminalidade, informações sobre o sistema prisional e gastos com segurança pública, entre outros recortes introduzidos a cada edição.\r\n\r\nA publicação é uma ferramenta importante para a promoção da transparência e da prestação de contas na área da segurança pública, influenciando a melhoria da qualidade dos dados por parte dos gestores. Além disso, o anuário contribui para a produção de conhecimento, para o incentivo à avaliação de políticas públicas, para a introdução de novos temas na agenda de discussão do campo e para ações de incidência política realizadas por diversas organizações da sociedade civil.', 'author': None, 'author_email': None, 'maintainer': None, 'maintainer_email': None, 'state': 'active', 'license_id': None, 'url': 'http://www.forumseguranca.org.br/atividades/anuario/', 'version': None, 'metadata_created': '2020-02-14T18:57:09.826433', 'metadata_modified': '2020-02-14T18:58:24.262865', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': None, 'num_resources': 2, 'resources': [{'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-02-14T18:57:38.301032', 'datastore_active': False, 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': '9650f679-3571-402a-a174-998f144d3932', 'language': ['portuguese'], 'last_modified': None, 'metadata_modified': '2020-02-14T18:57:38.301032', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar (Anuário 2019)', 'package_id': '5912b8df-56cc-47cf-833f-e0710c3be764', 'position': 0, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'america_sul', 'state': 'active', 'temporal_coverage': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 'update_frequency': 'one_year', 'url': 'http://www.forumseguranca.org.br/publicacoes/13-anuario-brasileiro-de-seguranca-publica/', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}, {'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-02-14T18:58:24.287645', 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': 'a2198aa4-d015-4523-a98e-6917dbd0e543', 'language': ['portuguese'], 'last_modified': None, 'metadata_modified': '2020-02-14T18:58:24.287645', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar (Anuário 2018)', 'package_id': '5912b8df-56cc-47cf-833f-e0710c3be764', 'position': 1, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'america_sul', 'state': 'active', 'temporal_coverage': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 'update_frequency': 'one_year', 'url': 'http://www.forumseguranca.org.br/publicacoes/anuario-brasileiro-de-seguranca-publica-2018/', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}], 'groups': [{'description': '', 'display_name': 'Segurança, Crime, Violência, e Conflito', 'id': '56e94027-c292-4450-8934-df4232414049', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-18-005515.746896violence.jpg', 'name': 'seguranca', 'title': 'Segurança, Crime, Violência, e Conflito'}], 'owner_org': 'eff1c7db-85ee-44c6-8895-aa50d57cb5d4', 'organization': {'id': 'eff1c7db-85ee-44c6-8895-aa50d57cb5d4', 'name': 'forum-brasileiro-de-seguranca-publica-fbsp', 'title': 'Fórum Brasileiro de Segurança Pública (FBSP)', 'type': 'organization', 'description': 'www.forumseguranca.org.br', 'image_url': '2020-02-14-185449.421293unna ...
# --------------------
# anuario-estatistico-da-antaq
# --------------------
# anuario-estatistico-da-previdencia-social-aeps
# --------------------
# anuario-estatistico-de-acidentes-do-trabalho-aeat
# --------------------
# api-of-ice-and-fire
# --------------------
# arab-barometer
# --------------------
# archigos
# --------------------
# armas-apreendidas-por-delegacia-de-policia-rj
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': 'f748cb72-665d-4687-b736-994dab538772', 'name': 'armas-apreendidas-por-delegacia-de-policia-rj', 'title': 'Armas Apreendidas por Delegacia de Polícia - RJ', 'type': 'dataset', 'notes': 'Armas: evolução mensal de armas apreendidas por circunscrição de Delegacia (1/2007 a 10/2019).', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': '', 'version': '', 'metadata_created': '2019-12-09T00:52:37.448975', 'metadata_modified': '2019-12-09T00:53:10.590938', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 1, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-12-09T00:53:08.770535', 'datastore_active': False, 'description': '', 'format': 'HTML', 'hash': '', 'id': 'a772d16d-5aa2-4e80-9fff-cc808051cebd', 'last_modified': None, 'metadata_modified': '2019-12-09T00:53:08.770535', 'mimetype': 'text/html', 'mimetype_inner': None, 'name': 'Baixar', 'package_id': 'f748cb72-665d-4687-b736-994dab538772', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'http://www.ispdados.rj.gov.br/estatistica.html', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'Segurança, Crime, Violência, e Conflito', 'id': '56e94027-c292-4450-8934-df4232414049', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-18-005515.746896violence.jpg', 'name': 'seguranca', 'title': 'Segurança, Crime, Violência, e Conflito'}], 'owner_org': 'cf3bacc8-7072-410c-8612-cb807da7901f', 'organization': {'id': 'cf3bacc8-7072-410c-8612-cb807da7901f', 'name': 'instituto-de-seguranca-publica-isp', 'title': 'Instituto de Segurança Pública (ISP)', 'type': 'organization', 'description': 'www.isp.rj.gov.br', 'image_url': '2019-12-09-003405.576992institutosegurancapublica.jpg', 'created': '2019-12-09T00:34:05.738897', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 2, 'tags': [{'display_name': 'arma', 'id': 'fdae943e-7d42-484c-bca2-2b658d37e38f', 'name': 'arma', 'state': 'active', 'vocabulary_id': None}, {'display_name': 'delegacia', 'id': '635728ef-62d2-44b5-a58a-3c6be8b53680', 'name': 'delegacia', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# armas-municoes-e-equipamentos-desviados
# --------------------
# armed-conflict-location-event-data-acled
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': '21332c11-ff5e-4ee7-9e00-00dc97ee619d', 'name': 'armed-conflict-location-event-data-acled', 'title': 'Armed Conflict Location & Event Data (ACLED)', 'type': 'dataset', 'notes': 'O Projeto de Localização de Conflitos Armados e Dados de Eventos (ACLED) é um projeto desagregado de coleta, análise e mapeamento de crises. A ACLED registra datas, atores, tipos de violência, locais e fatalidades de todos os eventos de violência política e protestos relatados na África, Sul da Ásia, Sudeste Asiático, Oriente Médio, Europa e América Latina. A violência política e a atividade de protesto incluem eventos que ocorrem em guerras civis e períodos de instabilidade, manifestações públicas e quebra de regime. O objetivo da ACLED é capturar as formas, atores, datas e locais da violência política e do protesto, como ocorre nos estados. A equipe do ACLED conduz análises para descrever, explorar e testar cenários de conflito e torna os dados e as análises abertos ao uso livre do público.', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': '', 'version': '', 'metadata_created': '2019-09-20T19:37:29.388167', 'metadata_modified': '2019-09-20T19:37:46.045425', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 1, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-09-20T19:37:45.912833', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': '094cd0d4-4626-4cd2-b723-473b8391e419', 'last_modified': None, 'metadata_modified': '2019-09-20T19:37:45.912833', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar', 'package_id': '21332c11-ff5e-4ee7-9e00-00dc97ee619d', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'https://www.acleddata.com/data/', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'Segurança, Crime, Violência, e Conflito', 'id': '56e94027-c292-4450-8934-df4232414049', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-18-005515.746896violence.jpg', 'name': 'seguranca', 'title': 'Segurança, Crime, Violência, e Conflito'}], 'owner_org': 'cb31aaac-3a93-4dc4-8d74-1d9dc56dce9d', 'organization': {'id': 'cb31aaac-3a93-4dc4-8d74-1d9dc56dce9d', 'name': 'armed-conflict-location-event-data-project-acled', 'title': 'Armed Conflict Location & Event Data Project (ACLED)', 'type': 'organization', 'description': 'www.acleddata.com', 'image_url': '2019-09-20-193441.915981ACLED-logo.png', 'created': '2019-09-20T19:34:41.927939', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 1, 'tags': [{'display_name': 'eventos', 'id': '5800685a-d206-4db4-a2df-4b5421919fe0', 'name': 'eventos', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# arquivo-do-gabriel-garcia-marquez
# --------------------
# arrecadacao-emissao-de-vistos-entre-2010-e-2019-por-posto
# [{'loc': ['resources', 1, 'ExternalLink', 'datastore_active'], 'msg': 'field required', 'type': 'value_error.missing'}]
# {'id': 'fa698a84-e8ff-46db-a246-e6ec82ba7da9', 'name': 'arrecadacao-emissao-de-vistos-entre-2010-e-2019-por-posto', 'title': 'Arrecadação com emissão de vistos entre 2010 e 2019 por posto', 'type': 'dataset', 'notes': 'Arrecadação de emolumentos consulares referente a emissão de vistos entre 2010 e 2019 por posto - valores expressos em Reais-Ouro', 'author': None, 'author_email': None, 'maintainer': None, 'maintainer_email': None, 'state': 'active', 'license_id': None, 'url': '', 'version': None, 'metadata_created': '2020-08-19T13:39:29.604528', 'metadata_modified': '2020-08-21T17:00:56.500899', 'creator_user_id': 'ce4390a5-3819-474f-b1f8-8bd3caf96c67', 'private': False, 'license_title': None, 'num_resources': 2, 'resources': [{'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-08-19T13:41:28.962120', 'datastore_active': True, 'description': 'Arrecadação de emolumentos consulares referente a emissão de vistos em 2019 por posto  - valores expressos em Reais-Ouro', 'format': 'XLSX', 'formato': 'XLSX', 'has_api': 'no', 'hash': '', 'id': '52e0cd3d-14e3-4a7d-b2af-30594055092e', 'language': ['portuguese'], 'last_modified': '2020-08-19T13:41:26.712010', 'metadata_modified': '2020-08-19T13:41:28.962120', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'mimetype_inner': None, 'name': 'Arrecadação de emolumentos consulares referente a emissão de vistos em 2019 por posto ', 'package_id': 'fa698a84-e8ff-46db-a246-e6ec82ba7da9', 'position': 0, 'resource_type': 'external_link', 'size': 19951, 'spatial_coverage': 'america_sul', 'state': 'active', 'temporal_coverage': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 'update_frequency': 'one_year', 'url': 'https://basedosdados.org/dataset/fa698a84-e8ff-46db-a246-e6ec82ba7da9/resource/52e0cd3d-14e3-4a7d-b2af-30594055092e/download/producao-de-vistos-2019-por-pais-e-por-posto-.xlsx', 'url_type': 'upload', 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}, {'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-08-19T13:48:13.589604', 'description': 'Arrecadação anual de emolumentos consulares referentes a emissão de vistos (2010 a 2018). ', 'format': 'XLSX', 'formato': 'XLSX', 'has_api': 'no', 'hash': '', 'id': '2e05997d-4178-4d02-85ad-a3d40377ff6b', 'language': ['portuguese'], 'last_modified': '2020-08-19T13:48:11.713873', 'metadata_modified': '2020-08-19T13:48:13.589604', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'mimetype_inner': None, 'name': 'Arrecadação anual de emolumentos consulares (2010-2018)', 'package_id': 'fa698a84-e8ff-46db-a246-e6ec82ba7da9', 'position': 1, 'resource_type': 'external_link', 'size': 75503, 'spatial_coverage': 'america_sul', 'state': 'active', 'temporal_coverage': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], 'update_frequency': 'one_year', 'url': 'https://basedosdados.org/dataset/fa698a84-e8ff-46db-a246-e6ec82ba7da9/resource/2e05997d-4178-4d02-85ad-a3d40377ff6b/download/emissao-de-vistos-valores-arrecadados-2010-a-2018-compactado.xlsx', 'url_type': 'upload', 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}], 'groups': [{'description': '', 'display_name': 'Governo e Finanças Públicas', 'id': '9b4676bf-be6f-4faa-8890-dbdab6992784', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060407.937294Prestaodecontas.jpg', 'name': 'gov-fin-pub', 'title': 'Governo e Finanças Públicas'}], 'owner_org': 'fc2d961d-f345-415c-9f1d-8a3f719dc73d', 'organization': {'id': 'fc2d961d-f345-415c-9f1d-8a3f719dc73d', 'name': 'ministerio-das-relacoes-exteriores-mre', 'title': 'Ministério das Relações Exteriores (MRE)', 'type': 'organization', 'description': 'www.itamaraty.gov.br\r\n\r\nO Ministério das Relações Exteriores, conhecido como Itamaraty, é o órgão do Poder Executivo responsável pela ...
# --------------------
# artificial-intelligence-index-report
# --------------------
# artigo-19-violacoes-a-liberdade
# --------------------
# arxiv-open-archives
# --------------------
# a-shell-dataset-for-shell-features-extraction-and-recognition
# --------------------
# asian-barometer
# [{'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# ...
# --------------------
# despesas-publicas
# [{'loc': ['resources', 1, 'ExternalLink', 'datastore_active'], 'msg': 'field required', 'type': 'value_error.missing'}, {'loc': ['API'], 'msg': 'extra fields not permitted', 'type': 'value_error.extra'}]
# {'id': '68a16285-b6bc-44b4-959f-1b9158bc2dbd', 'name': 'despesas-publicas', 'title': 'Despesas Públicas', 'type': 'dataset', 'notes': 'Despesa pública é o conjunto de dispêndios realizados pelos entes públicos para custear os serviços públicos (despesas correntes) prestados à sociedade ou para a realização de investimentos (despesas de capital).\r\n\r\nAs despesas públicas devem ser autorizadas pelo Poder Legislativo, por meio do ato administrativo chamado orçamento público. Exceção diz respeito às despesas extra-orçamentárias.', 'author': '', 'author_email': '', 'maintainer': '', 'maintainer_email': '', 'state': 'active', 'license_id': 'cc-by', 'url': 'http://www.portaltransparencia.gov.br/despesas', 'version': '', 'metadata_created': '2019-12-10T16:41:30.068780', 'metadata_modified': '2019-12-13T03:45:42.430022', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': 'Creative Commons Attribution', 'num_resources': 2, 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2019-12-10T16:41:43.003213', 'datastore_active': False, 'description': '', 'format': '', 'hash': '', 'id': '74b54089-71c0-46b7-83d1-939d6d60728a', 'last_modified': None, 'metadata_modified': '2019-12-10T16:41:43.003213', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar', 'package_id': '68a16285-b6bc-44b4-959f-1b9158bc2dbd', 'position': 0, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'http://www.portaltransparencia.gov.br/download-de-dados/despesas-execucao', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}, {'cache_last_updated': None, 'cache_url': None, 'created': '2019-12-11T05:33:47.680164', 'description': '', 'format': '', 'hash': '', 'id': '3227c9e0-61ab-4b68-83b3-70761bc8f193', 'last_modified': None, 'metadata_modified': '2019-12-11T05:33:47.680164', 'mimetype': None, 'mimetype_inner': None, 'name': 'Visualizar Painéis', 'package_id': '68a16285-b6bc-44b4-959f-1b9158bc2dbd', 'position': 1, 'resource_type': 'external_link', 'size': None, 'state': 'active', 'url': 'http://www.portaltransparencia.gov.br/despesas', 'url_type': None, 'country_ip_address_required': None, 'is_free': None, 'license': 'mit', 'requires_registration': None}], 'groups': [{'description': '', 'display_name': 'Governo e Finanças Públicas', 'id': '9b4676bf-be6f-4faa-8890-dbdab6992784', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060407.937294Prestaodecontas.jpg', 'name': 'gov-fin-pub', 'title': 'Governo e Finanças Públicas'}], 'owner_org': 'e7c869f1-7de8-48e2-9130-2294a3b2b9d7', 'organization': {'id': 'e7c869f1-7de8-48e2-9130-2294a3b2b9d7', 'name': 'controladoria-geral-da-uniao', 'title': 'Controladoria Geral da União', 'type': 'organization', 'description': 'www.cgu.gov.br', 'image_url': '2021-04-14-212930.8469531560522004082.jpeg', 'created': '2019-09-17T05:06:17.230569', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 3, 'tags': [{'display_name': 'despesa', 'id': 'a5f9035e-a220-480a-bf66-94190d35a02c', 'name': 'despesa', 'state': 'active', 'vocabulary_id': None}, {'display_name': 'gasto', 'id': 'f921eb53-bd7d-4fde-bfaa-b726c4cfc88a', 'name': 'gasto', 'state': 'active', 'vocabulary_id': None}, {'display_name': 'orcamento', 'id': 'dfe93b96-314c-4020-a5f2-d09a4e98f1d5', 'name': 'orcamento', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo', 'API': 'Não'}
# --------------------
# devedores-da-uniao
# --------------------
# diario-oficial-do-estado-da-bahia
# --------------------
# diario-oficial-do-estado-da-paraiba
# --------------------
# diario-oficial-do-estado-de-alagoas
# --------------------
# diario-oficial-do-estado-de-goias
# --------------------
# diario-oficial-do-estado-de-mato-grosso
# --------------------
# diario-oficial-do-estado-de-minas-gerais
# --------------------
# diario-oficial-do-estado-de-pernambuco
# --------------------
# diario-oficial-do-estado-de-rondonia
# --------------------
# diario-oficial-do-estado-de-roraima
# --------------------
# diario-oficial-do-estado-de-santa-catarina
# --------------------
# diario-oficial-do-estado-de-sao-paulo
# --------------------
# diario-oficial-do-estado-de-sergipe
# --------------------
# diario-oficial-do-estado-de-tocantins
# --------------------
# diario-oficial-do-estado-do-acre
# --------------------
# diario-oficial-do-estado-do-amapa
# --------------------
# diario-oficial-do-estado-do-amazonas
# --------------------
# diario-oficial-do-estado-do-ceara
# --------------------
# diario-oficial-do-estado-do-distrito-federal
# [{'loc': ['resources', 1, 'ExternalLink', 'datastore_active'], 'msg': 'field required', 'type': 'value_error.missing'}]
# {'id': '1276b6d1-0347-4523-8481-1ccc03c8483a', 'name': 'diario-oficial-do-estado-do-distrito-federal', 'title': 'Diário Oficial do Estado do Distrito Federal', 'type': 'dataset', 'notes': 'O Diário Oficial do Estado do Distrito Federal é um dos veículos de comunicação pelo qual a Imprensa Estadual tem de tornar público todo e qualquer assunto acerca do âmbito do Estado.', 'author': None, 'author_email': None, 'maintainer': None, 'maintainer_email': None, 'state': 'active', 'license_id': None, 'url': '', 'version': None, 'metadata_created': '2020-05-19T17:12:46.962958', 'metadata_modified': '2020-05-19T17:13:32.476420', 'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc', 'private': False, 'license_title': None, 'num_resources': 2, 'resources': [{'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-05-19T17:12:54.271982', 'datastore_active': False, 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': '187f4242-3c4c-4921-ba55-0604fff64340', 'language': ['portuguese'], 'last_modified': None, 'metadata_modified': '2020-05-19T17:12:54.271982', 'mimetype': None, 'mimetype_inner': None, 'name': 'Buscar', 'package_id': '1276b6d1-0347-4523-8481-1ccc03c8483a', 'position': 0, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'america_sul', 'state': 'active', 'temporal_coverage': ['CHECK', 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], 'update_frequency': 'day', 'url': 'https://www.dodf.df.gov.br/', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}, {'availability': 'online', 'cache_last_updated': None, 'cache_url': None, 'created': '2020-05-19T17:13:32.495047', 'description': '', 'format': '', 'formato': '', 'has_api': 'no', 'hash': '', 'id': '17710956-d547-4c0e-a4a8-8d8084dc7723', 'language': ['portuguese'], 'last_modified': None, 'metadata_modified': '2020-05-19T17:13:32.495047', 'mimetype': None, 'mimetype_inner': None, 'name': 'Baixar por FTP', 'package_id': '1276b6d1-0347-4523-8481-1ccc03c8483a', 'position': 1, 'resource_type': 'external_link', 'size': None, 'spatial_coverage': 'america_sul', 'state': 'active', 'temporal_coverage': ['CHECK', 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], 'update_frequency': 'day', 'url': 'http://www.buriti.df.gov.br/ftp/', 'url_type': None, 'country_ip_address_required': None, 'is_free': 'yes', 'license': 'mit', 'requires_registration': 'no'}], 'groups': [{'description': '', 'display_name': 'Governo e Finanças Públicas', 'id': '9b4676bf-be6f-4faa-8890-dbdab6992784', 'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060407.937294Prestaodecontas.jpg', 'name': 'gov-fin-pub', 'title': 'Governo e Finanças Públicas'}], 'owner_org': '8505d39a-d699-4a7b-9ddb-725bd91fb4a8', 'organization': {'id': '8505d39a-d699-4a7b-9ddb-725bd91fb4a8', 'name': 'governo-do-distrito-federal', 'title': 'Governo do Distrito Federal', 'type': 'organization', 'description': 'www.df.gov.br', 'image_url': '2020-05-19-170943.551255Teste-Rapido-comentado-de-Lei-Organica-do-DF.png', 'created': '2020-05-19T17:09:43.564120', 'is_organization': True, 'approval_status': 'approved', 'state': 'active'}, 'num_tags': 3, 'tags': [{'display_name': 'diario oficial', 'id': '6eccd3f9-886e-45bc-a9d7-3a86d6f49d85', 'name': 'diario oficial', 'state': 'active', 'vocabulary_id': None}, {'display_name': 'imprensa', 'id': '7e78788b-a7f8-4857-a597-9702fcabb5fb', 'name': 'imprensa', 'state': 'active', 'vocabulary_id': None}, {'display_name': 'lei', 'id': '0a716590-9eef-41f6-a0ab-a9cf55b6d2cb', 'name': 'lei', 'state': 'active', 'vocabulary_id': None}], 'relationships_as_object': [], 'relationships_as_subject': [], 'download_type': 'Link Externo'}
# --------------------
# diario-oficial-do-estado-do-espirito-santo
# --------------------
# diario-oficial-do-estado-do-maranhao
# --------------------
# diario-oficial-do-estado-do-mato-grosso-do-sul
# --------------------
# diario-oficial-do-estado-do-para
# --------------------
# diario-oficial-do-estado-do-parana
# --------------------
# diario-oficial-do-estado-do-piaui
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/d9/_9rrlqns6mb8xlw_314gg7480000gn/T/ipykernel_99390/1595169971.py in <module>
#       4     api_url = ORIGINAL_CKAN_URL + f'/api/3/action/package_show?id={p}'
#       5     content = requests.get(api_url).json()['result']
# ----> 6     errs = validate(migrate(content))
#       7     if errs:
#       8         print(errs)
#
# /var/folders/d9/_9rrlqns6mb8xlw_314gg7480000gn/T/ipykernel_99390/3344547377.py in validate(package_dict)
#       4         package_dict['extras'] = [kv for kv in package_dict.get('extras') if 'key' in kv and 'value' in kv] # there is a strange bug splitting extra dicts into dicts missing value and key, so we simply remove these, we aren't validating extras anyway
#       5     try:
# ----> 6         basedosdados.action.package_validate(**package_dict)
#       7     except ckanapi.errors.ValidationError as e:
#       8         return e.error_dict['message']
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/ckanapi/common.py in action(**kwargs)
#      49                     data_dict=nonfiles,
#      50                     files=files)
# ---> 51             return self._ckan.call_action(name, data_dict=kwargs)
#      52         return action
#      53
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/ckanapi/remoteckan.py in call_action(self, action, data_dict, context, apikey, files, requests_kwargs)
#      90             status, response = self._request_fn_get(url, data_dict, headers, requests_kwargs)
#      91         else:
# ---> 92             status, response = self._request_fn(url, data, headers, files, requests_kwargs)
#      93         return reverse_apicontroller_action(url, status, response)
#      94
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/ckanapi/remoteckan.py in _request_fn(self, url, data, headers, files, requests_kwargs)
#      94
#      95     def _request_fn(self, url, data, headers, files, requests_kwargs):
# ---> 96         r = self.session.post(url, data=data, headers=headers, files=files,
#      97             allow_redirects=False, **requests_kwargs)
#      98         # allow_redirects=False because: if a post is redirected (e.g. 301 due
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     588         """
#     589
# --> 590         return self.request('POST', url, data=data, json=json, **kwargs)
#     591
#     592     def put(self, url, data=None, **kwargs):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/http/client.py in getresponse(self)
#    1347         try:
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#    1351                 self.close()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/http/client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/http/client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
basedosdados.action.package_show(id=packages[0])
# Out:
# ---------------------------------------------------------------------------
# CKANAPIError                              Traceback (most recent call last)
# /var/folders/d9/_9rrlqns6mb8xlw_314gg7480000gn/T/ipykernel_99390/817195717.py in <module>
# ----> 1 basedosdados.action.package_show(id=packages[0])
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/ckanapi/common.py in action(**kwargs)
#      49                     data_dict=nonfiles,
#      50                     files=files)
# ---> 51             return self._ckan.call_action(name, data_dict=kwargs)
#      52         return action
#      53
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/ckanapi/remoteckan.py in call_action(self, action, data_dict, context, apikey, files, requests_kwargs)
#      91         else:
#      92             status, response = self._request_fn(url, data, headers, files, requests_kwargs)
# ---> 93         return reverse_apicontroller_action(url, status, response)
#      94
#      95     def _request_fn(self, url, data, headers, files, requests_kwargs):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/sandbox/lib/python3.9/site-packages/ckanapi/common.py in reverse_apicontroller_action(url, status, response)
#     131
#     132     # don't recognize the error
# --> 133     raise CKANAPIError(repr([url, status, response]))
#
# CKANAPIError: ['http://staging.basedosdados.org/api/action/package_show', 301, '<html>\r\n<head><title>301 Moved Permanently</title></head>\r\n<body>\r\n<center><h1>301 Moved Permanently</h1></center>\r\n<hr><center>nginx/1.19.2</center>\r\n</body>\r\n</html>\r\n']

# %%
for p in packages:
    print(p)
    validate(migrate(
             )
        )

# %%
# basedosdados.action.package_update(
#     **migrate(
#             basedosdados.action.package_show(id=p)))

# %%
migrate(basedosdados.action.package_show(id=p))
# Out:
# {'id': '85eb1869-c619-4ce0-bba6-345582bf728e',
#  'name': 'world-inequality-database',
#  'title': 'World Inequality Database',
#  'type': 'dataset',
#  'notes': 'O World Inequality Database (WID.world) visa fornecer acesso aberto e conveniente ao banco de dados mais amplo disponível sobre a evolução histórica da distribuição mundial de renda e riqueza, tanto dentro dos países como entre países.\r\n\r\nNos últimos quinze anos, o interesse renovado pela evolução de longo prazo da desigualdade de renda e riqueza deu origem a uma literatura florescente. Em particular, uma sucessão de estudos construiu as principais séries de compartilhamento de renda para um grande número de países (ver Thomas Piketty 2001, 2003, T. Piketty e Emmanuel Saez 2003, e os dois volumes multinacionais de renda superior editados por Anthony B. Atkinson e T. Piketty 2007, 2010; ver também AB Atkinson et al. 2011 e Facundo Alvaredo et al. 2013 para pesquisas desta literatura). Esses projetos geraram um grande volume de dados, destinado a ser um recurso de pesquisa para análises adicionais, bem como uma fonte para informar o debate público sobre a desigualdade de renda. Em grande parte, essa literatura segue o trabalho pioneiro de Simon Kuznets, 1953, e A.B. Atkinson e Alan Harrison, 1978, e o estende a muitos outros países e anos.',
#  'author': None,
#  'author_email': None,
#  'maintainer': None,
#  'maintainer_email': None,
#  'state': 'active',
#  'license_id': None,
#  'url': 'https://wid.world/wid-world/',
#  'version': None,
#  'metadata_created': '2019-10-28T03:37:37.717466',
#  'metadata_modified': '2020-11-18T19:42:10.249863',
#  'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc',
#  'private': False,
#  'license_title': None,
#  'num_resources': 1,
#  'resources': [{'availability': 'online',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2019-10-28T03:37:52.068739',
#    'datastore_active': False,
#    'description': '',
#    'format': '',
#    'formato': '',
#    'has_api': 'no',
#    'hash': '',
#    'id': '352f6149-0b82-4a17-a053-e8c49ee33361',
#    'language': ['english'],
#    'last_modified': None,
#    'metadata_modified': '2020-11-18T19:42:10.253907',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'name': 'Baixar',
#    'package_id': '85eb1869-c619-4ce0-bba6-345582bf728e',
#    'position': 0,
#    'resource_type': 'external_link',
#    'size': None,
#    'spatial_coverage': 'internacional',
#    'state': 'active',
#    'temporal_coverage': ['CHECK',
#     2000,
#     2001,
#     2002,
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018,
#     2019,
#     2020],
#    'update_frequency': 'one_year',
#    'url': 'https://wid.world/data/',
#    'url_type': None,
#    'country_ip_address_required': None,
#    'is_free': 'yes',
#    'license': 'mit',
#    'requires_registration': 'no'}],
#  'groups': [{'description': '',
#    'display_name': 'Economia',
#    'id': '52e4efe1-c527-4446-88dc-33ec9af7abb8',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-055720.95356961SjkfwyNTL.png',
#    'name': 'economia',
#    'title': 'Economia'},
#   {'description': '',
#    'display_name': 'População',
#    'id': 'c1990559-75f6-43d0-94f2-8ecfe470b673',
#    'image_display_url': 'http://localhost:5000/uploads/group/2019-09-19-060328.174268381c2abde74ad5fb139f94f5347d0fa6.jpg',
#    'name': 'populacao',
#    'title': 'População'}],
#  'owner_org': '28d498c7-3b25-4809-9c63-315b940b51b8',
#  'organization': {'id': '28d498c7-3b25-4809-9c63-315b940b51b8',
#   'name': 'wid-world',
#   'title': 'WID.WORLD',
#   'type': 'organization',
#   'description': 'wid.world',
#   'image_url': '2019-10-28-033504.328604logo-widworld-blue-x2.png',
#   'created': '2019-10-28T03:35:04.340770',
#   'is_organization': True,
#   'approval_status': 'approved',
#   'state': 'active'},
#  'num_tags': 2,
#  'tags': [{'display_name': 'desigualdade',
#    'id': 'dd915162-d8b4-4d6c-a951-0a5c85c109b6',
#    'name': 'desigualdade',
#    'state': 'active',
#    'vocabulary_id': None},
#   {'display_name': 'renda',
#    'id': '347907c3-92c3-45c9-9fcd-080fcd5e383f',
#    'name': 'renda',
#    'state': 'active',
#    'vocabulary_id': None}],
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'download_type': 'Link Externo'}

# %%
packages
# Out:
# ['aea-rct-registry-dataverse',
#  'a-global-database-on-central-banks-monetary-responses-to-covid-19',
#  'a-global-scale-data-set-of-mining-areas',
#  'al-urayya-project',
#  'anage-the-animal-ageing-and-longevity-database',
#  'analise-de-movimento-durante-covid-19-para-a-america-latina',
#  'a-spatial-database-of-health-facilities-managed-by-the-public-health-sector-in-sub-saharan-africa',
#  'awarded-grants-by-bill-and-melinda-gates-foundation',
#  'bloomberg-billionaires-index',
#  'bp-statistical-review-of-world-energy',
#  'br_abrinq_oca',
#  'br-ana-atlas-esgotos',
#  'br-anvisa-medicamentos-industrializados',
#  'br-ba-feiradesantana-camara-leis',
#  'br-bd-diretorios-brasil',
#  'br-bd-diretorios-data-tempo',
#  'br_camara_atividade_legislativa',
#  'br-denatran-frota',
#  'br-geobr-mapas',
#  'br-ibge-amc',
#  'br-ibge-censo-demografico',
#  'br-ibge-nomes-brasil',
#  'br-ibge-pam',
#  'br-ibge-pib',
#  'br-ibge-pnadc',
#  'br-ibge-pnad-covid',
#  'br-ibge-populacao',
#  'br-ibge-ppm',
#  'br-imprensa-nacional-dou',
#  'br-inep-ideb',
#  'br-inep-indicadores-educacionais',
#  'br-inpe-prodes',
#  'br-ipea-acesso-oportunidades',
#  'br-mapbiomas-estatisticas',
#  'br-mc-auxilio-emergencial',
#  'br-me-caged',
#  'br-me-comex-stat',
#  'br-me-rais',
#  'br-me-socios',
#  'br-mobilidados-indicadores',
#  'br-ms-sim',
#  'br-ms-vacinacao-covid19',
#  'br-seeg-emissoes',
#  'br-sp-alesp',
#  'br-sp-gov-orcamento',
#  'br-sp-gov-ssp',
#  'br-sp-seduc-fluxo-escolar',
#  'br-sp-seduc-idesp',
#  'br-sp-seduc-inse',
#  'br-tesouro-finbra',
#  'br-tse-eleicoes',
#  'br-tse-filiacao-partidaria',
#  'citi-bike-system-data',
#  'civil-rights-data-collection-crdc',
#  'commercial-fish-production-in-the-great-lakes-1867-2015',
#  'congo-soundscapes',
#  'coronavirus-covid-19-vaccinations',
#  'coronavirus-nos-sistemas-penitenciarios-brasileiros',
#  'covid-19-case-surveillance-public-use-data',
#  'covid-border-accountability-project-cobap',
#  'database-of-political-institutions-dpi',
#  'edgar-food-a-global-emission-inventory-of-ghgs-from-the-food-systems',
#  'enslaved-peoples-of-the-historical-slave-trade',
#  'football-data-co-uk',
#  'footstats',
#  'forbes-real-time-billionaires',
#  'gender-quotas-database',
#  'global-abortion-incidence-dataset',
#  'global-burden-of-disease-gbd',
#  'global-dataset-for-seized-and-non-intercepted-illegal-cheetah-trade-acinonyx-jubatus-2010-2019',
#  'ictd-government-revenue-dataset',
#  'light-every-night',
#  'mapping-the-third-republic-a-geographic-information-system-of-france-1870-1940',
#  'mass-shooter-database',
#  'mit-election-data-science-lab',
#  'mundo-onu-adh',
#  'mundo-transfermarkt-competicoes',
#  'openstreetmap',
#  'operabase',
#  'pesquisa-nacional-de-saneamento-basico-pnsb',
#  'pregnancies-births-and-abortions-in-the-united-states-national-and-state-trends-by-age',
#  'projeto-flora-do-brasil-2020',
#  'protein-data-bank-pdb',
#  'sinopses-estatisticas-da-educacao-basica',
#  'sinopses-estatisticas-da-educacao-superior',
#  'sinopses-estatisticas-do-exame-nacional-do-ensino-medio-enem',
#  'sistema-de-informacoes-geograficas-da-mineracao-sigmine',
#  'social-scientists-before-congress',
#  'soil-grids',
#  'transit-costs-project',
#  'tsa-screenings',
#  'unidades-de-conservacao',
#  'u-s-annual-survey-of-state-and-local-government-finances',
#  'u-s-law-schools',
#  'u-s-post-offices',
#  'u-s-state-by-state-spending-on-kids',
#  'utd19',
#  'witch-trials',
#  'world-bank-projects-and-operations',
#  'world-inequality-database']

# %%
a.pop('a')
# Out:
# 1

# %%
a
# Out:
# {}

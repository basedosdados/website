# %% [markdown]
# ## Cabeçalho

# %%
# %load_ext autoreload
# %autoreload 2

from pprint import pprint
import sys
import os, json, re, requests
from ckanapi import RemoteCKAN
import ckanapi.errors
from ckanapi.errors import NotFound, ValidationError
import pandas as pd
import random
import numpy as np

from pathlib import Path
import json

# from ckan_migration import Migrate
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def download_packages(ORIGINAL_CKAN_URL,env):
    api_url = ORIGINAL_CKAN_URL + '/api/3/action/package_search?q=&rows=3000'
    packages = requests.get(api_url, verify=False).json()['result']['results']
    for p in packages:
        if not os.path.isdir(f"packages/"):
            os.mkdir(f'packages/')
        if not os.path.isdir(f"packages/{env}"):
            os.mkdir(f'packages/{env}')
        name= p['name']
        json.dump(p, open(f'packages/{env}/{name}', 'w'))
    return packages

# %%
import inflection

def missing_dataset_id(resource):
	return resource['dataset_id'] is None

def list_resources_with_no_dataset_id(packages):

	l_bdm = []
	l_rest = []

	for package in packages:
		for resource in package['resources']:
			if 'dataset_id' not in resource:
				if resource['resource_type'] == 'bdm_table':
					l_bdm.append({package['name']:resource['name']})
				else:
					l_rest.append({package['name']:resource['name']})
	
	return l_bdm, l_rest

def list_tables_with_no_columns(packages):

	l_bdm = []

	for package in packages:
		for resource in [resource for resource in package['resources'] if resource['resource_type'] == 'bdm_table']:
			if 'columns' not in resource:
				l_bdm.append({package['name']:resource['name']})
	
	return l_bdm

def list_external_links_with_missing_fields(packages):

	l = []

	for package in packages:
		
		for resource in package['resources']:
			
			if resource['resource_type'] in ['external_link']:
				
				if ('url' not in resource):

					l.append({package['name']:resource['name']})
					
	return l

def list_columns_with_missing_fields(packages):

	l = []

	for package in packages:
		
		for resource in package['resources']:
			
			if resource['resource_type'] in ['bdm_table', 'bdm_dictionary']:
				
				if 'columns' not in resource:
					print('{}:{}'.format(package['name'],resource['name']))
				#assert 'columns' in resource
					#print(package['name'], resource['name'])
					#break
				else:
					for column in resource['columns']:
						
						if 'name' not in column:
							l.append(package['name'])

						elif ('bigquery_type' not in column or
							'description' not in column or
							'has_sensitive_data' not in column or
							'covered_by_dictionary' not in column):

							l.append({package['name']:'{}_{}'.format(resource['name'],column['name'])})
					
	return l

def replace_missing_dataset_ids(package):

	dataset_id = inflection.underscore(package['name'])

	for resource in package['resources']:
		
		if 'dataset_id' not in resource or resource['dataset_id'] != dataset_id:
			resource['dataset_id'] = dataset_id
		
	return package

def create_missing_entity_fields(package):

	for i, resource in enumerate(package['resources']):
		
		if 'entity' not in resource:
			package['resources'][i]['entity'] = []
	
	return package

def create_short_description_field(package):

	package['short_description'] = ''

	return package

def create_partner_organization_field(package):
	
	field = {'name': '', 'organization_id': ''}
	
	for i, resource in enumerate(package['resources']):
		if resource['resource_type'] in ['bdm_table', 'information_request']:
			resource['partner_organization'] = field
		package['resources'][i] = resource
	
	return package

def replace_missing_column_fields(package):

	substring_list = ['cpf', 'cnpj', 'nome', 'endereco']

	for resource in package['resources']:
		
		if resource['resource_type'] in ['bdm_table', 'bdm_dictionary']:
			
			assert 'columns' in resource
				#print(package['name'], resource['name'])
				#break

			for column in resource['columns']:
				
				if 'has_sensitive_data' not in column:
					column['has_sensitive_data'] = 'no'
				else:
					if column['has_sensitive_data'] is None:
						if any(substring in column['name'] for substring in substring_list):
							column['has_sensitive_data'] = 'no'
						else:
							column['has_sensitive_data'] = 'yes'
				
				if 'covered_by_dictionary' not in column or column['covered_by_dictionary'] is None:
					column['covered_by_dictionary'] = 'no'

	return package

def migrate_time_unit(package):
	
	for i, resource in enumerate(package['resources']):
		if 'time_unit' not in resource:
			pass
		elif resource['time_unit'] != '':
			
			# converts derived years to year
			if resource['time_unit'] in ['one_year', 'two_years', 'three_years', 'four_years', 'five_years', 'ten_years']:
				updated_time_unit = 'year'
			elif resource['time_unit'] in ['unique', 'recurring', 'uncertain', 'other']:
				updated_time_unit = None
			else:
				updated_time_unit = resource['time_unit']
			
			if 'entity' not in resource or resource['entity'] is None:
				resource['entity'] = updated_time_unit
			elif resource['entity'] is not None and isinstance(resource['entity'], list):
				#resource['entity'] = resource['entity'] + ', ' + resource['time_unit']
				resource['entity'].append(updated_time_unit)
		
		package['resources'][i] = resource

	return package

def migrate_data_cleaning_code_url(package):

	for i, resource in enumerate(package['resources']):
		if resource['resource_type'] == 'bdm_table':
			if 'code_url' in resource['data_cleaned_by']:
				resource['data_cleaning_code_url'] = resource['data_cleaned_by']['code_url']
			else:
				resource['data_cleaning_code_url'] = ''

			updated_field = {}
			for key, value in resource['data_cleaned_by'].items():
				if key != 'code_url':
					updated_field[key] = value
			resource['data_cleaned_by'] = updated_field

		package['resources'][i] = resource

	return package

def migrate_spatial_coverage(package):

	for k, resource in enumerate(package['resources']):
		
		if resource['name'] == 'dicionario':
			del resource['spatial_coverage']
		else:
			if 'spatial_coverage' in resource:
				if resource['spatial_coverage'] == 'all':
					resource['spatial_coverage'] = {'continent': ['all'],
													'country': None,
													'admin1': None,
													'admin2': None}
				elif resource['spatial_coverage'] == 'bra':
					resource['spatial_coverage'] = {'continent': ['south_america'],
													'country': ['bra'],
													'admin1': None,
													'admin2': None}
				else:
					pass

		package['resources'][k] = resource
	
	return package

def subLists(l):
    lists = [[]]
    for i in range(len(l) + 1):
        for j in range(i):
            lists.append(l[j: i])
    return lists

def stepsList(l):

	steps = [l[n]-l[n-1] for n in range(1,len(l))]
	diff = list(set(steps))

	return diff

def migrate_temporal_coverage_field(l):

	if str in [type(element) for element in l]:
		return l
	
	elif len(l) == 1:
		return [str(element) for element in l]
	
	else:
		
		l = sorted(list(set(l))) # to avoid negative steps
		
		steps = [l[n]-l[n-1] for n in range(1,len(l))]
		diff = list(set(steps))
		
		step = min(diff)
		sublists = subLists(l)
		largest_sublists = []
		for element in l:
			sls = [sl for sl in sublists if element in sl and ((len(stepsList(sl)) == 1 and stepsList(sl)[0] == step) or len(sl) == 1)]
			max_sl = max(sls, key=len)
			largest_sublists.append(max_sl)

		lists = [list(item) for item in set(tuple(row) for row in largest_sublists)]

		intervals = []
		for l in lists:

			steps = [l[n]-l[n-1] for n in range(1,len(l))]
			diff = list(set(steps))

			if len(l) == 1:
				intervals.append([str(x) for x in l])
			else:
				if len(diff) == 1:
					first = l[0]
					last = l[-1]
					unit = diff[0]
					intervals.append(['{}({}){}'.format(first, unit, last)])
				else:
					lists = []
					previous_step = steps[0]
					sub_list = [l[0]]
					for i, step in enumerate(steps[1:]):
						if step == previous_step:
							sub_list.append(step)
						else:
							sub_list.append(l[i+1])
							lists.append(sub_list)
							sub_list = []
						previous_step = step
					intervals.append(lists)

		updated_temporal_coverage = sorted([item for sublist in intervals for item in sublist])

		return updated_temporal_coverage
	
def migrate_temporal_coverage(package):

	for i, resource in enumerate(package['resources']):

		if 'temporal_coverage' in resource and resource['temporal_coverage'] is not None and resource['temporal_coverage'] != []:
			try:
				resource['temporal_coverage'] = migrate_temporal_coverage_field(resource['temporal_coverage'])
			except:
				print(resource['name'], resource['temporal_coverage'])
		else:
			resource['temporal_coverage'] = []

		if resource['resource_type'] == 'bdm_table':
			for j, column in enumerate(resource['columns']):
				if 'temporal_coverage' in column and column['temporal_coverage'] is not None and column['temporal_coverage'] != []:
					column['temporal_coverage'] = migrate_temporal_coverage_field(column['temporal_coverage'])
				else:
					column['temporal_coverage'] = []
				
				resource['columns'][j] = column
		
		package['resources'][i] = resource
	
	return package

def list_resources_with_no_entity(packages):

	l = []

	for package in packages:
		for resource in package['resources']:
			if 'entity' not in resource or resource['entity'] == []:
				l.append({package['name']:resource['name']})
	
	return l

def fill_out_observation_level_from_identifying_columns(resource, sols):

	for identifying_column in resource['identifying_columns']:

		# find index of corresponding entity and country
		i = None
		for k, sol in enumerate(sols):
			if sol[2] in identifying_column:
				i = k
		
		# if identifying_column is in standard
		if i is not None:
			country = sols[i][0]
			entity = sols[i][1]

			# if corresponding entity already exists:
			if entity in [ol['entity'] for ol in resource['observation_level'] if 'entity' in ol]:
				
				# paste identifying_column in correct place
				for k, ol in enumerate(resource['observation_level']):
					if 'entity' in ol and ol['entity'] == entity:
						resource['observation_level'][k]['column'] = [identifying_column]
						if 'country' in resource['observation_level'][k]:
							resource['observation_level'][k]['country'] = country
			
			else:
				if country == '':
					dict = {'entity': entity, 'columns': [identifying_column]}
				else:
					dict = {'country': country, 'entity': entity, 'columns': [identifying_column]}
				resource['observation_level'].append(dict)
		
		else:
			dict = {'columns': [identifying_column]}
			resource['observation_level'].append(dict)

	return resource

def migrate_observation_level(package):

	for i, resource in enumerate(package['resources']):
		
		resource['observation_level'] = []

		if resource['name'] == 'dicionario': # `dicionario` has different metadata from `bdm_table`
			pass

		else:
			if 'entity' in resource and resource['entity'] not in [None, []]:
				
				for k, entity in enumerate(resource['entity']):

					# migrate entity
					resource['observation_level'].append({'entity': entity})

					# fill out country for common spatial entities
					if entity in ['municipality', 'district', 'census_tract']:
						resource['observation_level'][k]['country'] = 'bra'
					elif entity in ['county']:
						resource['observation_level'][k]['country'] = 'usa'

			if 'identifying_columns' in resource and resource['identifying_columns'] not in [None, []]:
				
				standard_observation_levels = [
					['', 'year', 'ano'],
					['', 'quarter', 'trimestre'],
					['', 'month', 'mes'],
					['', 'day', 'dia'],
					['', 'date', 'data'],
					['bra', 'state', 'sigla_uf'],
					['bra', 'state', 'id_uf'],
					['bra', 'municipality', 'id_municipio'],
					['bra', 'district', 'id_distrito'],
					['bra', 'census_tract', 'id_setor_censitario'],
				]

				resource = fill_out_observation_level_from_identifying_columns(resource, standard_observation_levels)
			
		package['resources'][i] = resource

	return package

def migrate_partitions_field(package):

	for k, resource in enumerate(package['resources']):
		if resource['resource_type'] == 'bdm_table':
			if 'partitions' in resource and resource['partitions'] not in [None, '']:
				if type(resource['partitions']) == list:
					pass
				else:
					resource['partitions'] = resource['partitions'].replace(",", " ")
					resource['partitions'] = resource['partitions'].split()
			else:
				resource['partitions'] = []

		package['resources'][k] = resource
		
	return package

def list_datasets(packages, condition):

	l = []

	for package in packages:
		for resource in package['resources']:
			if resource['resource_type'] == 'bdm_table':
				if condition(resource):
					l.append(package['name'])
					break
	
	return l

def delete_package_field(package, field):

	updated_package = {}

	for key, value in package.items():
		if key != field:
			updated_package[key] = value

	return updated_package

def delete_package_dataset_id(package):

	package['extras'][0]['value'] = {}

	return package

def delete_resource_field(package, resource_type, field):

	for i, resource in enumerate(package['resources']):
		if resource['resource_type'] == resource_type:
			updated_resource = {}
			for key, value in resource.items():
				if key != field:
					updated_resource[key] = value
			package['resources'][i] = updated_resource
	
	return package

# %% [markdown]
# ## Download packages

# %%
LOCAL_CKAN_URL = 'http://localhost'
DEV_CKAN_URL = 'https://staging.basedosdados.org'
PROD_CKAN_URL = 'https://basedosdados.org'

local_packages = download_packages(LOCAL_CKAN_URL,'prod')
dev_packages = download_packages(DEV_CKAN_URL,'dev')
prod_packages = download_packages(PROD_CKAN_URL,'prod')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'staging.basedosdados.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'basedosdados.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ## Validation

# %%
packages = local_packages

#list_resources_with_no_dataset_id(packages)
#list_tables_with_no_columns(packages)
#list_external_links_with_missing_fields(packages)
list_resources_with_no_entity(packages) # necessary to make (bdm_table, external_link, information_request).observation_level
										# a required field
list_columns_with_missing_fields(packages)

# %% [markdown]
# ## Migration

# %%
class Migrator:
    def __init__(self, ckan_remote: RemoteCKAN, package_dict):
        self.ckan_remote = ckan_remote
        self.package_dict = package_dict

    def create(self):
        try:
            self.ckan_remote.action.package_create(**self.package_dict)
        except NotFound as e:
            print(e)
    
    def update(self):
        try:
            self.ckan_remote.action.package_update(**self.package_dict)
        except NotFound as e:
            print(e)
            
    def purge(self):
        try:
            self.ckan_remote.action.dataset_purge(id=self.package_dict['name'])
        except NotFound as e:
            print(e)
   
    def delete(self):
        try:
            self.ckan_remote.action.package_delete(id=self.package_dict['name'])
        except NotFound as e:
            print(e)
	
    def validate(self):
        try:
            self.ckan_remote.action.package_validate(**self.package_dict)
        except NotFound as e:
            print(e)

# %%
import copy

packages = copy.deepcopy(prod_packages)
updated_packages = []

for i, package in enumerate(packages):

	print(i, '-', package['name'])

	updated_package = packages[i]

	updated_package = delete_package_dataset_id(updated_package)
	updated_package = replace_missing_dataset_ids(updated_package)
	updated_package = create_missing_entity_fields(updated_package)
	updated_package = create_short_description_field(updated_package)
	updated_package = create_partner_organization_field(updated_package)
	
	updated_package = delete_package_field(updated_package, 'spatial_coverage')
	updated_package = delete_package_field(updated_package, 'temporal_coverage')
	updated_package = delete_package_field(updated_package, 'update_frequency')
	updated_package = delete_package_field(updated_package, 'entity')
	updated_package = delete_package_field(updated_package, 'time_unit')
	updated_package = delete_package_field(updated_package, 'download_type')
	
	updated_package = migrate_spatial_coverage(updated_package)
	updated_package = migrate_temporal_coverage(updated_package)
	updated_package = migrate_observation_level(updated_package)

	updated_package = migrate_partitions_field(updated_package)
	
	updated_package = delete_resource_field(updated_package, 'bdm_table', 'entity')
	updated_package = delete_resource_field(updated_package, 'bdm_table', 'identifying_columns')
	updated_package = delete_resource_field(updated_package, 'bdm_table', 'covered_by_dictionary')
	updated_package = delete_resource_field(updated_package, 'bdm_table', 'time_unit')
	updated_package = delete_resource_field(updated_package, 'bdm_table', 'formato')
	updated_package = delete_resource_field(updated_package, 'bdm_table', 'bdm_file_size')

	updated_package = migrate_data_cleaning_code_url(updated_package)

	updated_package = delete_resource_field(updated_package, 'external_link', 'entity')
	updated_package = delete_resource_field(updated_package, 'external_link', 'identifying_columns')
	updated_package = delete_resource_field(updated_package, 'external_link', 'time_unit')
	updated_package = delete_resource_field(updated_package, 'external_link', 'formato')
	
	updated_package = migrate_time_unit(updated_package)

	updated_package = replace_missing_column_fields(updated_package)

	updated_packages.append(updated_package)
# Out:
# 0 - br-ana-atlas-esgotos
# 1 - br-bd-diretorios-brasil
# 2 - centennia-historical-atlas
# 3 - br-anatel-banda-larga-fixa
# 4 - br-me-siconfi
# 5 - br-ba-feiradesantana-camara-leis
# 6 - br-ms-cnes
# 7 - br-me-caged
# 8 - br-ana-reservatorios
# 9 - br-ibge-ipca15
# 10 - br-ibge-inpc
# 11 - br-ibge-populacao
# 12 - br-anatel-telefonia-movel
# 13 - br-abrinq-oca
# 14 - br-ibge-ipca
# 15 - br-tse-eleicoes
# 16 - br-ms-sinan
# 17 - br-ms-vacinacao-covid19
# 18 - br-ons-energia-armazenada
# 19 - br-ibge-pib
# 20 - mundo-onu-adh
# 21 - br-sp-alesp
# 22 - br-geobr-mapas
# 23 - br-ibge-pnad
# 24 - br-poder360-pesquisas
# 25 - justica-aberta
# 26 - br-ibge-pnadc
# 27 - br-bd-indicadores
# 28 - br-me-rais
# 29 - br-bd-diretorios-mundo
# 30 - mundo-bm-learning-poverty
# 31 - br-ms-imunizacoes
# 32 - br-mme-consumo-energia-eletrica
# 33 - br-inep-indicador-nivel-socioeconomico
# 34 - br-inep-formacao-docente
# 35 - br-ms-sinasc
# 36 - linchamentos-beck-and-tolnay-1995
# 37 - mundo-transrespect-transphobia
# 38 - terremotos-no-mexico
# 39 - national-elections-across-democracy-and-autocracy
# 40 - br-cgu-servidores-executivo-federal
# 41 - barro-lee-education-attainment-dataset
# 42 - github-typo-corpus
# 43 - standardized-world-income-inequality-database-swiid
# 44 - br-ibge-cbo-2002
# 45 - mundo-kaggle-olimpiadas
# 46 - eu-fra-lgbt
# 47 - br-ggb-relatorio-lgbtqi
# 48 - br-mc-indicadores
# 49 - br-isp-estatisticas-seguranca
# 50 - br-inmet-bdmep
# 51 - br-me-comex-stat
# 52 - br-imprensa-nacional-dou
# 53 - br-inep-enem
# 54 - br-bd-vizinhanca
# 55 - br-mc-auxilio-emergencial
# 56 - br-inep-ana
# 57 - br-seeg-emissoes
# 58 - br-tse-filiacao-partidaria
# 59 - br-ms-populacao
# 60 - br-ibge-censo-demografico
# 61 - br-anp-precos-combustiveis
# 62 - br-sp-gov-ssp
# 63 - acaps-covid-19-government-measures-dataset
# 64 - acessos-de-telefonia-fixa-no-brasil
# 65 - acessos-dos-servicos-de-tv-por-assinatura-no-brasil
# 66 - achados-e-pedidos
# 67 - acidentes-de-transito
# 68 - a-complete-catalog-of-every-time-someone-cursed-or-bled-out-in-a-quentin-tarantino-movie
# 69 - aea-rct-registry-dataverse
# 70 - africa-integrity-indicators
# 71 - afrobarometer
# 72 - ageguess
# 73 - a-global-database-on-central-banks-monetary-responses-to-covid-19
# 74 - a-global-scale-data-set-of-mining-areas
# 75 - agrofit
# 76 - agrolink-fito
# 77 - aiddata-s-geocoded-global-chinese-official-finance
# 78 - ajuda-internacional-usaid
# 79 - aldeias-indigenas-sistema-indigenista-de-informacoes
# 80 - alistados-no-servico-militar
# 81 - allsides-media-bias-chart
# 82 - al-urayya-project
# 83 - amazonia-minada
# 84 - american-cabinet-appointments
# 85 - american-national-election-studies-anes
# 86 - american-time-use-survey-atus
# 87 - americasbarometer
# 88 - anage-the-animal-ageing-and-longevity-database
# 89 - analise-de-movimento-durante-covid-19-para-a-america-latina
# 90 - analytics-usa-gov
# 91 - antarctic-iceberg-tracking-database
# 92 - anuario-brasileiro-de-seguranca-publica
# 93 - anuario-estatistico-da-antaq
# 94 - anuario-estatistico-da-previdencia-social-aeps
# 95 - anuario-estatistico-de-acidentes-do-trabalho-aeat
# 96 - api-of-ice-and-fire
# 97 - arab-barometer
# 98 - archigos
# 99 - armas-apreendidas-por-delegacia-de-policia-rj
# 100 - armas-municoes-e-equipamentos-desviados
# 101 - armed-conflict-location-event-data-acled
# 102 - arquivo-do-gabriel-garcia-marquez
# 103 - arrecadacao-emissao-de-vistos-entre-2010-e-2019-por-posto
# 104 - artificial-intelligence-index-report
# 105 - artigo-19-violacoes-a-liberdade
# 106 - arxiv-open-archives
# 107 - a-shell-dataset-for-shell-features-extraction-and-recognition
# 108 - asian-barometer
# 109 - a-spatial-database-of-health-facilities-managed-by-the-public-health-sector-in-sub-saharan-africa
# 110 - atlas-da-noticia
# 111 - atlas-da-violencia
# 112 - atlas-de-mortalidade-por-cancer
# 113 - atlas-do-estado-brasileiro
# 114 - atlas-etnografico
# 115 - atlas-of-historical-county-boundaries
# 116 - atlas-of-the-human-planet
# 117 - a-tracker-of-trackers-covid-19-policy-responses-and-data
# 118 - at-the-circulating-library-a-database-of-victorian-fiction-1837-1901
# 119 - authoritarian-ruling-elites-database-ared
# 120 - autuacoes-ambientais-e-embargos
# 121 - avaliacao-nacional-da-alfabetizacao
# 122 - average-happiness-for-twitter
# 123 - awarded-grants-by-bill-and-melinda-gates-foundation
# 124 - baci
# 125 - balanca-comercial-brasileira
# 126 - banco-de-dados-da-wikipedia
# 127 - banco-de-dados-de-queimadas
# 128 - banco-de-dados-geodesicos-bdg
# 129 - banco-de-pesquisas-de-opiniao-publica
# 130 - banco-nacional-de-monitoramento-de-prisoes-bnmp
# 131 - base-de-dados-de-seguranca-cidada
# 132 - base-monetaria-papel-moeda-emitido
# 133 - basketball-reference
# 134 - bb-integra
# 135 - beneficios-do-instituto-nacional-de-seguro-social-inss
# 136 - berkeley-earth-air-pollution
# 137 - berkeley-earth-surface-temperature
# 138 - best-hip-hop-songs-of-all-time
# 139 - bible-api-com
# 140 - bloomberg-billionaires-index
# 141 - board-game-geek-bgg
# 142 - boletim-epidemiologico-da-secretaria-especial-de-saude-indigena-sesai
# 143 - boletim-estatistico-da-previdencia-social-beps
# 144 - bolsa-familia
# 145 - bolsas-e-auxilios-pagos
# 146 - bolsa-verde
# 147 - bounty-targets-data
# 148 - bp-statistical-review-of-world-energy
# 149 - br-anvisa-medicamentos-industrializados
# 150 - brazilian-electoral-panel-studies-beps
# 151 - br-bd-diretorios-data-tempo
# 152 - br-denatran-frota
# 153 - breaking-trust-software-supply-chain-attacks
# 154 - br-ibge-amc
# 155 - br-ibge-nomes-brasil
# 156 - br-ibge-pam
# 157 - br-ibge-pnad-covid
# 158 - br-ibge-ppm
# 159 - br-inep-censo-escolar
# 160 - br-inep-ideb
# 161 - br-inep-indicadores-educacionais
# 162 - br-inpe-prodes
# 163 - br-ipea-acesso-oportunidades
# 164 - british-social-attitudes-bsa
# 165 - br-mapbiomas-estatisticas
# 166 - br-me-pensionistas
# 167 - br-me-socios
# 168 - br-mobilidados-indicadores
# 169 - br-ms-sim
# 170 - br-rj-rio-de-janeiro-ipp-ips
# 171 - br-senado-cpipandemia
# 172 - br-sp-gov-orcamento
# 173 - br-sp-seduc-fluxo-escolar
# 174 - br-sp-seduc-idesp
# 175 - br-sp-seduc-inse
# 176 - cadastro-ambiental-rural
# 177 - cadastro-empresas-brasileiras-exportadoras-e-importadoras
# 178 - cadastro-nacional-de-florestas-publicas-cnfp
# 179 - cadastro-nacional-de-produtores-organicos
# 180 - cadastro-unico
# 181 - california-license-plates
# 182 - campus-expression-survey-ces
# 183 - capacidade-de-pagamento-capag-de-estados-e-municipios
# 184 - carga-horaria-por-docente-sao-paulo
# 185 - cartografia-dos-ataques-contra-indigenas-caci
# 186 - caselaw-access-project-cap
# 187 - casos-de-covid-19-no-brasil
# 188 - catalogo-de-escolas
# 189 - catalogue-of-bias
# 190 - caucasus-barometer
# 191 - cdc-s-social-vulnerability-index-svi
# 192 - cedulas-falsas-por-ano-e-estado
# 193 - censo-agropecuario
# 194 - censo-anual-da-igreja-catolica
# 195 - censo-da-educacao-superior
# 196 - censo-de-poblacion-y-vivienda-cpv
# 197 - censo-do-poder-judiciario
# 198 - censo-do-sistema-unico-de-assistencia-social-suas
# 199 - censo-dos-profissionais-do-magisterio
# 200 - censo-e-pesquisa-nacional-sobre-a-populacao-em-situacao-de-rua
# 201 - censo-gife
# 202 - censo-legislativo
# 203 - census-of-fatal-occupational-injuries-cfoi
# 204 - census-transportation-planning-products-ctpp
# 205 - centennial-earthquake-catalog
# 206 - central-database-of-shoah-victims-names
# 207 - central-european-art-database-cead
# 208 - centros-de-convivencia-de-idosos
# 209 - ceps-eurlex
# 210 - certificacao-quilombola
# 211 - chegada-de-turistas-internacionais
# 212 - chicago-citizens-police-data-project-cpdp-co
# 213 - china-biographical-database-project-cbdb
# 214 - china-s-public-diplomacy-dashboard-dataset
# 215 - china-statistical-yearbook
# 216 - cidades-do-mundo
# 217 - cidades-dos-eua
# 218 - citi-bike-system-data
# 219 - citybikes
# 220 - civil-rights-data-collection-crdc
# 221 - classificacao-brasileira-de-ocupacoes-cbo
# 222 - classificacao-de-agrotoxicos-e-cancerigenos-do-iarc
# 223 - classificacao-de-genero-em-nomes-brasileiros
# 224 - climate-action-tracker-cat
# 225 - climate-change-in-the-contiguous-united-states
# 226 - climate-data-record-cdr-of-normalized-difference-vegetation-index-ndvi
# 227 - climate-divisional-database-nclimdiv
# 228 - climate-hazards-center-chc
# 229 - climate-policy-database
# 230 - cockatoo-island-convicts
# 231 - codigos-dos-municipios-ibge
# 232 - codigos-nacionais-ddd
# 233 - colecao-de-cnpjs-e-cpfs-brasileiros
# 234 - collective-actions-in-tech
# 235 - college-scorecard
# 236 - commercial-fish-production-in-the-great-lakes-1867-2015
# 237 - community-earth-system-model-cesm
# 238 - comparative-competition-law
# 239 - comparative-constitutions-project-ccp
# 240 - comparative-income-taxation-database-citd
# 241 - complaints-against-new-york-police-department-officers
# 242 - comprehensive-food-consumption-database
# 243 - comtrade
# 244 - conflitos-no-campo
# 245 - confronting-the-demographics-of-power-america-s-sheriffs
# 246 - congo-soundscapes
# 247 - congressional-record-for-the-43rd-114th-congresses-parsed-speeches-and-phrase-counts
# 248 - consumer-expenditure-surveys-ce
# 249 - contratacoes-do-senado-federal
# 250 - contratos-de-marketing-e-publicidade-em-turismo
# 251 - contratos-federais
# 252 - convenios
# 253 - corelogic-housing-data
# 254 - coronavirus-2019-ncov-global-cases
# 255 - coronavirus-covid-19-vaccinations
# 256 - coronavirus-impact-dashboard
# 257 - coronavirus-nos-sistemas-penitenciarios-brasileiros
# 258 - correlates-of-war-territorial-change
# 259 - correlates-of-war-war-data
# 260 - corruption-perceptions-index-cpi
# 261 - country-reports-on-terrorism
# 262 - covid-19-case-surveillance-public-use-data
# 263 - covid-19-community-mobility-reports
# 264 - covid-19-data-resources-for-india
# 265 - covid-19-economic-stimulus-index
# 266 - covid-19-mobility-trends-reports
# 267 - covid-19-nas-favelas-do-rio-de-janeiro
# 268 - covid-19-no-brasil-io
# 269 - covid-19-open-research-dataset-cord-19
# 270 - covid-19-outbreak-panel
# 271 - covid-19-preprints
# 272 - covid-border-accountability-project-cobap
# 273 - credibly-accused-priests
# 274 - crime-in-the-u-s
# 275 - crimes-against-humanity-in-punjab-india
# 276 - crises-fiscais
# 277 - cropscape-cropland-data-layer
# 278 - cross-national-time-series-cnts-data-archive
# 279 - crowd-sourced-covid-19-dataset-tracking-involuntary-government-restrictions-tigr
# 280 - culture-under-threat-map
# 281 - current-population-survey-cps
# 282 - dados-da-educacao-brasileira
# 283 - dados-do-conflito-no-west-bank-em-israel
# 284 - dados-estatisticos-da-anac
# 285 - darknet-market-mortality-risks
# 286 - dartmouth-flood-observatory
# 287 - database-of-accredited-postsecondary-institutions-and-programs-dapip
# 288 - database-of-political-institutions-dpi
# 289 - data-informasi-bencana-indonesia-dibi
# 290 - dataluta
# 291 - data-on-covid-19-maintained-by-our-world-in-data
# 292 - democracy-index
# 293 - demographic-and-health-surveys-dhs
# 294 - design-of-international-trade-agreements-desta
# 295 - desmatamento-global-forest-cover
# 296 - despesas-pela-cota-para-exercicio-da-atividade-parlamentar
# 297 - despesas-publicas
# 298 - devedores-da-uniao
# 299 - diario-oficial-do-estado-da-bahia
# 300 - diario-oficial-do-estado-da-paraiba
# 301 - diario-oficial-do-estado-de-alagoas
# 302 - diario-oficial-do-estado-de-goias
# 303 - diario-oficial-do-estado-de-mato-grosso
# 304 - diario-oficial-do-estado-de-minas-gerais
# 305 - diario-oficial-do-estado-de-pernambuco
# 306 - diario-oficial-do-estado-de-rondonia
# 307 - diario-oficial-do-estado-de-roraima
# 308 - diario-oficial-do-estado-de-santa-catarina
# 309 - diario-oficial-do-estado-de-sao-paulo
# 310 - diario-oficial-do-estado-de-sergipe
# 311 - diario-oficial-do-estado-de-tocantins
# 312 - diario-oficial-do-estado-do-acre
# 313 - diario-oficial-do-estado-do-amapa
# 314 - diario-oficial-do-estado-do-amazonas
# 315 - diario-oficial-do-estado-do-ceara
# 316 - diario-oficial-do-estado-do-distrito-federal
# 317 - diario-oficial-do-estado-do-espirito-santo
# 318 - diario-oficial-do-estado-do-maranhao
# 319 - diario-oficial-do-estado-do-mato-grosso-do-sul
# 320 - diario-oficial-do-estado-do-para
# 321 - diario-oficial-do-estado-do-parana
# 322 - diario-oficial-do-estado-do-piaui
# 323 - diario-oficial-do-estado-do-rio-de-janeiro
# 324 - diario-oficial-do-estado-do-rio-grande-do-norte
# 325 - diario-oficial-do-estado-do-rio-grande-do-sul
# 326 - directions-of-trade-statistics-dots
# 327 - diretorio-nacional-de-enderecos-dne
# 328 - discogs
# 329 - discursos-membros-do-banco-central-europeu
# 330 - distribuicao-geografica-do-programa-mais-medicos-pmm
# 331 - diversifying-economics-seminars-speakers-list
# 332 - doacoes-de-campanha
# 333 - documento-de-origem-florestal-dof
# 334 - doing-business
# 335 - domains-project
# 336 - dominios-gov-br
# 337 - dsny-monthly-tonnage-data
# 338 - dying-inside-jail-deaths-in-america
# 339 - earthstat
# 340 - economia-informal-urbana
# 341 - economic-policy-uncertainty-epu
# 342 - edgar-food-a-global-emission-inventory-of-ghgs-from-the-food-systems
# 343 - elas-no-congresso
# 344 - election-betting-odds
# 345 - electoral-contention-and-violence-ecav
# 346 - electronic-army-serial-number-merged-file-ca-1938-1946
# 347 - emendas-parlamentares
# 348 - employment-protection-legislation-database-eplex
# 349 - empreendimentos-turisticos-acessiveis
# 350 - encyclopaedia-britannica-1768-1860
# 351 - england-s-immigrants-1330-1550
# 352 - enslaved-peoples-of-the-historical-slave-trade
# 353 - environmental-performance-index-epi
# 354 - eopp-indian-states-data
# 355 - epsg-io-coordinate-systems-worldwide
# 356 - estatistica-bancaria
# 357 - estatisticas-da-previdencia-social-por-municipio
# 358 - estatisticas-de-comercio-exterior-do-agronegocio-brasileiro-agrostat
# 359 - estatisticas-de-seguranca-por-delegacia-de-policia-rj
# 360 - estatisticas-do-futebol
# 361 - estatisticas-do-registro-civil
# 362 - estatisticas-futebol-brasileiro
# 363 - estatisticas-sobre-acidentes-de-trabalho
# 364 - estatisticas-sobre-microempreendedores-individuais-mei
# 365 - estatisticas-sobre-simples-nacional
# 366 - estoque-da-divida-publica-federal
# 367 - estrangeiros-resgatados-em-situacao-analoga-a-escravidao
# 368 - eurobarometer
# 369 - european-population-demography-population-projections-census-asylum-and-migration
# 370 - european-settlement-map-esm
# 371 - european-union-consolidated-financial-sanctions-list
# 372 - eva-evidencias-sobre-violencias-e-alternativas-para-mulheres-e-meninas
# 373 - eventos-da-camara-lista-orgaos-realizadores-deputados-presentes
# 374 - eventos-turisticos
# 375 - every-politician
# 376 - exame-nacional-de-desempenho-dos-estudantes
# 377 - exame-nacional-do-ensino-medio
# 378 - exame-nacional-para-certificacao-de-competencias-de-jovens-e-adultos
# 379 - executive-approval-project-eap
# 380 - exposure-indices-derived-from-placeiq-movement-data
# 381 - faostat-land-use
# 382 - fastercures-covid-19
# 383 - fatal-encounters
# 384 - fatality-analysis-reporting-system-fars
# 385 - favicons
# 386 - federal-employee-viewpoint-survey-fevs
# 387 - feminicidio-por-delegacia-de-policia-rj
# 388 - feminicidio-sp
# 389 - financial-access-survey-fas
# 390 - fire-disinvitation-database
# 391 - fire-information-for-resource-management-system-firms
# 392 - fire-spotlight-database
# 393 - fivethirtyeight-s-pollster-ratings
# 394 - flightradar24
# 395 - flights-in-and-out-of-san-francisco-airport
# 396 - fluxos-de-comercio-em-agropecuaria
# 397 - football-data-co-uk
# 398 - footstats
# 399 - forbes-real-time-billionaires
# 400 - foreign-terrorist-organizations
# 401 - freedom-of-information-act-annual-reports-1975-2018
# 402 - frentes-parlamentares
# 403 - full-emoji-list
# 404 - future-hydropower-reservoirs-and-dams-database-fhred
# 405 - galerias-artistas-e-casas-de-leilao-de-arte-no-mundo
# 406 - gemstat
# 407 - gender-quotas-database
# 408 - general-social-survey
# 409 - genomic-data-commons-gdc
# 410 - geocoded-peacekeeping-operations-geo-pko
# 411 - geographically-based-economic-data-g-econ
# 412 - geopresidios-radiografia-do-sistema-prisional
# 413 - geothermal-data-repository-gdr
# 414 - gestao-de-pessoas-do-senado-federal-administrativo
# 415 - gestao-de-pessoas-executivo-federal-aposentados
# 416 - gestao-de-pessoas-executivo-federal-cargo-de-direcao-e-assessoramento-superiores-das
# 417 - gestao-de-pessoas-executivo-federal-pensionistas
# 418 - glad-alerts-footprint
# 419 - global-abortion-incidence-dataset
# 420 - global-administrative-unit-layers-gaul
# 421 - global-atlas-for-renewable-energy
# 422 - global-attitudes-on-abortion
# 423 - global-burden-of-disease-gbd
# 424 - global-carbon-atlas
# 425 - global-carbon-budget
# 426 - global-competitiveness-report-gcr
# 427 - global-corruption-barometer-gcb
# 428 - global-dataset-for-seized-and-non-intercepted-illegal-cheetah-trade-acinonyx-jubatus-2010-2019
# 429 - global-debt-database-gdd
# 430 - global-development-network-growth-database-gdngd
# 431 - global-georeferenced-database-of-dams-goodd
# 432 - global-health-security-index
# 433 - global-human-settlement-ghs-built
# 434 - global-human-settlement-model-ghs-smod
# 435 - global-human-settlement-population-ghs-pop
# 436 - global-land-one-km-base-elevation-project-globe
# 437 - global-observatory-for-physical-activity-country-cards
# 438 - global-open-data-index-godi
# 439 - global-party-survey-gps
# 440 - globalpetrolprices-com
# 441 - global-power-plant-database
# 442 - global-preferences-survey-gps
# 443 - global-reservoir-and-dam-database-grand
# 444 - global-slavery-index
# 445 - global-solar-atlas
# 446 - global-terrorism-database-gtd
# 447 - global-terrorism-index
# 448 - global-transnational-mobility-dataset
# 449 - global-visa-cost-dataset
# 450 - global-wind-atlas
# 451 - gm-approval-database
# 452 - govinfo
# 453 - govtrack-us-tracking-the-u-s-congress
# 454 - gridded-5km-ghcn-daily-temperature-and-precipitation-dataset-nclimgrid
# 455 - gridded-population-of-the-world-gpw
# 456 - h1b-salary-database
# 457 - hate-crime-in-the-u-s
# 458 - healthmap-novel-coronavirus-covid-19
# 459 - historia-de-tentativas-de-assassinato-politico-1875-2004
# 460 - historical-empires
# 461 - historical-light-aids-to-navigation-1514-1911
# 462 - historico-de-matriculas-por-turma-sao-paulo
# 463 - houston-police-department-shootings
# 464 - human-development-reports
# 465 - human-fertility-database-hfd
# 466 - human-life-table-database-hld
# 467 - human-mortality-database-hmd
# 468 - ibge-paises
# 469 - icij-offshore-leaks-database
# 470 - ictd-government-revenue-dataset
# 471 - imagenet
# 472 - imdb-datasets
# 473 - immunization-vaccines-and-biologicals
# 474 - imoveis-da-uniao
# 475 - importacoes-e-exportacoes-de-petroleo
# 476 - incendios-em-unidades-de-conservacao-federais
# 477 - indenizacoes-dos-beneficiados-pela-lei-10-559-2002-anistiados-do-ministerio-da-defesa
# 478 - india-human-development-survey-ihds
# 479 - indicador-de-diferenca-entre-os-desempenhos-observado-e-esperado
# 480 - indicadores-da-distribuicao-de-energia-eletrica
# 481 - indicadores-de-qualidade-da-banda-larga-fixa-scm-no-brasil
# 482 - indicadores-de-qualidade-do-servico-de-telefonia-fixa-stfc-no-brasil
# 483 - indicadores-de-qualidade-do-servico-de-telefonia-movel-smp-no-brasil
# 484 - indicadores-de-qualidade-dos-servicos-de-tv-por-assinatura-stva-no-brasil
# 485 - indicadores-programa-mais-medicos-pmm
# 486 - indicadores-sociais-minimos
# 487 - indice-de-competitividade-em-turismo
# 488 - indice-de-progresso-social-na-amazonia-brasileira
# 489 - indice-nacional-de-precos-ao-consumidor-amplo-ipca
# 490 - indonesia-administrative-level-0-4-boundaries
# 491 - indonesia-database-for-policy-and-economic-research-indo-dapoer
# 492 - influence-watch
# 493 - infogov
# 494 - info-gripe
# 495 - informacoes-indigenas
# 496 - inside-airbnb
# 497 - integrated-civil-society-organizations-system-icso
# 498 - integrated-crisis-early-warning-system-icews
# 499 - integrated-postseondary-education-data-system-ipeds
# 500 - interactive-terminology-for-europe-iate
# 501 - international-banking-statistics-ibs
# 502 - international-bathymetric-chart-of-the-arctic-ocean-ibcao
# 503 - international-environmental-agreements-iea-database-project
# 504 - international-registry-of-seismograph-stations-ir
# 505 - international-social-survey-programme-issp
# 506 - international-survey-on-coronavirus
# 507 - internet-archive
# 508 - intra-american-slave-trade-database
# 509 - iowa-liquor-sales
# 510 - ipardes-base-de-dados-do-estado-bdeweb
# 511 - ipu-parline
# 512 - journalists-killed
# 513 - justica-em-numeros
# 514 - kaokore-a-pre-modern-japanese-art-facial-expression-dataset
# 515 - killed-by-police
# 516 - kworb-net
# 517 - large-logo-dataset-lld
# 518 - latin-american-human-mortality-database
# 519 - latin-american-migration-project-lamp
# 520 - latinobarometro
# 521 - leader-statement-database
# 522 - learning-and-educational-achievement-in-punjab-schools-leaps
# 523 - leg-go
# 524 - leiden-ranking
# 525 - leis-estaduais
# 526 - leis-municipais
# 527 - letourdataset
# 528 - levantamento-nacional-de-informacoes-penitenciarias-infopen
# 529 - licitacoes-federais
# 530 - light-every-night
# 531 - light-pollution-map
# 532 - lista-de-cartorios
# 533 - lista-de-devedores-da-pgfn
# 534 - lista-de-dominios-fr
# 535 - listagem-dos-organismos-de-avaliacao-da-conformidade-organica-oac
# 536 - list-of-dirty-naughty-obscene-and-otherwise-bad-words
# 537 - living-planet-index-lpi
# 538 - living-standards-measurement-study-lsms
# 539 - lobbyfacts-eu
# 540 - lobbyview
# 541 - long-term-productivity-database
# 542 - macimide-global-expatriate-dual-citizenship-dataset
# 543 - macro-financial-dataset
# 544 - maddison-project-database-for-historical-development
# 545 - malha-municipal
# 546 - manchas-de-oleo-no-litoral-brasileiro
# 547 - manifesto-project
# 548 - mapa-das-franquias
# 549 - mapa-das-ongs-no-brasil
# 550 - mapa-das-organizacoes-da-sociedade-civil
# 551 - mapa-de-feiras-organicas
# 552 - mapa-do-turismo-brasileiro
# 553 - mapa-mundo-paises
# 554 - mapas-da-infraestrutura
# 555 - mapas-multimodais
# 556 - mapbiomas-alerta
# 557 - mapping-application-for-penguin-populations-and-projected-dynamics-mapppd
# 558 - mapping-militants
# 559 - mapping-police-violence
# 560 - mapping-the-gay-guides-mgg
# 561 - mapping-the-third-republic-a-geographic-information-system-of-france-1870-1940
# 562 - marine-and-hydrokinetic-data-repository-mhk
# 563 - marinetraffic
# 564 - mass-mobilization-project-mm
# 565 - mass-shooter-database
# 566 - matriz-de-dados-do-credito-rural-mdcr
# 567 - medicare-hospital-compare-datasets
# 568 - medicare-nursing-home-compare-datasets
# 569 - medicare-physician-compare-datasets
# 570 - member-states-of-the-united-nations
# 571 - meteoritical-bulletin-database
# 572 - metmuseum-of-art-open-access-initiative
# 573 - mexican-health-and-aging-study-mhas
# 574 - mexican-migration-project-mmp
# 575 - microsoft-academic-graph-mag
# 576 - migracao-internacional
# 577 - migraciones-interiores-y-exteriores-de-espana
# 578 - millennium-development-goals-indicators
# 579 - million-song-dataset
# 580 - missing-migrants-project
# 581 - mit-election-data-science-lab
# 582 - mobile-broadband-data-costs
# 583 - mobile-coverage-explorer
# 584 - moderate-resolution-imaging-spectroradiometer-modis
# 585 - modern-era-retrospective-analysis-for-research-and-applications-merra
# 586 - monitor-de-politicas-de-drogas-nas-americas
# 587 - monroe-work-today
# 588 - mprjmais
# 589 - mundo-transfermarkt-competicoes
# 590 - museum-data-files-mdf
# 591 - museus-br
# 592 - musicbrainz
# 593 - nascidos-vivos-com-microcefalia-ou-zika
# 594 - national-crime-victimization-survey-ncvs
# 595 - national-health-security-preparedness-index-nhspi
# 596 - national-solar-radiation-database-nsrdb
# 597 - native-bee-inventory-and-monitoring-program
# 598 - native-land-ca
# 599 - natural-earth-data
# 600 - nature-phd-students-survey-data
# 601 - nba-basketball-stats
# 602 - newspapers-com
# 603 - new-york-city-sidewalks
# 604 - new-york-philharmonic-performance-history
# 605 - nighttime-lights
# 606 - nih-chest-x-rays
# 607 - nih-open-citation-collection
# 608 - nobel-laureates-1901-present
# 609 - nomes-africanos
# 610 - notificacao-de-casos-de-doenca-pelo-coronavirus-2019-covid-19
# 611 - novel-coronavirus-covid-19-situation
# 612 - oasis-brains-project
# 613 - observatorio-de-homicidios
# 614 - observatorio-de-migracoes-forcadas
# 615 - observing-systems-capability-analysis-and-review-oscar
# 616 - occupied-palestinian-territory
# 617 - oecd-income-distribution-database-idd
# 618 - oecd-revenue-statistics-in-latin-america-and-the-caribbean
# 619 - oecd-tax-database
# 620 - official-document-system-of-the-united-nations
# 621 - open-corporates
# 622 - open-data-barometer-odb
# 623 - open-data-inception
# 624 - open-states
# 625 - openstreetmap
# 626 - opentraffic
# 627 - operabase
# 628 - operacao-serenata-de-amor
# 629 - opportunity-atlas
# 630 - orbis-amadeus
# 631 - oxford-covid-19-government-response-tracker-oxcgrt
# 632 - painel-correicao-em-dados
# 633 - painel-de-indicadores-da-confederacao-nacional-de-reservas-particulares-do-patrimonio-natural-cnrppn
# 634 - painel-de-legislacao-ambiental
# 635 - painel-de-obras
# 636 - painel-de-obras-paralisadas-ou-atrasadas-sao-paulo
# 637 - painel-de-raio-x-da-administracao-publica-federal
# 638 - painel-de-viagens-governo-federal
# 639 - painel-dinamico-da-fiscalizacao-do-abastecimento
# 640 - painel-lei-de-acesso-a-informacao-lai
# 641 - painel-monitoramento-de-dados-abertos
# 642 - panel-study-of-income-dynamics-psid
# 643 - pan-pesticide-database
# 644 - pantheon
# 645 - parameter-elevation-regressions-on-independent-slopes-model-prism-climate-group
# 646 - parliamentary-elections
# 647 - parliamentary-rules-database
# 648 - parlspeech
# 649 - participacoes-governamentais-royalties-de-petroleo-e-gas-natural
# 650 - party-facts
# 651 - peacekeeping-fatalities
# 652 - peacekeeping-master-open-datasets
# 653 - peacekeeping-troop-and-police-contributions
# 654 - penn-world-tables
# 655 - perfil-das-unidades-do-instituto-nacional-de-seguro-social-inss
# 656 - perfil-dos-municipios-brasileiros
# 657 - perfil-parlamentar
# 658 - perfil-politico
# 659 - personal-characteristics-of-lone-actor-terrorists
# 660 - pesquisa-anual-da-industria-da-construcao-paic
# 661 - pesquisa-anual-de-comercio
# 662 - pesquisa-anual-de-servicos
# 663 - pesquisa-de-assistencia-medico-sanitaria-ams
# 664 - pesquisa-de-entidades-de-assistencia-social-privadas-sem-fins-lucrativos-peas
# 665 - pesquisa-de-informacoes-basicas-estaduais-estadic
# 666 - pesquisa-de-inovacao
# 667 - pesquisa-de-opiniao-american-trends-panel
# 668 - pesquisa-de-opiniao-global-attitudes-and-trends
# 669 - pesquisa-de-opiniao-hispanic-trends
# 670 - pesquisa-de-opiniao-internet-and-technology
# 671 - pesquisa-de-opiniao-journalism-and-media
# 672 - pesquisa-de-opiniao-publica-nacional-aborto-junho-2019
# 673 - pesquisa-de-opiniao-religion-and-public-life
# 674 - pesquisa-de-opiniao-science-and-society
# 675 - pesquisa-de-opiniao-social-and-demographic-trends
# 676 - pesquisa-de-opiniao-u-s-politics-policy
# 677 - pesquisa-de-orcamentos-familiares
# 678 - pesquisa-industrial-anual
# 679 - pesquisa-internacional-sobre-ensino-e-aprendizagem
# 680 - pesquisa-mensal-de-empregos-pme
# 681 - pesquisa-nacional-de-saneamento-basico-pnsb
# 682 - pesquisa-nacional-de-saude
# 683 - pesticide-properties-database-ppdb
# 684 - pew-survey-of-u-s-muslims
# 685 - pinball-map
# 686 - plano-de-nacional-de-controle-de-residuos-e-contaminantes-pncrc
# 687 - plataforma-cidades-frageis
# 688 - poki-a-large-dataset-of-poems-by-children
# 689 - police-brutality-during-the-2020-george-floyd-protests
# 690 - police-public-contact-survey-ppcs
# 691 - police-scorecard-project
# 692 - police-union-contract-project
# 693 - police-use-of-force-project
# 694 - policy-responses-to-covid-19
# 695 - political-terror-scale-pts
# 696 - polity-iv
# 697 - pollbase
# 698 - poll-of-polls
# 699 - polls-and-the-timeline-of-elections
# 700 - portal-da-transparencia-do-registro-civil
# 701 - portal-de-imigracao-laboral
# 702 - portal-meu-municipio
# 703 - posse-e-porte-de-arma-de-fogo
# 704 - precos-agropecuarios-parana
# 705 - precos-medicamentos-consumidor
# 706 - pregnancies-births-and-abortions-in-the-united-states-national-and-state-trends-by-age
# 707 - prestadores-de-servicos-turisticos-cadastur
# 708 - producao-da-extracao-vegetal-e-da-silvicultura-pevs
# 709 - producao-de-petroleo-e-gas-natural-nacional-dados-historicos
# 710 - produto-interno-bruto-pib
# 711 - programa-de-analise-de-residuos-de-agrotoxicos-em-alimentos-para
# 712 - programa-de-fiscalizacao-em-entes-federativos
# 713 - programa-nacional-de-acesso-ao-ensino-tecnico-e-emprego-pronatec
# 714 - programa-universidade-para-todos-prouni
# 715 - programme-for-international-student-assessment
# 716 - project-gutenberg
# 717 - projeto-flora-do-brasil-2020
# 718 - projetos-e-materias-do-senado-federal-legislativo
# 719 - projeto-tracksource
# 720 - propaganda-na-alemanha-nazista
# 721 - proposicoes-apresentadas-a-camara-dos-deputados
# 722 - protein-data-bank-pdb
# 723 - proyecto-inventario-de-cuba
# 724 - public-libraries-survey-pls
# 725 - public-utility-data-liberation-project-pudl
# 726 - purpleair-real-time-air-quality-monitoring
# 727 - qualis-periodicos
# 728 - quality-of-government-qog
# 729 - quantidade-de-armas-de-fogo-destruidas-pelo-exercito
# 730 - quantidade-de-infracoes-de-transito
# 731 - quantidade-de-novos-registros-de-armas-de-fogo-para-colecionadores
# 732 - quarterly-census-of-employment-and-wages-qcew
# 733 - quem-eram-os-papas
# 734 - quick-draw-dataset
# 735 - radar-legislativo
# 736 - radio-locator
# 737 - rand-database-of-worldwide-terrorism-incidents-rdwti
# 738 - ranked-vote
# 739 - ranking-da-transparencia-do-poder-judiciario
# 740 - ranking-de-transparencia-no-combate-a-covid-19
# 741 - receitas-e-despesas-dos-municipios-de-sao-paulo
# 742 - recenseamento-geral-do-imperio-do-brasil-de-1872
# 743 - reclamacoes-de-direitos-autorais-em-buscas
# 744 - registro-de-imoveis-do-brasil
# 745 - regulacao-de-atividades-moralmente-controversas
# 746 - remessas-de-dinheiro-internacionais-remittances
# 747 - report-of-the-committee-on-the-status-of-minority-groups-in-the-economics-profession-csmgep
# 748 - repositorio-de-eleicoes-na-india
# 749 - research-for-effective-covid-19-response-recovr
# 750 - residuos-solidos
# 751 - rois-de-informacoes-classificadas
# 752 - rois-de-informacoes-desclassificadas
# 753 - roller-coaster-database-rcdb
# 754 - rural-household-multiple-indicator-survey-rhomis
# 755 - russia-longitudinal-monitoring-survey-rlms
# 756 - saci
# 757 - salario-minimo
# 758 - salarios-dos-magistrados-no-brasil
# 759 - salud-bienestar-y-envejeveimiento-en-america-latina-y-el-caribe-sabe
# 760 - seattle-book-checkouts-by-title
# 761 - senadores-administrativo
# 762 - senadores-legislativo
# 763 - servico-militar-obrigatorio
# 764 - sexual-orientation-laws-in-the-world
# 765 - shakespeare-and-company-project
# 766 - shuttle-radar-topography-mission-srtm
# 767 - side-effect-resource-sider
# 768 - simply-scripts
# 769 - sinopses-estatisticas-da-educacao-basica
# 770 - sinopses-estatisticas-da-educacao-superior
# 771 - sinopses-estatisticas-do-exame-nacional-do-ensino-medio-enem
# 772 - sipri-arms-embargoes
# 773 - sipri-arms-transfers-database
# 774 - sipri-military-expenditure-database
# 775 - sistema-de-avaliacao-da-educacao-basica
# 776 - sistema-de-deteccao-de-desmatamentos-em-tempo-real
# 777 - sistema-de-informacoes-geograficas-da-mineracao-sigmine
# 778 - sistema-de-informacoes-hospitalares-do-sus-sihsus
# 779 - sistema-de-informacoes-sobre-orcamentos-publicos-em-saude-siops
# 780 - sistema-de-licenciamento-ambiental-sislic
# 781 - sistema-de-registro-nacional-de-emissoes-sirene
# 782 - sistema-integrado-de-gestao-de-barragens-de-mineracao-sigbm
# 783 - sistema-nacional-de-cadastro-rural-sncr
# 784 - sistema-nacional-de-informacoes-sobre-saneamento-snis
# 785 - sistema-nacional-de-informacoes-toxico-farmacologicas-sinitox
# 786 - sistema-nacional-de-viacao
# 787 - sketchgraphs-a-large-scale-dataset-for-modeling-relational-geometry-in-computer-aided-design
# 788 - smithsonian-open-access
# 789 - soccer-match-event-dataset
# 790 - social-conflict-analysis-database-scad
# 791 - social-connectedness-index-facebook-sci
# 792 - social-explorer
# 793 - social-scientists-before-congress
# 794 - socio-economic-database-for-latin-america-and-the-caribbean-sedlac
# 795 - socioeconomic-high-resolution-rural-urban-geographic-platform-for-india-shrug
# 796 - soil-grids
# 797 - solicitacoes-de-reconhecimento-da-condicao-de-refugiado
# 798 - south-african-national-income-dynamics-study-nids
# 799 - south-asia-terrorism-portal
# 800 - spotify-charts
# 801 - stack-overflow-annual-developer-survey
# 802 - stadiumdb
# 803 - statoids
# 804 - stayinghome-club
# 805 - stop-question-and-frisk-data
# 806 - storm-events-database
# 807 - survey-of-earned-doctorates-sed
# 808 - survey-of-the-incarcerated
# 809 - sustainable-development-goals-sdg
# 810 - systemic-banking-crises
# 811 - taxa-de-cambio
# 812 - taxas-de-letalidade-violenta-por-grandes-regioes-rj
# 813 - taxa-selic
# 814 - tax-introduction-database-tid
# 815 - tenders-electronic-daily-ted-public-procurement-notices-from-the-eu
# 816 - terraclass
# 817 - terrain-ruggedness
# 818 - terras-indigenas-sistema-indigenista-de-informacoes
# 819 - territorial-self-governance-dataset-terrgo
# 820 - tesco-grocery
# 821 - the-atlas-of-surveillance
# 822 - the-big-mac-index
# 823 - the-comprehensive-bigfoot-sightings-database
# 824 - the-condemned
# 825 - the-covid-tracking-project
# 826 - the-digital-atlas-of-roman-and-medieval-civilizations-darmc
# 827 - the-evolution-of-the-american-census
# 828 - the-geographic-diversity-project
# 829 - the-global-dataset-of-historical-yields-for-major-crops-1981-2016
# 830 - the-health-inequality-project
# 831 - the-indonesia-family-life-survey-ifls
# 832 - the-international-disaster-database-em-dat
# 833 - the-international-political-economy-ipe-data-resource
# 834 - the-largest-known-primes
# 835 - the-longevity-of-famous-people-from-hammurabi-to-einstein
# 836 - the-malaysian-family-life-surveys-mfls
# 837 - the-market-for-data-privacy-data-and-code
# 838 - the-metal-archives
# 839 - the-microbe-directory
# 840 - the-national-registry-of-exonerations
# 841 - the-observatory-of-economic-complexity-oec
# 842 - the-official-register-of-the-united-states-1816-1959
# 843 - the-oldest-company-in-almost-every-country
# 844 - the-planetary-exploration-budget-dataset
# 845 - the-specter-of-chemical-weapons-use-in-syria
# 846 - the-study-of-the-tsunami-aftermath-and-recovery-star
# 847 - the-triumph-of-injustice
# 848 - the-xinjiang-data-project
# 849 - tic-domicilios
# 850 - tic-educacao
# 851 - tic-empresas
# 852 - tic-governo-eletronico
# 853 - tic-kids-online
# 854 - tic-organizacoes-sem-fins-lucrativos
# 855 - tic-saude
# 856 - tools-for-harmonizing-u-s-county-boundaries
# 857 - townsend-thai-project
# 858 - tracking-government-responses-towards-covid-19
# 859 - trans-atlantic-slave-trade-database
# 860 - transferencias-a-estados-e-municipios
# 861 - transit-costs-project
# 862 - tree-biomass-loss
# 863 - trump-twitter-archive
# 864 - tsa-screenings
# 865 - tv-tropes
# 866 - tweets-de-donald-trump-atacando-a-imprensa
# 867 - tweets-of-congress
# 868 - uber-movement
# 869 - ucdp-battle-related-deaths-dataset
# 870 - ucdp-dyadic-dataset
# 871 - ucdp-georeferenced-event-dataset-ged-global-version
# 872 - ucdp-georeferenced-event-dataset-ged-polygons
# 873 - ucdp-georeferenced-event-dataset-ged-syria
# 874 - ucdp-non-state-conflict-dataset
# 875 - ucdp-one-sided-violence-dataset
# 876 - ucdp-onset-dataset
# 877 - ucdp-peace-agreement-dataset
# 878 - ucdp-prio-armed-conflict-dataset
# 879 - ucs-satellite-database
# 880 - u-k-inspire-index-polygons-spatial-data
# 881 - unidades-de-conservacao
# 882 - unidades-de-conservacao-painel-dinamico-de-informacoes-gerenciais
# 883 - uniform-crime-reporting-ucr-program-data-arrests-by-age-sex-and-race
# 884 - united-nations-general-assembly-voting-data
# 885 - united-states-newspaper-panel-1869-2004
# 886 - university-of-california-cliometric-history-project-uc-chp
# 887 - u-n-treaty-collection
# 888 - u-s-annual-survey-of-state-and-local-government-finances
# 889 - usaspending-gov
# 890 - u-s-board-on-geographic-names
# 891 - u-s-campaign-finance-data
# 892 - u-s-cancer-statistics-center
# 893 - u-s-census-linking-project
# 894 - us-census-microdata
# 895 - u-s-census-of-governments
# 896 - u-s-covid-19-economic-tracker
# 897 - u-s-crime-data-explorer-cde
# 898 - usda-national-forest-type-dataset
# 899 - u-s-debt-to-the-penny
# 900 - u-s-federal-sentencing
# 901 - u-s-fm-service-contour-data-points
# 902 - u-s-frequently-occurring-surnames
# 903 - u-s-historical-debt-outstanding
# 904 - u-s-law-enforcement-officers-killed-and-assaulted-leoka
# 905 - u-s-law-schools
# 906 - u-s-monthly-retail-trade
# 907 - u-s-national-park-trails
# 908 - u-s-newspaper-navigator
# 909 - u-s-nonprofit-explorer
# 910 - u-s-police-shootings-database
# 911 - u-s-political-polls
# 912 - u-s-post-offices
# 913 - u-s-press-freedom-tracker
# 914 - u-s-prison-system-statistics
# 915 - u-s-protests-since-2017
# 916 - u-s-state-by-state-spending-on-kids
# 917 - u-s-support-for-black-lives-matter
# 918 - u-s-survey-of-doctorate-recipients-sdr
# 919 - u-s-survey-of-income-and-program-participation-sipp
# 920 - u-s-tv-service-contour-data-points
# 921 - u-s-women-elected-officials
# 922 - utd19
# 923 - utility-rate-database-urdb
# 924 - vanderbilt-television-news-archive
# 925 - varieties-of-democracy-v-dem
# 926 - vessel-finder
# 927 - visible-infrared-imaging-radiometer-suite-viirs
# 928 - what-do-philosophers-believe
# 929 - where-s-george
# 930 - whogov
# 931 - who-is
# 932 - whose-heritage-public-symbols-of-the-confederacy
# 933 - wikiart
# 934 - wilderness-net
# 935 - witch-trials
# 936 - women-in-parliament
# 937 - world-air-quality-index
# 938 - world-atlas-of-language-structures-wals
# 939 - world-bank-projects-and-operations
# 940 - world-database-on-protected-areas-wdpa
# 941 - world-development-indicators
# 942 - world-digital-library-wdl
# 943 - world-fertility-surveys-wfs
# 944 - world-giving-index-wgi
# 945 - world-governance-indicators
# 946 - world-happiness-report
# 947 - world-higher-education-database-whed
# 948 - world-inequality-database
# 949 - world-input-output-database-wiod
# 950 - world-management-survey-wms
# 951 - worldometer
# 952 - worldpop
# 953 - world-population-prospects-wpp
# 954 - world-poverty-clock
# 955 - world-press-freedom-index
# 956 - world-sea-temperatures
# 957 - world-stadiums
# 958 - world-uncertainty-index-wui
# 959 - world-urbanization-prospects-wup
# 960 - world-values-survey
# 961 - world-war-i-document-archive
# 962 - worldwide-bureaucracy-indicators-wwbi
# 963 - worldwide-mobile-data-pricing
# 964 - young-lives
# 965 - world-competitiveness-ranking
# 966 - br-cgu-pessoal-executivo-federal
# 967 - br-me-cno
# 968 - br-camara-dados-abertos
# 969 - br-camara-atividade-legislativa

# %%
ckan_remote_local = RemoteCKAN(
    "http://localhost:5000",
    "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJ3eTVMYThfeDllN0dFdmtodE5MaXNMR2FfN3Etc1lWeTFPeldWVjQ5QWZOMXdiQWgtVHdGY0F5cjJtYnpEb01ZbnZDYm5wZDNsRGdaWExuTiIsImlhdCI6MTY0Mjk4Mjk3MX0.k2iMMrC_DfRdDylqUDbXo7UOCeksazxginQSEReCoJg"
)
ckan_remote_dev = RemoteCKAN(
    "https://staging.basedosdados.org",
    ""
)

ckan_remote = ckan_remote_local

dev_names = [package['name'] for package in dev_packages]
prod_names = [package['name'] for package in prod_packages]

for i, package in enumerate(updated_packages):
    
	print(i, ' - ', package['name'])

	if updated_package['name'] != 'br-ibge-censo-demografico':
		migrator = Migrator(ckan_remote, updated_package)
	else:
		censo = copy.deepcopy(updated_package)
		censo['resources'] = censo['resources'][0:29] # waiting to solve issue #website/219
		migrator = Migrator(ckan_remote, censo)
	
	migrator.validate()

	#if package['name'] in dev_names:
	#	migrator.update()
	#else:
	#	migrator.create()
